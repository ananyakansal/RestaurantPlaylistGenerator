# %%
import numpy as np
import sys
sys.path.append ('/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages')
from librosa import load, feature
from IPython.display import Audio
from scipy.io.wavfile import read
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
import sklearn
import pandas as pd

# %% [markdown]
# Similarity Using Cosine Distance

# %%
df = pd.read_csv('testSongData.csv')

# %%
songlist = df.values.tolist()
songlist
# Out:
# [["['El Majo Olvidado']",
#   "['Kim Kashkashian / Robert Levin']",
#   "['AsturianaSongs from Spain and Argentina']",
#   0.00772218545899,
#   0.9922778010369999,
#   0.962229669094,
#   0.00045702868374099996,
#   0.0018324668053499998,
#   0.0322792083025,
#   0.000355220312485,
#   0.0014598116977100001,
#   0.000582756241783,
#   0.000803849485237,
#   0.050519190728699995,
#   0.229904696345,
#   0.500016987324,
#   0.183133840561,
#   0.0364252962172,
#   0.658461689949,
#   0.341538310051,
#   0.9804841279979999,
#   0.019515877589599998,
#   0.0835315585136,
#   84.4965667725],
#  ["['Les Programmeurs']",
#   "['Tri Yann']",
#   "['Café du Bon Coin']",
#   0.63545781374,
#   0.36454218626,
#   0.0329187326133,
#   0.057352140545800005,
#   0.162320315838,
#   0.087341748178,
#   0.349094331264,
#   0.192879930139,
#   0.109712079167,
#   0.008380719460550001,
#   0.14401553571200001,
#   0.139429688454,
#   0.229340910912,
#   0.242777660489,
#   0.24443621933499998,
# ...

# %%
for i in range(0, len(songlist)):
    del(songlist[i][0])

# %%
for i in range(0, len(songlist)):
    del(songlist[i][0])

# %%
for i in range(0, len(songlist)):
    del(songlist[i][0])

# %%
songlist
# Out:
# [[0.00772218545899,
#   0.9922778010369999,
#   0.962229669094,
#   0.00045702868374099996,
#   0.0018324668053499998,
#   0.0322792083025,
#   0.000355220312485,
#   0.0014598116977100001,
#   0.000582756241783,
#   0.000803849485237,
#   0.050519190728699995,
#   0.229904696345,
#   0.500016987324,
#   0.183133840561,
#   0.0364252962172,
#   0.658461689949,
#   0.341538310051,
#   0.9804841279979999,
#   0.019515877589599998,
#   0.0835315585136,
#   84.4965667725],
#  [0.63545781374,
#   0.36454218626,
#   0.0329187326133,
#   0.057352140545800005,
#   0.162320315838,
#   0.087341748178,
#   0.349094331264,
#   0.192879930139,
#   0.109712079167,
#   0.008380719460550001,
#   0.14401553571200001,
#   0.139429688454,
#   0.229340910912,
#   0.242777660489,
#   0.24443621933499998,
#   0.5,
#   0.5,
#   0.06623198837040001,
#   0.9337680339810001,
#   0.765487313271,
#   127.834915161],
#  [3.00000096379e-14,
#   1.0,
#   0.0012128961971,
#   0.910444140434,
#   0.0202603191137,
# ...

# %%
score1 = sklearn.metrics.pairwise.cosine_similarity(songlist,Y=None,dense_output=True)[31]
score1
# Out:
# array([0.99991951, 0.99989742, 0.99994125, 0.99997575, 0.99992607,
#        0.99999367, 0.99974149, 0.99988958, 0.99995152, 0.99979487,
#        0.99985324, 0.99984271, 0.99991937, 0.99971158, 0.99990754,
#        0.99991837, 0.99990677, 0.99993388, 0.99989571, 0.9998632 ,
#        0.99981772, 0.99992325, 0.99990452, 0.99987135, 0.99974505,
#        0.99995829, 0.99985431, 0.99993242, 0.99990117, 0.99995252,
#        0.9998849 , 1.        , 0.99985287, 0.99985565, 0.99990511,
#        0.99991516, 0.99993198, 0.99979259, 0.99982813, 0.99985655,
#        0.99980044, 0.99992399, 0.99991097, 0.99984754, 0.99984624,
#        0.9999292 , 0.99995237, 0.99988856, 0.99980459, 0.99993154,
#        0.99988076, 0.99982684, 0.99982883, 0.99996088, 0.999866  ,
#        0.99989746, 0.9999218 , 0.99993504, 0.99985872, 0.99996866,
#        0.99986583, 0.99991173, 0.99994341, 0.99988167, 0.99994274,
#        0.99984917, 0.99989298, 0.99976121, 0.99989012, 0.999826  ,
# ...

# %%
rank1 = score1.argsort()
rank1
# Out:
# array([661, 240, 491, 314, 161, 163,  13, 733, 631, 251, 349, 696, 212,
#        490, 157, 588,  93, 142,   6, 650, 711,  24, 232, 620, 223, 313,
#        321, 494, 420, 528, 456, 721, 173, 644,  67, 626, 542, 438, 531,
#        199, 640, 503, 196, 345, 500, 668, 337, 747, 274, 492, 424, 177,
#        432, 684, 699, 461, 455, 590, 567, 252, 344, 339, 497, 635, 236,
#         37, 270,   9, 416, 703, 478, 454, 471, 309, 352, 342, 761, 361,
#        358,  80, 511,  40, 789, 795,  48, 553, 523, 518, 780, 149, 193,
#        606, 243, 233, 346, 167, 642, 320, 580, 128, 570, 124,  20, 386,
#        764, 583, 294, 132, 672, 280, 655, 680,  75, 392, 259, 323, 646,
#        715, 333, 238, 639,  69, 130,  74, 767,  51, 225,  38, 622, 122,
#        310,  52, 593, 806, 203, 273, 217, 482, 146, 269, 607, 319, 365,
#        385, 249, 496, 717, 602, 695, 307, 312, 479, 546, 466, 327, 576,
#        614, 712, 402, 109, 791, 777,  11, 290, 589, 527, 258, 627, 351,
# ...

# %% [markdown]
# Similarity Using Affinity Propogation

# %%
df = pd.read_csv('100songdata.csv')
songlist = df.values.tolist()
songlist
# Out:
# [["['El Majo Olvidado']",
#   "['Kim Kashkashian / Robert Levin']",
#   "['AsturianaSongs from Spain and Argentina']",
#   0.00772218545899,
#   0.9922778010369999,
#   0.962229669094,
#   0.00045702868374099996,
#   0.0018324668053499998,
#   0.0322792083025,
#   0.000355220312485,
#   0.0014598116977100001,
#   0.000582756241783,
#   0.000803849485237,
#   0.050519190728699995,
#   0.229904696345,
#   0.500016987324,
#   0.183133840561,
#   0.0364252962172,
#   0.658461689949,
#   0.341538310051,
#   0.9804841279979999,
#   0.019515877589599998,
#   0.0835315585136,
#   84.4965667725],
#  ["['Les Programmeurs']",
#   "['Tri Yann']",
#   "['Café du Bon Coin']",
#   0.63545781374,
#   0.36454218626,
#   0.0329187326133,
#   0.057352140545800005,
#   0.162320315838,
#   0.087341748178,
#   0.349094331264,
#   0.192879930139,
#   0.109712079167,
#   0.008380719460550001,
#   0.14401553571200001,
#   0.139429688454,
#   0.229340910912,
#   0.242777660489,
#   0.24443621933499998,
# ...

# %%
for i in range(0, len(songlist)):
    del(songlist[i][0])

# %%
for i in range(0, len(songlist)):
    del(songlist[i][0])

# %%
for i in range(0, len(songlist)):
    del(songlist[i][0])

# %%
model = sklearn.cluster.AffinityPropagation()

# %%
labels = model.fit_predict(songlist)

# %%
print(labels)
# Out:
# [0 4 5 5 2 5 3 3 1 1 0 4 6 0 5 1 5 2 3 5 1 6 4 3 3 2 5 2 5 6 4 6 3 5 4 6 5
#  3 1 3 1 1 5 4 0 6 2 2 0 2 5 0 3 5 1 3 4 5 4 6 1 4 2 4 4 5 5 3 4 0 2 4 2 5
#  3 4 4 6 4 5 0 5 6 5 6 6 4 4 1 5 6 4 2 3 0 3 2 3 3 5]
