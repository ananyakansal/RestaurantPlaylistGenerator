# %%
import numpy as np
import sys
sys.path.append ('/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages')
from librosa import load, feature
from IPython.display import Audio
from scipy.io.wavfile import read
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
import sklearn
import pandas as pd

# %%
df = pd.read_csv('out.csv')

# %%
alldata = df.values.tolist()

# %% [markdown]
# # Classical Playlists

# %%
# classical cheerful bright instrumental fast not_dance 281
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 2:
        if alldata[i][26] == 11:
            if alldata[i][27] == 15:
                if alldata[i][28] == 17:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Jacqueline', 'spotify:track:0DA459lZrZqqOPO2m2ekSE'],
#  ['Samba De Angry', 'spotify:track:5e5mySUIenXwXW3rwM8JX1'],
#  ['Quiet Beauty', 'spotify:track:7iLl9YbHSiXRgj6Fy2ZGPh'],
#  ['White Garlic', 'Not Found'],
#  ['Eon Blue Apocalypse', 'spotify:track:5aVJ5rv7ghWSkQaqP726tE'],
#  ['Petrushka - I. Le tour de pass', 'Not Found'],
#  ['Soldiers Joy', 'spotify:track:6ViWOuVuZAtDZuGfI2XNCz'],
#  ['Heart Like A Wheel', 'spotify:track:1uDZjIV8W9EEq1J9MbJxhK'],
#  ['Your Name (Has Slipped My Mind Again)',
#   'spotify:track:3fgSfvNcJbzhVhzEV74Wqq'],
#  ['Gaîté Parisienne, ballet: No. 22', 'spotify:track:5hutF14UOsJsRyfkTubulr'],
#  ['Jørgen Østvang', 'spotify:track:2nZNmTMYfGmna81f2Eq67F'],
#  ['Int. 3', 'spotify:track:3u6ptJOkl6fyVwJuI0dbu1'],
#  ['Chain of Fools', 'spotify:track:3YnVd0MuCRsqDv2irVtPhH'],
#  ['Sonata for 2 cellos No. 10 in G major: Allegro prestissimo', 'Not Found'],
#  ['Caprice For Solo Violin, Op. 1 No. 9 In E Major',
#   'spotify:track:36mpQAaQXFMlZHCyoOpwGn'],
# ...

# %%
# classical cheerful bright voice fast not_dance 314
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 2:
        if alldata[i][26] == 11:
            if alldata[i][27] == 15:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Byen driver', 'Not Found'],
#  ['Red Balloon', 'spotify:track:7FF85cvYeg3ivmig48MuQk'],
#  ['Mamas Intro (Gods Order) Skit', 'spotify:track:2kLFsJWo6cUND8ZEKcMD2N'],
#  ['Lied zum Schluss (Zu dritt Version)',
#   'spotify:track:3vfzdJyMRyqBD3XQfyfBz0'],
#  ['Slims Jam', 'Not Found'],
#  ['Ill Know', 'spotify:track:2oG8VHCUYe6HI6ASPDUq5P'],
#  ['12.Qui di sposa eterna fede', 'Not Found'],
#  ['11 - FOUNTAINS  OF  WAYNE - I Want You Around', 'Not Found'],
#  ['Gruesome Details', 'spotify:track:4Wt0iVR2tAMDwGhkeUX0TD'],
#  ['But They Got It Fixed Right On', 'spotify:track:2yTC4GRz3Y7yNKcq1fTS70'],
#  ['Im Bugged at My Ol Man', 'spotify:track:5cgFP20UJaGnXfoJfuCMO2'],
#  ['Time And Space', 'spotify:track:6po0trnxfpO80hJeAgFQ7E'],
#  ['Ather', 'spotify:track:15ZX0irzz20HXT3p7GtNKx'],
#  ['God Bless the Child', 'spotify:track:6v2DbCEOjbO4VrNkFACL4k'],
#  ['Tozhular Yry', 'spotify:track:6aNO0B7wXv47uUgj5e8PWl'],
#  ['Home of the Blues (Overdubbed Master)', 'Not Found'],
# ...

# %%
# classical cheerful bright voice slow notdance 165
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 2:
        if alldata[i][26] == 11:
            if alldata[i][27] == 15:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 20:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Believe', 'spotify:track:1TEMlXRU6c8zBqnp2bKj7X'],
#  ['Boat of Car (live)', 'Not Found'],
#  ['Pijani pilot', 'spotify:track:1I4Olvm1XczESfBehBV81v'],
#  ['Uncle Tom Got Caught', 'spotify:track:4MOWNBzwBTqYrLlIVNhXR5'],
#  ['Cleve Van Valen (Cleve Van Valen / Wagon Train / Morgan, Lilith and Aggie / Cleve and the Mule) (extended version)',
#   'Not Found'],
#  ['Oregon', 'spotify:track:2emKXFrE9GkomiZAMHfvQn'],
#  ['Dont Think Twice, Its All Right', 'spotify:track:5YqdrbmXUOYUjL7GYaSVSo'],
#  ['Faust Ballet Music: V. Les Troyens', 'Not Found'],
#  ['Handsome Molly', 'Not Found'],
#  ['Dont Take It Out on Me', 'Not Found'],
#  ['Cancion final', 'Not Found'],
#  ['Dulcinea', 'spotify:track:6S9cVNkrZIgzN4aZPf3l7B'],
#  ['Proud Mary', 'Not Found'],
#  ['Living Without You', 'spotify:track:7DsVUVNJPFToKYpDO6JXp1'],
#  ['Shadow My Baby', 'spotify:track:6ffPIfotQ6Jxktgcy5Fy38'],
#  ['Uphi Umhlobo', 'spotify:track:3Gv0dolr8nchisNROwsiJ0'],
#  ['Coming Home, Parts 1 & 2', 'Not Found'],
# ...

# %%
# classical cheerful dark instrumental fast notdance 150
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 2:
        if alldata[i][26] == 11:
            if alldata[i][27] == 16:
                if alldata[i][28] == 17:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Honda Is Tortured', 'Not Found'],
#  ['Flyer', 'spotify:track:6rv0Dpr35OtWi1OGE2DPW7'],
#  ['Down by the Creek', 'Not Found'],
#  ['Ikos', 'spotify:track:3cMfDnpCcxP1OJJeWlq0K2'],
#  ['Pictures at an Exhibition (Kartinki s vïstavski), for orchestra: Samuel Goldenberg and Schmuyle',
#   'Not Found'],
#  ['Blue Soldier Night', 'spotify:track:2FZZMhmyvpn8kSXywKQx6X'],
#  ['Venezia lunare', 'spotify:track:0mMm7Q99ECe8d7Cr5Kq6NT'],
#  ['Das wohltemperierte Klavier, Buch I: Fuge No. 16 G-moll, BWV 861',
#   'Not Found'],
#  ['Bishops Countdown', 'spotify:track:2ey3OGFKBn4yX8yw5PprV5'],
#  ['Boards Phone Machine', 'spotify:track:4YzVKmuHF0U4EaIMGd77DA'],
#  ['Im Alone With You', 'spotify:track:31fiqgLHk5CBEGyHoLy3kC'],
#  ['Burning the Book', 'spotify:track:6STzdsTKkGGOT6qmEEnQhH'],
#  ['Drax / Kit (The Phantom Fights Back)', 'Not Found'],
#  ['Exodus', 'spotify:track:2Bkfvi3pCcwoJwnmd45OnA'],
#  ['Lisa (The Passion)', 'spotify:track:6rtTh1XJZpMFzdmBvjGBkQ'],
# ...

# %%
# classical bittersweet bright instrumental fast notdance 717
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 2:
        if alldata[i][26] == 12:
            if alldata[i][27] == 15:
                if alldata[i][28] == 17:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Little Martha', 'spotify:track:4hgFHqoT6TaVgmQVPqJPhk'],
#  ['What Is And What Should Never Be (Rough Mix With Vocal)',
#   'spotify:track:6eOVtyKUlEO6osSI6weaFC'],
#  ['Suite No. 1 in A-major, BWV 806: VII. Sarabande',
#   'spotify:track:7IbX0uph3xSIzYLJSgjOlW'],
#  ['Act 3 - Scene 1 - Ah!... Deh, Cessate Quel Contento!... Dalle Stanze Ove Lucia',
#   'Not Found'],
#  ['Dancing on the (Berlin) Wall', 'spotify:track:5nYfoT04GrVfdWYU5dSQ1N'],
#  ['Sonata for bassoon & cello in B-flat major, K. 292 (K. 196c): I. Allegro',
#   'Not Found'],
#  ['Prelude, after Vivaldi (theorbo solo)', 'Not Found'],
#  ['Sometimes Im Happy', 'spotify:track:4F2uV1GxPPSb03G1CB4R0M'],
#  ['Bigger House', 'Not Found'],
#  ['Five Rückert-Lieder (2001 Digital Remaster): II: Liebst du um Schönheit',
#   'Not Found'],
#  ['Hersham Boys', 'spotify:track:5pZfyHjckVQ9a8SqkQlzE6'],
#  ['Miroku', 'spotify:track:5s63g4kUHYmydJEvWLKx2y'],
#  ['Sanctuary', 'spotify:track:32bKYzqdUwt4u2iRp4DTI1'],
# ...

# %%
# classical bittersweet bright instrumental slow not_dance 230
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 2:
        if alldata[i][26] == 12:
            if alldata[i][27] == 15:
                if alldata[i][28] == 17:
                    if alldata[i][29] == 20:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['El Majo Olvidado', 'Not Found'],
#  ['All Men Know the Truth', 'Not Found'],
#  ['More Dreams', 'spotify:track:4v7hY1KV7eBqsKYCihg3Fe'],
#  ['Boy Beach and Ball', 'spotify:track:6SmNM4Pv2dXMxYqVhE2fyX'],
#  ['Chicken Feed', 'spotify:track:6s7coadGxGLWTqC3J3I1Gg'],
#  ['Timeout And Mind', 'spotify:track:7aUq1jV2QA3YhBsfc7T7rS'],
#  ['Life Mask (Interlude)', 'spotify:track:5pTidTk6LpYTVebNQOCRdA'],
#  ['John Brown', 'spotify:track:2ViUgXvUq3UdqqR19TH9ua'],
#  ['When Youre Smiling (Alt)', 'Not Found'],
#  ['Symphony no. 5 in D minor, op. 107 Reformation: 2. Allegro vivace',
#   'spotify:track:3wdnVxn4q7XZWvpzbLGgi3'],
#  ['Prelude', 'spotify:track:6b0oZ8TjWHquXZs8YMQZet'],
#  ['Satori (Enlightenment)', 'spotify:track:6EGRXWF3PmMb0cytL63hVG'],
#  ['Electric Counterpoint: I. Fast', 'spotify:track:62nT00q7HsIuyFWfSLxMP4'],
#  ['Golden Age of Terrible Photography',
#   'spotify:track:5T1oFXlOruJMGfktBfkY38'],
# ...

# %%
# classical bittersweet bright voice fast not_dance 243
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 2:
        if alldata[i][26] == 12:
            if alldata[i][27] == 15:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Mona Lisa', 'spotify:track:6okiHoGuuFyamV54GkdXIM'],
#  ['Shot in the Head', 'Not Found'],
#  ['Desperado', 'Not Found'],
#  ['Icarus', 'Not Found'],
#  ['Sunny Tennessee', 'Not Found'],
#  ['Il Turco in Italia (1997 Digital Remaster), ATTO SECONDO: In Italia certamente non si fa lamor cosi',
#   'spotify:track:7kNiU2tspbJTNc1Or8UwOI'],
#  ['Fum, Fum, Fum', 'Not Found'],
#  ['Act 1 - Che Gelida Manina', 'spotify:track:7ovSFr12IB8SywbiyQaPuP'],
#  ['Atto 1 - Fermo! Che Fai? Tarresta!', 'Not Found'],
#  ['Atto IV - Quest Ultimo Bacio Cheil Pianto', 'Not Found'],
#  ['Away in a Manger', 'spotify:track:0uR9e3VLzrviQXIg80NZwJ'],
#  ['Dont Cry for Me Argentina', 'spotify:track:1oh7JFblzvaHuiXWltfNSM'],
#  ['Acte III - Quant Au Douanier, Cest Notre Affaire',
#   'spotify:track:7LJvohHz8zO5tIeYrptIRu'],
#  ['Kantate, BWV 4 Christ Lag In Todesbanden: V. Coro Versus IV Es War Ein Wunderlicher Krieg',
#   'Not Found'],
#  ['Brain Damage', 'spotify:track:05uGBKRCuePsf43Hfm0JwX'],
# ...

# %%
# classical bittersweet bright voice slow not_dance 243
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 2:
        if alldata[i][26] == 12:
            if alldata[i][27] == 15:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 20:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['You Can Bet Your Bottom Dollar', 'spotify:track:32vh61rklsrd1JTw20UARP'],
#  ['Let Me Go Lover', 'spotify:track:2ghmhqUMZ4Z2GqpwrH8yLj'],
#  ['You Still Have a Place in My Heart', 'Not Found'],
#  ['Silent Night, Holy Night', 'spotify:track:5qXD16VZmq0kjRDAvJbcbJ'],
#  ['Laudate pueri: Gloria Patri et Filio et Spiritui Sancto', 'Not Found'],
#  ['My Heart Knows', 'spotify:track:1AVRHmq97dGq2chjIgWc8r'],
#  ['All the Flowers', 'spotify:track:7pDv4YeKNqH8zHYcnU8lRj'],
#  ['Erased', 'spotify:track:4jzEkdmhmeXO0tmbXINLqV'],
#  ['Thank You for Loving Me', 'spotify:track:37NE69B3PGCmcwoO0y9Snc'],
#  ['Breaking the Law', 'Not Found'],
#  ['South of Chicago', 'spotify:track:5ncfPDRY7NQXigq1s06dT3'],
#  ['Guilty', 'spotify:track:6p66URrQrQgIEJsUGqh481'],
#  ['Herberts Blaue Augen', 'spotify:track:7JTbADBqAmAz2kOJMYh0Wr'],
#  ['Leftover Wine (live)', 'Not Found'],
#  ['Marble Coolie Hat', 'spotify:track:3tlHFuv3DSuLPt8yjEsIWB'],
#  ['Mean Bad Man Blues', 'Not Found'],
# ...

# %%
# classical bittersweet bright voice slow not_dance 243
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 2:
        if alldata[i][26] == 12:
            if alldata[i][27] == 15:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 20:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1

# %%
# classical bittersweet dark instrumental fast not_dance 828
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 2:
        if alldata[i][26] == 12:
            if alldata[i][27] == 16:
                if alldata[i][28] == 17:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Sonata, S.R. 103 Modo Dorico in C minor', 'Not Found'],
#  ['The Past', 'spotify:track:0IOpGnoXwTSEw5HC3qCW9r'],
#  ['Sending the Earl to Valhalla', 'spotify:track:5OGeSNCcBhFuflw2u4R2jr'],
#  ['The Subway Voice', 'Not Found'],
#  ['Madama Butterfly: Act I. Introduction / E soffito e pareti', 'Not Found'],
#  ['III. Cour dAmours: Amor Volat Undique',
#   'spotify:track:70ruoZFDxU6Wikloxyhc18'],
#  ['The Purple of All Curtains', 'Not Found'],
#  ['Bells Aloud', 'spotify:track:7GuX57VUPoTXjdrlHuibof'],
#  ['Symphonic Studies, op. 13: Etude VI',
#   'spotify:track:5MAhsM0Z2nv0UVTJn1U26z'],
#  ['Again, to Drift (For Veronika)', 'spotify:track:6Uvty1D4ozVxkI5lxahNU3'],
#  ['Don Quixote, op. 35: 12. Variation 9 (Schnell und stürmisch)',
#   'spotify:track:4VmUlpbKBGrbndnM9OQ2TA'],
#  ['The Town Marshall; A Quarter Interest', 'Not Found'],
#  ['As Easy As Breathing', 'spotify:track:43iMjzi6phlBEpHD9sVwMw'],
#  ['Eight Concert Études, Op. 40: No. 3. Toccatina. Allegro', 'Not Found'],
# ...

# %%
# classical bittersweet dark instrumental slow not_dance 312
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 2:
        if alldata[i][26] == 12:
            if alldata[i][27] == 16:
                if alldata[i][28] == 17:
                    if alldata[i][29] == 20:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Path 5 (Short Edit)', 'spotify:track:4jjFmHGsEmeTodWedjIM0r'],
#  ['Balthasar (extended version)', 'spotify:track:6lJDLiBWw7LbHxmOyMK4yx'],
#  ['The Procession to Calvary', 'spotify:track:7vAW1CCCNE4R2tqAInAXVg'],
#  ['Sunshower', 'spotify:track:3jPEwRNX93K1SauQCT6c2G'],
#  ['The Path of Tushui', 'Not Found'],
#  ['At Present', 'spotify:track:1rG544AVQEDdflCNLBL398'],
#  ['Pozor', 'spotify:track:6GoNLD1QwAosWeSP9Ensg6'],
#  ['Transmission One', 'Not Found'],
#  ['Mafia', 'spotify:track:2IMoLfbKHnODgjoqbOOcBe'],
#  ['Mirage', 'spotify:track:2gDm82zUtEAxAjrRYK98a4'],
#  ['Beyond Sorrow and Grief (extended version)',
#   'spotify:track:1yD7kM9XCFlsM5gbzx765D'],
#  ['Once Upon a Time Orchestral Suite', 'Not Found'],
#  ['24 Preludes & Fugues, op. 87: Fugue no. 10 in C-sharp minor. Moderato (4 voice)',
#   'Not Found'],
#  ['Wander', 'spotify:track:3I7JFFCxYmFnhU5qrsIpZo'],
#  ['Ultraviolet (Rothko remix)', 'Not Found'],
#  ['Cinderella: Act III. No. 39. The Prince and the Cobblers',
# ...

# %%
# classical bittersweet dark voice fast not_dance 232
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 2:
        if alldata[i][26] == 12:
            if alldata[i][27] == 16:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1

# %%
# classical bittersweet dark voice slow not_dance 79
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 2:
        if alldata[i][26] == 12:
            if alldata[i][27] == 16:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 20:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['The Unfortunate Lass', 'Not Found'],
#  ['Lili Marlène', 'Not Found'],
#  ['Atto 1 - Figlio, Che Fai?', 'Not Found'],
#  ['Fineline', 'spotify:track:2QUI6QJ7gospWKbUeMxh6M'],
#  ['Rose of Los Angeles', 'spotify:track:2P5NeGSpkN4eS3vbzvzjwx'],
#  ['The Difference Is Why (Home demo)', 'spotify:track:3jjkL6e8ix1Vdmz7QPapwk'],
#  ['Silent Night', 'spotify:track:2wtjFDWDJWbfPIGPzB5wfs'],
#  ['Inspire the Empathetic', 'spotify:track:3KCGP2lQiXZ80hA6Mhj5Np'],
#  ['I Love My Josephine', 'spotify:track:2dOTDBPIy4A4XgvI0hZ4vw'],
#  ['Sing To Be Safe', 'spotify:track:5CuhdQteVwUZdXtNn2CDvX'],
#  ['Fanfare to Prelude / Prelude / Marcia Romana', 'Not Found'],
#  ['I Want You A Cappella Vocal #', 'Not Found'],
#  ['Mouse Robot / Blasting Off', 'Not Found'],
#  ['Heroic Blues', 'spotify:track:7Me2AZMXoKJsRXt41p5RPI'],
#  ['Skip James Talking', 'spotify:track:3EuxF5BVuFgGmKuiR9KjMM'],
#  ['All the Way', 'spotify:track:6YQ6lbjUu8yRVgdPmvShjf'],
#  ['Once', 'spotify:track:1O0RXkVkGKJJdHFujXU5p1'],
# ...

# %%
# classical humorous not_dance 317
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 2:
        if alldata[i][26] == 13:
            if alldata[i][30] == 1:
                list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Don Giovanni, KV 527: Atto secondo, no. 14. Leporello! / Signore! (Don Giovanni, Leporello)',
#   'Not Found'],
#  ['Act 2 - Orsu, Signor Don Bartolo', 'spotify:track:2kvJtetNZ0s8ECQ9YKzLtR'],
#  ['Pierre the Pirate', 'spotify:track:0yf5fI7E2t7OiHAcSrMRmi'],
#  ['Wine, Wine, Wine', 'spotify:track:6iMzaXAzzS4lV1cpGFwC0i'],
#  ['Ready Teddy', 'spotify:track:5n4olF1R3x54LhUtfbf6P2'],
#  ['Abou Ben Adhem', 'Not Found'],
#  ['Tosca (2002 - Remaster), Act I: Tosca? Che non mi veda (Scarpia/Tosca/Sagrestano)',
#   'Not Found'],
#  ['Don Giovanni, KV 527: Atto primo, no. 9. Povera sventurata (Don Giovanni',
#   'Not Found'],
#  ['Cacio e Pepe', 'spotify:track:22pkeBtPAGjYdQiAZorMPN'],
#  ['Komm auf die Schaukel, Luise', 'spotify:track:0yotDGsXGbuxRmduU3ZEPv'],
#  ['Concerto for 3 Trumpets & Orchestra in B flat major: III. Allegro',
#   'spotify:track:0siegLIIaO7TyaEJdz2jew'],
#  ['Lovin Up a Storm', 'Not Found'],
#  ['Suicide Mission', 'Not Found'],
# ...

# %%
# classical agreesive slow not_dance 284
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 2:
        if alldata[i][26] == 14:
            if alldata[i][29] == 20:
                if alldata[i][30] == 1:
                    list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Trost im Unglück from Lieder aus Des Knaben Wunderhorn (2001 Digital Remaster)',
#   'Not Found'],
#  ['Sea of Tranquillity', 'spotify:track:352NbWbBNUrxl9iHIDDIgw'],
#  ['The Foxchase', 'Not Found'],
#  ['The Respect Chant', 'spotify:track:1w1TZS8VaGjuhgxckBg7Gx'],
#  ['Borboletta', 'spotify:track:2Xtt9opHE5gXdPtpeTeThN'],
#  ['Dew Upon Shapeless Bounds', 'Not Found'],
#  ['Djigui', 'Not Found'],
#  ['Marlene E Gli Ospii Misteriosi', 'Not Found'],
#  ['Francesca da Rimini, op. 32: Allegro vivo -',
#   'spotify:track:28A3cRapWyEvAI7Sfo4DlX'],
#  ['Intermission', 'spotify:track:0Up3p1fwJkzlzFtKCd5vPV'],
#  ['Prince Igor: Polovtsian dances', 'Not Found'],
#  ['Au revoir', 'Not Found'],
#  ['Last One (Last One)', 'spotify:track:31pJ9fpf16BTK3ILxAO50q'],
#  ['Virgo Splendens', 'spotify:track:6QV7dOmyWOOK68bKAIJPlM'],
#  ['Piano Sonata in B-flat major, D 960: I. Molto moderato',
#   'spotify:track:1QE4KBHZb0Y4ERG18VEm3y'],
# ...

# %%
# classical agreesive bright instrumental fast not_dance 468
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 2:
        if alldata[i][26] == 14:
            if alldata[i][27] == 15:
                if alldata[i][28] == 17:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Åsa', 'Not Found'],
#  ['String Quartet No. 6 In F Minor, Op. 80: I. Allegro Vivace Assai',
#   'spotify:track:6NDslOSpC8wIq61rSx7mGb'],
#  ['Mountains are Far Away', 'Not Found'],
#  ['String Quintet No. 2 in G major, Op. 111: IV. Vivace ma non troppo presto',
#   'Not Found'],
#  ['Warm Canto', 'spotify:track:31Rc1UZk40bZhp7upiTORM'],
#  ['Sonata No.7 in D major, Op. 10 No. 3: II. Largo e mesto', 'Not Found'],
#  ['Piano Trio in A minor, M. 67: 1. Modéré',
#   'spotify:track:155WNUC8hC3fov8iyO4NGY'],
#  ['The Gift: I. Echoes Of Primordial Time',
#   'spotify:track:6TohS3WMOc0xCdCdVodZiv'],
#  ['String Quartet no. 1 in F Major, op. 18/1: IV. Finale: Allegro',
#   'spotify:track:6chKkp79zeMfE95Oj2Ejyt'],
#  ['Blue Room (Ambient mix)', 'Not Found'],
#  ['Changeling', 'spotify:track:4TEdXKd9AKAclNPLLodIgM'],
#  ['Water Dances: Stroking / Synchronising', 'Not Found'],
#  ['Donna Diana - Overture', 'Not Found'],
#  ['Piano Sonata in D major, D 850: IV. Rondo. Allegro moderato',
# ...

# %%
# classical agreesive bright voice fast not_dance 128
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 2:
        if alldata[i][26] == 14:
            if alldata[i][27] == 15:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Drowned in My Own Tears', 'spotify:track:1fQoQUlcxTWCETuIOKW5ve'],
#  ['Putain de Temps', 'Not Found'],
#  ['Atto II - Scena 3 - In Mia Man Alfin Tu Sei', 'Not Found'],
#  ['Act 2 - Scene 2 - Esci, Fuggi, Il Furor Che Maccende', 'Not Found'],
#  ['La Cenerentola : Nacqui All Affanno...Non Pi? Mesta',
#   'spotify:track:2oPFVWnA0PCdV2Ks3OyxOa'],
#  ['Atto III - Scena 1 - La Gaia Canzone', 'Not Found'],
#  ['Det räcker nu', 'Not Found'],
#  ['Stabat Mater: 2. Cujus animam gementem',
#   'spotify:track:4YObHuF4vRGqq6n6CZEhoY'],
#  ['Closer To The Truth And Furthher From The Sky', 'Not Found'],
#  ['LInternmittente', 'Not Found'],
#  ['Boshaft ist die Vogelschar', 'spotify:track:5kVfEBmfyetribi8q8w92j'],
#  ['If I Were a Carpenter', 'spotify:track:07yhlDqS99totZZkdQEWBW'],
#  ['Is This Real Life', 'spotify:track:0lIoHITUFn1rRJZzi7Ja6B'],
#  ['Luna', 'Not Found'],
#  ['Je taime, moi non plus', 'Not Found'],
#  ['Q Quarters', 'spotify:track:21ntXIi1jgyzbRldYT3vj1'],
# ...

# %%
# classical agreesive dark instrumental fast not_dance 655
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 2:
        if alldata[i][26] == 14:
            if alldata[i][27] == 16:
                if alldata[i][28] == 17:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['All Time Chump', 'spotify:track:1XGxRm23zHutreSs9VnJoQ'],
#  ['Cello Concerto in E minor, Op. 85: I. Adagio-Moderato / II. Lento-allegro molto',
#   'Not Found'],
#  ['Pneuma, Part 3', 'spotify:track:0dNSFexCAvZR41TP8n2xEL'],
#  ['Fallen Leaves', 'spotify:track:3jUTjCISntIUFL8jnAjzgc'],
#  ['Membra Jesu Nostri, BuxWV 75: V. Ad Pectus Sicunt Modo Geniti',
#   'Not Found'],
#  ['Writing On Ice', 'spotify:track:2B32ctKUpYsdzCS3elJG5C'],
#  ['Revealing: The Celestial Crown Reflecting Rays of Sol & Shade',
#   'Not Found'],
#  ['Catfish Row (Suite from Porgy and Bess): I. Introduction - Act 1, Scene 1',
#   'Not Found'],
#  ['After Dark', 'spotify:track:5Iu03rDn9k5c4fV10nCDyS'],
#  ['Symphony no. 6 in B minor, op. 74 Pathétique: 4. Finale. Adagio lamentoso - Andante',
#   'spotify:track:3KcSvnVG1xUum3zSm6MipQ'],
#  ['Bark, Xylem (Unabridged)', 'spotify:track:2N4te32Qp8IQ8jkRj6uJze'],
#  ['Two', 'spotify:track:6pkJKzsuKwr04iClM2nVNF'],
# ...

# %%
# classical agreesive dark voice fast not_dance 133
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 2:
        if alldata[i][26] == 14:
            if alldata[i][27] == 16:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Rowing of the Galley Slaves', 'spotify:track:0NKDLJXP8ZXpaSBGZmhfsH'],
#  ['1967', 'spotify:track:6f2Uug6dzZLDhMAYbDy3ys'],
#  ['Text Message Tone: Stinger - Shield Regen', 'Not Found'],
#  ['Humaine', 'spotify:track:0Dp6AvE2STrmyOsmnYX4nz'],
#  ['She', 'spotify:track:25nCarIvhiAembDM78uamP'],
#  ['Mutterschaft', 'Not Found'],
#  ['Bear-Hug', 'Not Found'],
#  ['Himmelweg (Le chemin du ciel), Part 4', 'Not Found'],
#  ['M.S.', 'Not Found'],
#  ['This Is Halloween', 'Not Found'],
#  ['The Individual', 'spotify:track:2l43jtOZgyQfh3SiCacVpB'],
#  ['In the Lord I Take Refuge', 'spotify:track:1qKQNdHHsuZcOU7EXbHbCi'],
#  ['Intro', 'spotify:track:61IBpJ6TymrEwd7bz3oPNp'],
#  ['Lemminkäis-sarja, op. 22: IV. Lemminkäisen paluu', 'Not Found'],
#  ['Faccia a faccia (il ritorno di Beauregard)',
#   'spotify:track:6DZVjYP56Etk29s7lsrjuA'],
#  ['Im About to Faint Song', 'Not Found'],
#  ['The Dark Secret', 'spotify:track:0C8SSfZIRllA7yF8o9oq7x'],
#  ['Against All Odds (Intro)', 'Not Found'],
# ...

# %%
# classical danceable 266
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 2:
        if alldata[i][30] == 0:
            list1.append([alldata[i][0],alldata[i][24]])
list1

# %% [markdown]
# # Dance Playlists

# %%
# dance notdanceable 681 who wouldn't love that
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 3:
        if alldata[i][30] == 1:
            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['My Time', 'spotify:track:66YEk4Ub2v9w3P3IhgUAaj'],
#  ['Ever after', 'Not Found'],
#  ['Apple of My Eye', 'spotify:track:6JPCGPZTF6XDSGbSptqjnq'],
#  ['Always for You', 'spotify:track:7lk17pB9xBouaCTLeB6cYn'],
#  ['Exit (radio)', 'Not Found'],
#  ['Merry Christmas Baby', 'spotify:track:2bAicGteiwwAW7GbNJVYjo'],
#  ['MX-03.11', 'spotify:track:7hAtndS9ahDgqBh4CLPi4n'],
#  ['On the Run', 'spotify:track:4SGj0FIewTPN5ROOvHYOUM'],
#  ['Dance A Little Bit Closer (12- Mix)',
#   'spotify:track:3cwMDPUQ0Y8PQSg68HV2Fn'],
#  ['Are You With Me (Dimaro radio edit)',
#   'spotify:track:0VDneLyomi6GBZjwpArWiu'],
#  ['Hands Tied Eyes Closed', 'spotify:track:1eAjQObjoXfn5XLdj5gtMb'],
#  ['Grovzimmer march', 'Not Found'],
#  ['Ambiantz', 'spotify:track:6Swi1j5XQ7XcjlBnJC85bP'],
#  ['Thunder Bay', 'spotify:track:4pfWXSIUdlmwhFA3qeV276'],
#  ['7th Moon', 'spotify:track:6aflwWRHWzLqenCJsZneXz'],
#  ['Mountainside', 'spotify:track:7BgyYJ47zdwhpWOorViFfu'],
# ...

# %%
# dance slow danceable 325
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 3:
        if alldata[i][29] == 20:
            if alldata[i][30] == 0:
                list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Boss', 'spotify:track:6HYJveQPu2Wof9x8YccjmM'],
#  ['Border', 'spotify:track:6o1qgWB4DTTKf8Ffu7bJey'],
#  ['Bodies Hit the Floor', 'spotify:track:6581a5OtGdwGWlAVmZdVKv'],
#  ['Alien Species Zero', 'spotify:track:03CLDb1Frb4c1VqnwTooMd'],
#  ['For Her Light', 'spotify:track:2bdlaYYLaXJIguKSSS63Lz'],
#  ['Japanese Fantasy', 'spotify:track:1bDQW4l8pm1kBr016UniMP'],
#  ['Carpe Diem (feat. Turbulence)', 'Not Found'],
#  ['Numatic', 'spotify:track:5jbvNGlUYqkeRJWCy5RGRp'],
#  ['Priceless', 'spotify:track:3agqBidsb0aV8KYnseo0i4'],
#  ['4 the rest of your life', 'spotify:track:1soMikkhdD14tVmgvnWpRW'],
#  ['Mercy in You', 'spotify:track:3O62hTWKH1rZ8RlhUbdy59'],
#  ['Let the Party Begin (extended mix)',
#   'spotify:track:7lOIcCXsdiMIbe9ibrMSg2'],
#  ['Mamas Room', 'spotify:track:2MBXVgoj0mJDM27EK89Meq'],
#  ['Pressure Drop (Leon Switch & Kryptic Minds remix)', 'Not Found'],
#  ['Is Your Love Strong Enough?', 'spotify:track:7wp8SzRnbGExjwL3jfUgs0'],
#  ['We Are', 'Not Found'],
# ...

# %%
# dance not_aggressive instrumental fast danceable 115
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 3:
        if alldata[i][28] == 17:
            if alldata[i][29] == 19:
                if alldata[i][30] == 0:
                    if alldata[i][26] != 14:
                        list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# 115

# %%
# dance aggressive bright instrumental fast danceable 388
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 3:
        if alldata[i][26] == 14:
            if alldata[i][27] == 15:
                if alldata[i][28] == 17:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 0:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Disremembrance (full orchestral 12 mix)',
#   'spotify:track:3fZAclzzkh21nRzCSgZrr7'],
#  ['Careless Woman', 'spotify:track:7pQFpipPfINqiIW6j8ArLy'],
#  ['Carry Me (Nilson & The 8th Note remix)',
#   'spotify:track:2l5Y3ZiNghy3RZsOFW63Kl'],
#  ['Into This Universe', 'spotify:track:42fiZLDvmA5PcgZFBiltVJ'],
#  ['Moar Ghosts N Stuff', 'spotify:track:2lXzgU19U9cSZLJtawjob6'],
#  ['Are You Lulu', 'spotify:track:7bQ4m8BBfBVZglvpuOvQGF'],
#  ['Mon ami', 'spotify:track:29jkQVaXBKBiFPu9OhtGmw'],
#  ['Stupid Girl (Tees Radio Mix)', 'spotify:track:2xOocszGASJ3sASOZDkjIP'],
#  ['Beat in Love - Yasutaka Nakata (Capsule) (remix)',
#   'spotify:track:5ER7J1jTxgGQgXon3SCk8T'],
#  ['Ęg-gęd-ōsis', 'spotify:track:16QPJ9tsWeaFMRK6zXZte1'],
#  ['Kabangin All Night', 'spotify:track:0VzBFbxaoWy2rgUuZ6TAjk'],
#  ['Dancing Jodi', 'spotify:track:2YNgcIiD73XsXFNM3UuxlM'],
#  ['(Im) In Deep', 'Not Found'],
#  ['Steady Job (3AM Mix)', 'Not Found'],
# ...

# %%
# dance aggressive bright voice fast danceable 252
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 3:
        if alldata[i][26] == 14:
            if alldata[i][27] == 15:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 0:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Whos that Rave', 'spotify:track:6SHSa3ao4Dz1tfUXYJ4Abj'],
#  ['Let This Party Never End', 'spotify:track:0ObRC3dRhPZr3HRCkYf25O'],
#  ['Sweet Inspiration', 'spotify:track:53rYxgcywD6gcbslzsSWtb'],
#  ['Together', 'spotify:track:1f2ATrxK6Vy2bAyNaVId9Q'],
#  ['Worldwide', 'spotify:track:5Ebo6T4YqKlJZdqvp7vaeL'],
#  ['Mr. Lonely (Hex Hector / Mac Quayle main club mix / Widelife mix)',
#   'Not Found'],
#  ['Girls & Boys (Essex mix)', 'Not Found'],
#  ['Share it with Me', 'spotify:track:2BLRucShaRZRQ8tOu2ea6J'],
#  ['I Adore (Gammer remix)', 'spotify:track:1gfr08yPvi8S8k7TYYVgZR'],
#  ['Human (Ferry Corsten dub remix)', 'spotify:track:7Ac8FiGHewxqdU51GrmeGw'],
#  ['Just Around the Hill (Doug Laurent 12″ vocal mix)',
#   'spotify:track:0ybTiPVxkMBzP3HFDimiMO'],
#  ['Saideira', 'spotify:track:2BHfb1qBSA8IzsJUVQvFTZ'],
#  ['Spotlight (Johnny Vicious radio mix)',
#   'spotify:track:0kayabhToeO9PdJKYcxFXK'],
#  ['Everybody Gonfi-Gon (Its Cool Man remix)', 'Not Found'],
# ...

# %%
# dance aggressive dark instrumental fast danceable 667
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 3:
        if alldata[i][26] == 14:
            if alldata[i][27] == 16:
                if alldata[i][28] == 17:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 0:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Cafe Del Mar (Marco V remix)', 'spotify:track:6z91SyGlPsllxhnG2Aw0Fb'],
#  ['Isnt That So Nice (He Said)', 'Not Found'],
#  ['Space Cowboy', 'spotify:track:6GnM3oCmbYspisR3wdnBTF'],
#  ['Brook', 'spotify:track:14qa4IoBwAQeLLiaBobedR'],
#  ['Dont Look Back', 'Not Found'],
#  ['Casanova’s Last Words', 'Not Found'],
#  ['Burnin / Too Long', 'spotify:track:3Ons6C3wXBMi8nYpLBMlVe'],
#  ['Meer der Tränen (I Crossed the Line)', 'Not Found'],
#  ['Acid Drops', 'spotify:track:6ky98KwqJ9d9I1RnxQVi6e'],
#  ['Have You Seen My Baby (Baby Mix)', 'Not Found'],
#  ['Flash', 'spotify:track:3veLaWOLdX0SeRUyehfTzj'],
#  ['Weltunter (rerecorded)', 'Not Found'],
#  ['Act II: The Dark Forest', 'Not Found'],
#  ['Mainline', 'spotify:track:6qpfhlx1GqvEXMDdtotbt5'],
#  ['Chalet', 'spotify:track:7HuvmEYvlpVGwtIfd0vsnw'],
#  ['Time Shift', 'spotify:track:6uJDYK6RhsUEcuaEGqXKrh'],
#  ['The Take (Theme From Panic Room, Part 2)', 'Not Found'],
#  ['Dear God', 'spotify:track:0Z3KJmuZhmbec6LSqdPw1L'],
# ...

# %%
# dance aggressive dark voice fast danceable 536
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 3:
        if alldata[i][26] == 14:
            if alldata[i][27] == 16:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 0:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Vertigo (Hardgroove mix)', 'Not Found'],
#  ['We Got The Sound', 'spotify:track:3PCMaeOrc3On1DzFTSfrsL'],
#  ['Perturbante limbo', 'spotify:track:20vAj0Itm8UX4xiapIpCOh'],
#  ['Evening Star', 'spotify:track:3OZjqQX9zaquGvjSwwGT00'],
#  ['(I Dont Want to Go to) Chelsea', 'spotify:track:0mq1y8G1tgzDx33qKc8qTZ'],
#  ['False pretense', 'spotify:track:05DE65ocdEMQBHHH0T9CR4'],
#  ['Madder', 'spotify:track:5Wj2PSZ47OnjTPDsO5vJv5'],
#  ['I Get a Rush (Moogwai vs. Chab remix)', 'Not Found'],
#  ['Wer hat die Hitze', 'Not Found'],
#  ['Where I Am', 'Not Found'],
#  ['Dawn Patrol', 'spotify:track:4NwFxag85AYdCel47a3Yhi'],
#  ['Uja', 'spotify:track:7G0bCNHvrRH9myw1yxdfDw'],
#  ['Jusquen Haut feat. Omnikrom', 'Not Found'],
#  ['Super Sonic', 'Not Found'],
#  ['Track 2', 'spotify:track:57HzoP4L7JSjFljDtL3nwE'],
#  ['Gloria 2004 (S.A.D. club mix)', 'Not Found'],
#  ['Remember', 'spotify:track:0yrxMBhxXTdVwAnzuoc3rJ'],
#  ['Madness', 'Not Found'],
# ...

# %% [markdown]
# # Hip Hop Playlists

# %%
# HipHop passionate and cheerful 242
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 4:
        if alldata[i][26] == 10 or alldata[i][26] == 11:
            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['untitled', 'Not Found'],
#  ['Me Myself and I (Oblapos Instrumental)', 'Not Found'],
#  ['Temperature (feat. Talib Kweli)', 'Not Found'],
#  ['Dusk', 'spotify:track:6YkJdIETXkaSIpZ6kNB2iS'],
#  ['Attitude', 'spotify:track:1NgV5UtOsgXGYs3nYLTWRC'],
#  ['Fight The Power', 'spotify:track:1VciFCr3FuN1CJ8hr3rayF'],
#  ['untitled', 'Not Found'],
#  ['Komba', 'spotify:track:43TKGNbGBRZdMdHbWyZIfu'],
#  ['Don\\x92t Stop feat. Kurupt & Nas', 'Not Found'],
#  ['Bombastic Jazz Style (live version)', 'Not Found'],
#  ['Killing the Man in the Mirror', 'spotify:track:6N8OL0uXbIihnDQ5W9GutN'],
#  ['The Gorgon Is Back', 'spotify:track:5aUMzYfdpKvtgH03xsG6Oc'],
#  ['The Picture Was You', 'spotify:track:5vjifdLHEIpHHmXpZE3538'],
#  ['Shadows', 'spotify:track:1B8bAR6epIdoPptPG2B8s4'],
#  ['Y Cho', 'spotify:track:1GCCVnmjp4Ns8yVy90ECRE'],
#  ['4. Linjustice', 'Not Found'],
#  ['Maladie', 'spotify:track:1iadLp9dk2MaeAS49GA2DH'],
#  ['Photoshop® Sucks', 'spotify:track:4yIZ9LHZR0fy6QHhprhnFN'],
# ...

# %%
# HipHop bittersweet 226
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 4:
        if alldata[i][26] == 12:
            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['We No Speak Americano (original)', 'spotify:track:4PYw4uaV1tynJspfHRm6lm'],
#  ['À chaque jour suffit sa peine', 'spotify:track:3Rf1L0UWxTHp4Vr5jGLGQS'],
#  ['ImmO im Ohr', 'spotify:track:6cjtxbR51WPZKJ058C6TNI'],
#  ['The Hidden Cage', 'spotify:track:2sSx8w4BthBsRTgecrMPGq'],
#  ['What Yall Came to Do', 'spotify:track:6m1T3YQbUGutuKabuEGvmO'],
#  ['Why?_(Just_One_Of_Those_Things', 'Not Found'],
#  ['Music I Like', 'spotify:track:14OVdH7D9tABxpbIn2oYVu'],
#  ['Ishmael Tongue', 'spotify:track:3ZK38L1ckZnzko7xIJxQpo'],
#  ['Something', 'spotify:track:6GNM7asYK1XgrQBzwsdFJ4'],
#  ['Southafternoon', 'spotify:track:1gQVF4qSyZu1H1nljYx0QE'],
#  ['Ill Be Waiting', 'spotify:track:3ikV7OqGaAW3lqmGsbOWPV'],
#  ['Adrian Borland - The Last Days Of The Rain Machine - 11 - Hallucinating You',
#   'Not Found'],
#  ['Me Killa', 'spotify:track:6R3W9g8yTPhQI7bwKC43Mh'],
#  ['Shes Dead', 'spotify:track:1AsU3J103jUFNZXD3dPCVN'],
#  ['Charles Barkley', 'spotify:track:5gQzRoLYnu0OddUyzYiNvR'],
# ...

# %%
# HipHop humorous 167
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 4:
        if alldata[i][26] == 13:
            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Hasskappe', 'spotify:track:0CW9kqqJ9bmwc7AvWt9ecO'],
#  ['Down The Drain', 'spotify:track:37wU4yrzOyto1Py4yFSF7H'],
#  ['Aint a Thang Wrong', 'spotify:track:7sfQr8Cqfdlgi7Lga6ynKe'],
#  ['Chicos Groove (mix 2)', 'spotify:track:2ishPGXL52EoEhX8mJBl1O'],
#  ['Caught Up', 'spotify:track:5zdUc1JRCImBYcDWgvFNpE'],
#  ['The Urban Theme', 'spotify:track:21xVx0n3qonzK2PXah9M1S'],
#  ['Summer of Love (radio edit)', 'spotify:track:1bmnlM7k7q1E8kO4SSrZBn'],
#  ['Non-Fiction Intro', 'spotify:track:5wTEH8k3GRiBdgoxZQ0dSy'],
#  ['Positive Contact (Mario C remix)', 'spotify:track:6WZp9rcZVL7KjAvVWuFy7G'],
#  ['Hot Stuff', 'spotify:track:5FPdQbKa7rMmdNq9z7WA2h'],
#  ['Music Monks (The See(e)dy Monks)', 'spotify:track:1zk3YNnpetT3ob5NhVGYO9'],
#  ['Fat Sack', 'spotify:track:72VQOpDUa1NN8kJvPq6RR1'],
#  ['Burnin (feat. Royce Da 5’9″, Kid Vishis & Crooked I)', 'Not Found'],
#  ['Computer', 'spotify:track:7K8VZAvRKcK4CmeGlpBOkN'],
#  ['Gumshoe', 'spotify:track:7288GdnFtIWDrYNTOuQu88'],
# ...

# %%
# HipHop aggressive bright instrumental fast 202
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 4:
        if alldata[i][26] == 14:
            if alldata[i][27] == 15:
                if alldata[i][28] == 17:
                    if alldata[i][29] == 19:
                        list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Carnival', 'spotify:track:0q8IdxsWWgpaLAfpEWkeVS'],
#  ['Ehtaa tavaraa', 'spotify:track:7L8PjpJLUE6UIAzrnyRYvg'],
#  ['Geoffrey Boycott', 'spotify:track:0BMV4n4pXHJCOrhh2PRfi4'],
#  ['Avalon', 'spotify:track:7IBr9r9Ae3GLQ9kUgkLxXZ'],
#  ['Nosferatu (Original Version)', 'Not Found'],
#  ['Cattle Herders Chant', 'spotify:track:5xEhco1GsRtpjE5xGssBnK'],
#  ['Die Lunge brennt ab', 'Not Found'],
#  ['Rat (12 Inch Mix Feat. Fathead)', 'Not Found'],
#  ['untitled / Primer', 'Not Found'],
#  ['Everybody', 'spotify:track:4sFGkok98Cu0gu52fD48Xr'],
#  ['Disc ONostalgia', 'spotify:track:2XrRtzKe9wakBD2KIUBWD1'],
#  ['Sphinx', 'spotify:track:63XLU1S91DXtwrcAoPP5Nm'],
#  ['Uptown Festival: Medley', 'spotify:track:4KeF5XqBJ6Kb8rHUS91YNz'],
#  ['The Heathen', 'spotify:track:3GlaUbcv4UvNR6bFLzAZJe'],
#  ['08 - PLUS  DEVICE - My, To Make You Feel', 'Not Found'],
#  ['Lost in Space (Lionrock Galactic Boogie mix)', 'Not Found'],
#  ['Da Capo (Space Tubemix)', 'spotify:track:5tAgCzdUMLtsWS3LjIkqPo'],
# ...

# %%
# HipHop aggressive bright voice fast 160
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 4:
        if alldata[i][26] == 14:
            if alldata[i][27] == 15:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 19:
                        list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Don Juan (demo version)', 'spotify:track:41yBoV9VlHmWNOFcazZr5t'],
#  ['Jumpin(g)', 'spotify:track:1Gh7dg4anNWYgpnCwlo5s1'],
#  ['Lonely Weekends', 'Not Found'],
#  ['Peace Sign', 'spotify:track:5tOnvJkZeTv3ClEh6RaDiB'],
#  ['Look Sharp!', 'spotify:track:1PXshYSkA3gGYOrInU3lRE'],
#  ['Real New York (feat. I Am Many)', 'Not Found'],
#  ['Peaches III', 'spotify:track:27b9yjS1Zam4YaA3xziFzi'],
#  ['Sugar Town', 'spotify:track:0vT1Q3qFCQgJcyLsFuK60O'],
#  ['Hmm Hmm Hmm', 'spotify:track:7HVWUK42Hugz0XDLuv9J0v'],
#  ['U.4.2.P.1. Club Dub', 'Not Found'],
#  ['Walking on Thin Ice', 'Not Found'],
#  ['Take It as a Warning', 'spotify:track:4N0InqUqjzpuaPpJzBFGqe'],
#  ['03 - Arada Bir', 'Not Found'],
#  ['Walk on Water', 'spotify:track:6Z0gQnjYAiHchXqzkiUR5a'],
#  ['Waiting for a Miracle', 'Not Found'],
#  ['Sample Me. 4', 'spotify:track:0hN7mH1bQO536JN9QZ16jT'],
#  ['Gamble (Live)', 'Not Found'],
#  ['Collision', 'spotify:track:57tbcYkfgqlblj794aLyd7'],
# ...

# %%
# HipHop aggressive bright instrumental slow 106
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 4:
        if alldata[i][26] == 14:
            if alldata[i][27] == 15:
                if alldata[i][28] == 17:
                    if alldata[i][29] == 20:
                        list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Ajat on kovat', 'Not Found'],
#  ['9 to 5', 'spotify:track:75CvLXm77tXvaOL7MOmu0g'],
#  ['Die Gedanken Sind Frei (Thoughts Are Free)',
#   'spotify:track:0z9eRMy7WzuqOSEdENs2WV'],
#  ['Eye of a Needle (remixed by Lemon D)', 'Not Found'],
#  ['Guitar King', 'spotify:track:1O8SPR1JUq7V8W3QP3OZUN'],
#  ['Mighty Hard Rocker', 'spotify:track:0Qu19O5u37F9UKIu8eTG0z'],
#  ['Divine Design', 'spotify:track:1FcMV4PXXCVOTNMCd0HO1R'],
#  ['All Along the Watchtower', 'spotify:track:0YdvOi1wtAInrJe2cWiPMv'],
#  ['Its Nothing (feat. AG & Gab Goblin)', 'Not Found'],
#  ['Hillside Stomp', 'spotify:track:3WK9A42OdXyMPhGQnIIHpK'],
#  ['Leave It Up to the Cut Professor', 'Not Found'],
#  ['Play This Only at Night', 'Not Found'],
#  ['This Life (Boymerang mix)', 'Not Found'],
#  ['Guaracha U.F.O. (Version Rebajada)',
#   'spotify:track:76V3yxAkGfpSBGjLAz62Cw'],
#  ['I Don’t Play', 'spotify:track:0fcHgMmwEclq6liArDogML'],
#  ['Heart Set', 'Not Found'],
# ...

# %%
# HipHop aggressive bright voice slow 178
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 4:
        if alldata[i][26] == 14:
            if alldata[i][27] == 15:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 20:
                        list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Every Step Of The Way', 'spotify:track:3Ai3mBumP1cW9dYbzjORcA'],
#  ['Soundtrack to the Streets', 'spotify:track:7hw1PtPZdfNJNRiimFjtuO'],
#  ['Me & My Friends (Apathy remix)', 'spotify:track:2J2m8b1FhIA25U4IpxsDQC'],
#  ['Une journée sans fin', 'spotify:track:0cx3QY1gLJmnNse0zWEmlv'],
#  ['Lucifer', 'spotify:track:05VHidqx1tV6V7MsCdAIby'],
#  ['Heat', 'spotify:track:51pRtHNRROwHcqrhYrwPaO'],
#  ['Andy (english version)', 'Not Found'],
#  ['Neva Stop', 'spotify:track:2QPgNp1tqAJGUNcKMsawmZ'],
#  ['Rock It to the Moon', 'Not Found'],
#  ['Table découte', 'spotify:track:06ej6ai9EeCwTh8Abi6FDV'],
#  ['Sun Large Promo', 'Not Found'],
#  ['Special Efx (feat. Godfather Don)', 'Not Found'],
#  ['Fractal XI', 'Not Found'],
#  ['Still Move Work', 'Not Found'],
#  ['Was geht', 'spotify:track:2AhdS52IBINqnz06LPWfke'],
#  ['Ridå', 'spotify:track:5capmjPrQxHgYLwryjTuVd'],
#  ['Kill.I.Am', 'spotify:track:14Fl1O3WtGdIP9awvVY1nG'],
#  ['Marginal Tietê', 'spotify:track:3RsgtkVR9UefxNu8W20rBC'],
# ...

# %%
# HipHop aggressive dark instrumental fast danceable 392
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 4:
        if alldata[i][26] == 14:
            if alldata[i][27] == 16:
                if alldata[i][28] == 17:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 0:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Real Estate', 'spotify:track:3ul8eqBFpmtiDt2CR2Xac0'],
#  ['Ellie Lou', 'spotify:track:0JBPzw7WBeRFcEcBVCYqVc'],
#  ['Takka Takka', 'Not Found'],
#  ['Season No. 5 (Forest Fire dub)', 'Not Found'],
#  ['Novelty Waves v.1', 'spotify:track:40k4QPqBEBoDLOWpzbDj33'],
#  ['History In the Making / Never Too Late', 'Not Found'],
#  ['Freeze', 'spotify:track:0jDlvW4pA1iKCKOzg1TXOC'],
#  ['Quartz#1', 'spotify:track:3HaNARbb0UTtZN9PLDH02W'],
#  ['Aquatic Bata Particles', 'spotify:track:3v7Kd2QFu1dPboRb8BGYeO'],
#  ['Diseases', 'spotify:track:6v8ptSgfj5ouKKWsj2mug5'],
#  ['Aqua', 'spotify:track:4Hi25tacHBady0t7vcTp9R'],
#  ['Jaded Kisses', 'Not Found'],
#  ['Fstup', 'Not Found'],
#  ['House Nation', 'spotify:track:5V38g1CC8aUpnapCYIfL4A'],
#  ['Chandra', 'spotify:track:3Uj9EdAU6RQOYNxMl0Vgfo'],
#  ['Bitte Spitte Toi Lab (Banger Musik Remix)', 'Not Found'],
#  ['Popularity', 'spotify:track:4ezIzKB3OHFAkmTUpffAT8'],
#  ['lArbre de vie', 'spotify:track:4hXjtmnQyiWwcCFAuopy31'],
# ...

# %%
# HipHop aggressive dark instrumental fast not_danceable 831
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 4:
        if alldata[i][26] == 14:
            if alldata[i][27] == 16:
                if alldata[i][28] == 17:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Scienceless', 'spotify:track:1yS61zD1k218Z3I4VL14a5'],
#  ['Sunday in Sevastopol', 'Not Found'],
#  ['Erneuerung', 'spotify:track:4Urv5Ru2WEn09bhgkaDLh8'],
#  ['SPEEDDIALER', 'spotify:track:4ZsyF1Jx0VpMHu5xLPkj4S'],
#  ['Autumn Leaves', 'spotify:track:3o3JMNDVfZr4tnLUcLyL4J'],
#  ['I and I Survive', 'spotify:track:4tMlyDh4A8cttW6jFBTRmv'],
#  ['Saviour', 'spotify:track:5ofjb7z2YooGmNL3EKG4B4'],
#  ['My Life (feat. Cee Lo Green)', 'Not Found'],
#  ['Filibuster X', 'spotify:track:0eZqf4CvTmDHqFaiSa3At6'],
#  ['Trick With a Knife', 'spotify:track:3o8jc0V09QYKnuiERNuqxZ'],
#  ['Live & Direct', 'spotify:track:4AjmYJ2KOyqfowihvXisNX'],
#  ['Hey You', 'spotify:track:0DS1IWkB1lNdHD7Ihuz9VT'],
#  ['Trixies Good Side', 'Not Found'],
#  ['Rykketid', 'spotify:track:14Rw41CigHI1VEkElmvB4N'],
#  ['Bad Sector', 'Not Found'],
#  ['Velvet Darkness They Fear', 'spotify:track:1EcfYVTjyQ1aRaLyTn8uJw'],
#  ['The Girl With the Fairytail Dream', 'Not Found'],
# ...

# %%
# HipHop aggressive dark instrumental slow danceable 251
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 4:
        if alldata[i][26] == 14:
            if alldata[i][27] == 16:
                if alldata[i][28] == 17:
                    if alldata[i][29] == 20:
                        if alldata[i][30] == 0:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Take It Slow', 'spotify:track:4OwrxnjxPK7IiiiW1nl4ig'],
#  ['Intro', 'spotify:track:6EBNDe7okfEut5WMf9tTIq'],
#  ['Lucky and Unhappy', 'spotify:track:3KtCDKfQyDOYpedX16GPpL'],
#  ['Lost in Dub (Los Kalakos dub remix)',
#   'spotify:track:37hgYazLy5MmAgtKt27V4c'],
#  ['Jagga', 'Not Found'],
#  ['Deep Down', 'spotify:track:36fEa2IHjS7bETiDbrw9bh'],
#  ['For Doz That Slept', 'spotify:track:4RLDbbujDgBT8k44SESmnE'],
#  ['Let the Girls Out', 'spotify:track:1ceCqjXSnkZGjjhlpSdCqS'],
#  ['Burnt Pride', 'spotify:track:3iu5hePHmVngzMcO3uByFB'],
#  ['Rock Wit U', 'spotify:track:0uwbsSXsexqcHxsuohgrzk'],
#  ['Slowfast Matrix', 'spotify:track:5P9Ns3RZLQrgdFjJrLa8ha'],
#  ['Rising Sand', 'Not Found'],
#  ['Night on a Bare Mountain', 'spotify:track:5owKnrmtYMRQo7njY9AvdW'],
#  ['Psycho Circle Game', 'Not Found'],
#  ['Żaden z nich', 'spotify:track:5pQwdv2ILLmZB2PUD0ZFCS'],
#  ['God vs. Devil', 'spotify:track:2fwa0rXvaykU8JtW1Dvxpf'],
#  ['Go See the Doctor 2k7 (feat. Twone Gabz)',
# ...

# %%
# HipHop aggressive dark instrumental slow not_danceable 728
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 4:
        if alldata[i][26] == 14:
            if alldata[i][27] == 16:
                if alldata[i][28] == 17:
                    if alldata[i][29] == 20:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['887 (Structure)', 'spotify:track:4cH7eEIVUCfG6pLjm1WeYw'],
#  ['Stand Up', 'spotify:track:3yoZpOB5ro75ENWjl5F2z7'],
#  ['The Best Thing for You', 'spotify:track:2jHpis70QAtKH3rtSvtSEu'],
#  ['Scratch (interlude)', 'Not Found'],
#  ['I Aint Mad at All', 'spotify:track:1XmMJFu1UBHhKvvi1z6D8u'],
#  ['Jocelyne', 'spotify:track:2VkSVOLBbQk9wTDAAhosAn'],
#  ['Spacecowboy vs. Bobble Head', 'spotify:track:1yEUaCau5F0jOOBIscrqXZ'],
#  ['Tres Leches (Triboro Trilogy) (feat. Prodigy & Inspectah Deck)',
#   'Not Found'],
#  ['Rock Bottom Again', 'spotify:track:5DDD2JEUHAKIShMK9yKs2A'],
#  ['All in Mind', 'spotify:track:29tmEbbU3bDNwfqjUlaoBo'],
#  ['Wonder Why', 'spotify:track:5uph2lCx269yyOgB4e9pmV'],
#  ['Gasolina', 'spotify:track:3gKLgDHWRojohIX0090G8j'],
#  ['Hilikus', 'spotify:track:76f8pLUFhqiv9AzweVBR1O'],
#  ['1er Janvier 2010', 'spotify:track:77gbZw7pVDs4nzUB7vUQze'],
#  ['905', 'spotify:track:1OUhfm8VXT7jvDPjH7P6Sx'],
#  ['Miss America', 'spotify:track:05Z7P0sjCNkFXM5XIgIiaW'],
# ...

# %%
# HipHop aggressive dark voice fast danceable 316
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 4:
        if alldata[i][26] == 14:
            if alldata[i][27] == 16:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 0:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['I Pull My Gun Once', 'Not Found'],
#  ['Hot Ones (O.Gz Madness) (feat. O.Gz)', 'Not Found'],
#  ['Parli Con Me?!', 'spotify:track:7c1WIAjdl74pHfwgsLLTgt'],
#  ['Merde In France (Cacapoum)', 'spotify:track:0FLWZ1f9yQJTuYwCJbLy8S'],
#  ['Funny', 'spotify:track:4BzQGofRpTVV8VWZHoTL3L'],
#  ['Changuito', 'spotify:track:40B8yTSjj16lsu0D4glD3u'],
#  ['Love etc. (Kurd Maverick dub)', 'spotify:track:13usoXIs5e2tWU8J92nIel'],
#  ['Technique', 'spotify:track:48ZUwXrEOhaXLCxvmRYhZv'],
#  ['Between', 'spotify:track:3PMoHdsG7P6Azl6fiUu505'],
#  ['Sloh Beat', 'Not Found'],
#  ['Remmidemmi (Yippie Yippie Yeah) (Egoexpress remix D)', 'Not Found'],
#  ['Drinking Air', 'Not Found'],
#  ['Liquor, Niggas & Triggas', 'Not Found'],
#  ['Cross My Heart and Hope to Die', 'spotify:track:5IFS5ISgnw82MrRkeQjLR9'],
#  ['Waiting for My Man', 'spotify:track:0KZtz8irOz07u2TbfxGy16'],
#  ['Long Cut', 'Not Found'],
#  ['I Want It All (Roland M. Dill remix)',
#   'spotify:track:6YPceN8XCrTAQuWZaBWd5G'],
# ...

# %%
# HipHop aggressive dark voice fast not_danceable 87
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 4:
        if alldata[i][26] == 14:
            if alldata[i][27] == 16:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Sexy Graveyard', 'spotify:track:56WkTg1xBI92tmwMoHqLnG'],
#  ['Restaurant Shootout', 'spotify:track:6AE1UJOekITXhhvZr08Sm0'],
#  ['Paardeberg', 'Not Found'],
#  ['Even More Songs', 'spotify:track:2kDHjX4GmViJUB1a25IO1L'],
#  ['Its Not What You Do', 'spotify:track:43QJxFNYD83leUAqteDoR3'],
#  ['Funeral', 'Not Found'],
#  ['Methodology', 'spotify:track:0oN8LdtctVwvvNUZ5dUNfq'],
#  ['13.Sodom und Gomorrha', 'Not Found'],
#  ['Un monde fabuleux', 'spotify:track:7leAGMZ9fkYhJI5IWQUBKt'],
#  ['Greenhouse (Night)', 'spotify:track:2k4aO9CpJASAcJtCS6xo7g'],
#  ['Intro', 'spotify:track:1AIWVUTXnneLwBWprbUArr'],
#  ['You Must Be Wicked Underground If You Own This',
#   'spotify:track:0UNwbqE5fIb1Hp61jd3qp9'],
#  ['Drool', 'Not Found'],
#  ['Mancuerda', 'Not Found'],
#  ['Condemned to Rock n Roll', 'spotify:track:5LcmBByAdVu4TvHkpxuN5I'],
#  ['Crazy Dreams And High Ideals', 'spotify:track:7CDD3p8W3han9bl6b6YpGn'],
#  ['Moustik', 'spotify:track:7pc8tJiy5oNXB1mFrkg73d'],
# ...

# %%
# HipHop aggressive dark voice slow danceable 353
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 4:
        if alldata[i][26] == 14:
            if alldata[i][27] == 16:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 20:
                        if alldata[i][30] == 0:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Le Cours de lhistoire (DJ Lethal mix)', 'Not Found'],
#  ['Accidents Don’t Happen', 'spotify:track:2Hw0MCTZo5I2o1xHcQ8oQQ'],
#  ['Take It Back (Feat. Rakaa Iriscience & Roc Marciano)', 'Not Found'],
#  ['Taschen voller Sonnenschein', 'Not Found'],
#  ['Shout (Strikes Grey Elephants from Denmark)', 'Not Found'],
#  ['숲', 'Not Found'],
#  ['The Don The Dutch', 'spotify:track:5BxzwUqufcCRv2iVLGpnD7'],
#  ['Six o Clock', 'spotify:track:4BeOdxoXFCgtYTUYFLR3Jq'],
#  ['Manager (Feat. Lloyd)', 'spotify:track:7qBT83cQ3HgjjJywUIhXBI'],
#  ['Rn2-09, Parts 1 & 2', 'Not Found'],
#  ['Mic Check', 'spotify:track:6q3ch0if9c5SPxxCuSuDLm'],
#  ['Decisions', 'spotify:track:00aGE7srKFGiRoMXeg4wDt'],
#  ['Peanut Butta Ups (Prod. By DJ Marmaduke)', 'Not Found'],
#  ['Do What I Gotta Do (feat. Tyga)', 'Not Found'],
#  ['Eh', 'spotify:track:5pNYiMbnXm7UkewX2KhmyK'],
#  ['Freestyle Rhyme', 'Not Found'],
#  ['Fu-Gee-La (Sly & Robbie mix)', 'spotify:track:6kQ0p90x2OgwandZiLyR6I'],
# ...

# %%
# HipHop aggressive dark voice slow not_danceable 57
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 4:
        if alldata[i][26] == 14:
            if alldata[i][27] == 16:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 20:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Picking the Feathers', 'spotify:track:2ogc1MInrSJSAfcqxUode8'],
#  ['Gully Slang', 'spotify:track:54dZIGrOzci3fdxSYt9Cby'],
#  ['Allah', 'spotify:track:4NCRRvCQxBtYc0s7MHlQSn'],
#  ['If They Only Knew', 'spotify:track:5fl2oE7A8F6mSmB4oOy6Bq'],
#  ['God Knows', 'Not Found'],
#  ['Les Binks Hairstyle', 'spotify:track:1H8XM84INUWZHM86IM2TSK'],
#  ['Ich habe keinen Körper', 'Not Found'],
#  ['Creep City (feat. Sheek Louch)', 'spotify:track:4IbWhUKcREvxJVrZAssUqU'],
#  ['Interlude', 'spotify:track:3AY37jdthqdttK6trftHzl'],
#  ['The Gift', 'spotify:track:7nviB40euH8GciNuOn7uci'],
#  ['delirium rag', 'Not Found'],
#  ['Smurf', 'spotify:track:2ek5UrBZNS5nBYolOp3GvT'],
#  ['Puhallettu 25 sec.', 'Not Found'],
#  ['Mary Anne', 'spotify:track:1TD9RGS3hEJECkfWLyNHWU'],
#  ['Drifting Black Umbrellas', 'Not Found'],
#  ['Easy To Fly (Featuring Carlitta Durand) (Produced By 9th Wonder)',
#   'Not Found'],
#  ['P.S.K. “What Does It Mean”?', 'spotify:track:3StKzbpR9dRZB8epDx4KDW'],
# ...

# %% [markdown]
# # Jazz Playlists

# %%
# Jazz passionate and humurous 189
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 5:
        if alldata[i][26] == 10 or alldata[i][26] == 13:
            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Childrens Song #5', 'spotify:track:6DtiLMgpjofXbXPcIuisio'],
#  ['Her Love Rubbed Off (home recording)', 'Not Found'],
#  ['Oh Bess, Oh Wheres My Bess (take 3)',
#   'spotify:track:5l4lRXGIM41MfwvkpecrkL'],
#  ['San Francisco River', 'spotify:track:3LwVYznvoRAG4JYbmUjJKf'],
#  ['Hot House', 'spotify:track:3FDcju4FoQf3IJMRifStsZ'],
#  ['I Got a Woman', 'spotify:track:1sZ0lnEiJ6w57Ntme1r8AF'],
#  ['Iris', 'spotify:track:4NiKtErEz8AzMHw6XzXhbm'],
#  ['Is My Baby Mad at Me (without horns)', 'Not Found'],
#  ['My Headphones Are Deadtones', 'spotify:track:5dj0QbKlQM73JpjS1UtXoR'],
#  ['Two Cents Worth', 'spotify:track:0BO9TfkqN6LnbySI8P4xAi'],
#  ['Excuse Me', 'spotify:track:2oZOvEmF6Uym6c9xbvixHN'],
#  ['Cook It Up', 'spotify:track:3XdtfkqsjOEFwT1peCV8b9'],
#  ['Exit B', 'spotify:track:2yX0PSLDnfaWAYC80Yi5LG'],
#  ['Eddie, Are You Kidding?', 'spotify:track:2Hb6PkgsYwmKIngKsxA8JN'],
#  ['The Rockers Anthem', 'spotify:track:5YBrWjCax6uo00ImZ3eg52'],
# ...

# %%
# Jazz cheerful danceable 102
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 5:
        if alldata[i][26] == 11:
            if alldata[i][30] == 0:
                list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['The World Is Waiting for the Sunrise',
#   'spotify:track:42r4kvwQOmJE7sRCU1Hq3Y'],
#  ['Idän ja lännen tiet', 'Not Found'],
#  ['Ven Devorame Otra Vez', 'spotify:track:4Y4KEbWgFM2zqkGRNMPqpM'],
#  ['Rad der verandering', 'spotify:track:3qCRoAeGCfAvFHib5A4Lzm'],
#  ['Rockin Jerry Lee (Mono)', 'Not Found'],
#  ['01-MUI3IRA DE MALPICA', 'Not Found'],
#  ['Canção da tarde', 'Not Found'],
#  ['Till There Was You', 'Not Found'],
#  ['Blues for Janet', 'spotify:track:5cxtJfowsLMPSJM4fndVS6'],
#  ['Tijuana Taxi', 'spotify:track:2vLgPIAJj1Z7fd69QoFxqK'],
#  ['Medley - Swing Low Sweet Chariot, the Lonesome Road', 'Not Found'],
#  ['When the Mist Comes Again', 'spotify:track:3OFdFgZD1bksPQzL33b1qC'],
#  ['Malka on the Beach', 'spotify:track:1nscxBv8goKRvhW1zB74XI'],
#  ['02. Biblioth¨¨que I', 'Not Found'],
#  ['Mister Main', 'spotify:track:23y0IUk2U8tPendcKMevG7'],
#  ['Exodus', 'spotify:track:3YIhRHjC10JuKt8jiBS5zL'],
#  ['The Vatican Method', 'spotify:track:4OGyOyHjTxjx0nczmGsokr'],
# ...

# %%
# Jazz cheerful slow not_danceable 265
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 5:
        if alldata[i][26] == 11:
             if alldata[i][29] == 20:
                if alldata[i][30] == 1:
                    list1.append([alldata[i][0],alldata[i][24]])
list1

# %%
# Jazz cheerful dark fast not_danceable 136
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 5:
        if alldata[i][26] == 11:
            if alldata[i][27] == 16:
                if alldata[i][29] == 19:
                    if alldata[i][30] == 1:
                         list1.append([alldata[i][0],alldata[i][24]])
list1

# %%
# Jazz cheerful bright instrumental fast not_danceable 103
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 5:
        if alldata[i][26] == 11:
            if alldata[i][27] == 15:
                if alldata[i][28] == 17:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Striking Similarities', 'spotify:track:1A5WaZ7bgr9CRRPSExpsxB'],
#  ['Little Willie Leaps', 'spotify:track:0E1s6gVI38CVCUMEyQnpQF'],
#  ['Chets Chat', 'spotify:track:4xTwqiSUeFq63Ps5GoxECb'],
#  ['Blue Skies', 'spotify:track:5cdBPBfYeRFDZWHAk4UPOH'],
#  ['I know that you know', 'spotify:track:5dtlrgq1YuN8KTkqnXrD2E'],
#  ['My Romance', 'spotify:track:4xDw9mf1vRsIWv7Cb45vNv'],
#  ['Capitaine Fracasse', 'spotify:track:79kNxjPOysbFZABJVo3eJG'],
#  ['Old Bush / Expect the Unexpected', 'spotify:track:0d2IX0w9jD2NeC8mCarGAW'],
#  ['Close to You', 'spotify:track:3Ev4e7X9K3O88vJqsclJDb'],
#  ['Something for Rosa', 'Not Found'],
#  ['Yesterdays', 'spotify:track:43WXOe9fGwnIZJuJt2Dhzb'],
#  ['Did You Hear Me Mommy?', 'spotify:track:0Rp6MkkRRZDeRbEl2eE9hA'],
#  ['There Is Nothing I Can Do', 'spotify:track:19g7rdVgVgC5q3x5XYj6Wk'],
#  ['I Could Write a Book', 'spotify:track:4fTV2tXbeAeTaIfFIDoF4H'],
#  ['In the Grip of Stronger Stuff', 'spotify:track:7mxHGV6IWLtEDkDq6VD928'],
# ...

# %%
# Jazz cheerful bright voice fast not_danceable 132
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 5:
        if alldata[i][26] == 11:
            if alldata[i][27] == 15:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Cry Me A River- Live Acoustic Theatre Version', 'Not Found'],
#  ['Ai Que Saudade DOcê', 'spotify:track:5i2h4dcCVTRoMQ35LcEJ3Y'],
#  ['Elli', 'Not Found'],
#  ['03 Akeboshi - Éñ\\x98\\x94¤ÎÉà´ò¤Á', 'Not Found'],
#  ['Ladys Reward', 'spotify:track:7jaEsHl2192t9ChSoL5lI0'],
#  ['For Her Eyes', 'spotify:track:3TlJ1uRP77gRg9HST6NwC7'],
#  ['Honeysuckle Rose', 'spotify:track:4LIw2QRvZWvtV48O92yfKu'],
#  ['Ghost Writer', 'Not Found'],
#  ['Get Rhythm', 'spotify:track:1xKEI3TDR1NjJSgAlC384x'],
#  ['Dúlaman', 'spotify:track:6s4tmVUNIhCFzwdikt4l5m'],
#  ['Blue Prelude', 'spotify:track:6RiiG9c8fgU7n3Ih40tT3e'],
#  ['Moonshiner', 'spotify:track:0TswKil0hHgV900ic3qZHl'],
#  ['If You Want Me to Love You I Will', 'spotify:track:1RIgwQ2cTjSNUj4og4Z4gl'],
#  ['Fly Me to the Moon', 'spotify:track:5b7OgznPJJr1vHNYGyvxau'],
#  ['Engepuu', 'Not Found'],
#  ['Fire Leap', 'spotify:track:2KJL5h7d1USDGvK4nvBIvw'],
#  ['The Lane - Five Childrens Songs, op. 89: 1. Doctor Beetle', 'Not Found'],
# ...

# %%
# Jazz bittersweet danceable 136
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 5:
        if alldata[i][26] == 12:
            if alldata[i][30] == 0:
                list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Die Kunst Der Fuge, BWV 1080 No. 6: Contrapunctus 6 A 4 In Stylo Francese',
#   'spotify:track:1WwWrw2YJjwObHSXzlHybj'],
#  ['When God Created The Coffebreak', 'spotify:track:2hOzPs6jooBT7LYup1QSBP'],
#  ['Windy', 'spotify:track:3rMxsoHiWqRLHruuPuzjGM'],
#  ['District Six', 'spotify:track:2QXRM1EdhaJfAwoncOBkIF'],
#  ['Rosemarie', 'spotify:track:4PyICfZQvoCRHiPzcUFJRp'],
#  ['The End of The End', 'spotify:track:71W6e67EUnzAKHlNBkWg3U'],
#  ['Manu', 'spotify:track:6jTBprRG30gyQNEUwGKJPM'],
#  ['Perhonen', 'Not Found'],
#  ['Pastime Paradise', 'spotify:track:4Gn4b1qJ12rowCNRw5DHM9'],
#  ['Papillon (French version)', 'spotify:track:2Jc6Eo78HJgdng3hhrHfIi'],
#  ['Wabash (Feat. John Coltrane)', 'Not Found'],
#  ['Finale Incantata', 'Not Found'],
#  ['Variations Goldberg, BWV 988: Variatio 21 Canone alla Settima',
#   'spotify:track:3DZjisXoTKywNBAnxoH6jy'],
#  ['Surface of the Real', 'Not Found'],
#  ['Body and Soul', 'spotify:track:4xOddn8kZXMLlVEDpV9WwR'],
# ...

# %%
# Jazz bittersweet bright instrumental fast not_danceable 269
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 5:
        if alldata[i][26] == 12:
            if alldata[i][27] == 15:
                if alldata[i][28] == 17:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Welcome Home', 'spotify:track:76brPklS0WdzpoOooFltDS'],
#  ['Summer Night', 'spotify:track:01dGlfV1esSbayq4lZ76WH'],
#  ['Housewife', 'spotify:track:1St8wcB0dypSbTvS9HbPcP'],
#  ['Keening Of The Three Marys', 'Not Found'],
#  ['Amarcord', 'spotify:track:3ZJrhfNnX0nttLmC1vK1Xo'],
#  ['The Lullaby', 'spotify:track:5spc9JVbY13Gbhvf69ae6v'],
#  ['Sourdos (live)', 'Not Found'],
#  ['So Danco Samba', 'spotify:track:0tWDEatIfyxwVDQIgbwCKx'],
#  ['Astelin kaunista kangasta', 'Not Found'],
#  ['G12 Nights', 'spotify:track:4Uen1omWBIHBdgL6qG5tms'],
#  ['East of the Sun (and West of the Moon)',
#   'spotify:track:052pP3bbU7ccH7dBykaKa8'],
#  ['Chelsea Girl', 'spotify:track:4Ev46A76YphOKxkroEb4Je'],
#  ['Woody n You', 'spotify:track:36x28pieH33klygZ7JYBHr'],
#  ['The Zeppelin Arrives', 'spotify:track:27apwbpYUiflJDdjbnGUT0'],
#  ['Mood Indigo', 'spotify:track:3LZcUzSFUOZraM0nPJCb6N'],
#  ['Oh Grace', 'spotify:track:3ezGmPj2R4ZhmwX4d71xHG'],
# ...

# %%
# Jazz cheerful bright instrumental slow not_danceable 118
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 5:
        if alldata[i][26] == 12:
            if alldata[i][27] == 15:
                if alldata[i][28] == 17:
                    if alldata[i][29] == 20:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['An Roghainn Dàin do Eimhir XXII (The Choice)', 'Not Found'],
#  ['Tudo que eu quero (tranqüilo)', 'spotify:track:5hSsy22Imsv8lrDrrmQqQX'],
#  ['Summary', 'spotify:track:0qlyyZODtI4BixuHLN1AN9'],
#  ['Pirkko', 'spotify:track:7f0MWq8Ryx9N7pB2ofZ5za'],
#  ['Somewhere Between Highway 61 & 49', 'spotify:track:08MpvMcUGyoWIxYuNHvG6E'],
#  ['The Girl from Ipanema', 'spotify:track:0ihqVUYfvMx8VHZvIDPt4Z'],
#  ['A Spirit Harness', 'spotify:track:2wUSGVeoGf260U8pSVJzXm'],
#  ['Macavity: The Mystery Cat', 'spotify:track:1xTp65doSyf0vZz7OEsTyr'],
#  ['Glasgow Peggy', 'spotify:track:2lojSFYLCrYFxkco0tJPeF'],
#  ['Tale of Two Orphanages', 'Not Found'],
#  ['North of God', 'Not Found'],
#  ['Tudo Que Voce Podia Ser', 'spotify:track:0yP0uLdL5JebyaHvevPsBS'],
#  ['Crystal Rain', 'spotify:track:2QjefBHgqnNHuHnQ2AKHYm'],
#  ['My Lily / The Sweetness of Mary / Hughie Jim Pauls Reel',
#   'spotify:track:6qtVSzNf2mv02PktHRSth9'],
#  ['The River', 'spotify:track:6By9C9SrRMFVdVNzuImvHK'],
# ...

# %%
# Jazz cheerful bright voice fast not_danceable 269
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 5:
        if alldata[i][26] == 12:
            if alldata[i][27] == 15:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Overs (live)', 'spotify:track:5fMIpAaTY7BR0yncUqV8RQ'],
#  ['Up on the Roof', 'spotify:track:2yHKFtw2jSHO8533t6GC2M'],
#  ['O Bittersweet Dear Madeline', 'spotify:track:7qNwPOlFZ4ApkBTUaYHvrd'],
#  ['Cest Si Bon', 'spotify:track:5PcCSUGriuhWuyyWxuBnnM'],
#  ['I Dont Wanna Be Kissed (by Anyone but You) (piano take 4)',
#   'spotify:track:0xM6JK1VvtC9N572g9Ik16'],
#  ['S Wonderful', 'spotify:track:0HbjKMz0SDHvJZ5eA14t6y'],
#  ['Bug', 'spotify:track:1F6x1U3E3HKv7bYySW1Ehe'],
#  ['Adventures in Paradise', 'spotify:track:6BtTlutYpLqeX3lym2SlIf'],
#  ['Minha lisboa de mim', 'spotify:track:4YP5gdKpeuiVGHuDUMHqXG'],
#  ['Tuxedo Junction', 'spotify:track:68EjeHBVmkoE3KvXBOIHRl'],
#  ['Buzzard Song', 'spotify:track:0rRY6HvzcMnfbe7a8aiiPl'],
#  ['Our Love', 'spotify:track:2RuxVpqaQ5BXv1CPnlTBvx'],
#  ['Thaney', 'spotify:track:79IB80kN34H2S2tGS24ZBs'],
#  ['Freeker By The Speaker', 'spotify:track:0bTar7V90X1FBXnCEzfPNr'],
#  ['Easy Rider', 'spotify:track:2YiCNUzMCA2OZzfWKWyHjp'],
# ...

# %%
# Jazz cheerful bright voice slow not_danceable 153
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 5:
        if alldata[i][26] == 12:
            if alldata[i][27] == 15:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 20:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['På Grund Av Emigration', 'Not Found'],
#  ['Rock n Roll Suicide', 'spotify:track:1k5iH4KDKi56MFvlnrALNV'],
#  ['Vajzë e valëve', 'spotify:track:5zgAla85Xl61Cyr0pyU7Qr'],
#  ['Forever Yours', 'spotify:track:1KEMzUbCAGNNEvdUDwEiIl'],
#  ['Push-Ka-Pee She Pie (The Saga of Saga Boy)', 'Not Found'],
#  ['Stars Fell on Alabama', 'spotify:track:6wMoTfKB8Ra3SMyIF86I8j'],
#  ['Ghosts Are Good Company', 'spotify:track:0IuHqFbdeZoZD1TKa9i0ub'],
#  ['I vespri Siciliani, (The) Sicilian Vespers (2005 Digital Remaster): Mercè, dilette amiche (Bolero)',
#   'Not Found'],
#  ['Bayern is überoi', 'Not Found'],
#  ['Please Just Call Me Baby', 'Not Found'],
#  ['La Demoiselle De Déshonneur', 'Not Found'],
#  ['Comme Un Arbre', 'spotify:track:3DzSddKBiniOvW8x8YUwr5'],
#  ['Hurricane Drunk', 'spotify:track:1T0Kkq1Oio6nHVhenMQeDR'],
#  ['Dreamin Blues', 'spotify:track:4GgU39Hl7VyqFrlLFS9FvD'],
#  ['On The Sunny Side Of The Street', 'spotify:track:5YEyym9HPekysgzKn0uME4'],
# ...

# %%
# Jazz cheerful dark isntrumental fast not_danceable 240
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 5:
        if alldata[i][26] == 12:
            if alldata[i][27] == 16:
                if alldata[i][28] == 17:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Imperius Removes Arrow', 'Not Found'],
#  ['Le Temps Scellé', 'spotify:track:6qpsRTmnosUz3QoiNyRXxi'],
#  ['La Ville', 'spotify:track:4xv3hxMCtqpqJ5y5ryfdpF'],
#  ['Die Walküre: Aufzug I, Szene II. Ich weiß ein wildes Geschlecht (Hunding)',
#   'Not Found'],
#  ['Soon as I Get Home', 'spotify:track:3RDEfHgsYe98GJhUR93kJ4'],
#  ['Laboratory Hunt', 'Not Found'],
#  ['The Prayer', 'spotify:track:5PYjaurejfoz5EXyeWVCTP'],
#  ['Window Blues', 'spotify:track:5gBjVLINJkJl7v3S7p0ygU'],
#  ['Technicians of Spaceship Earth (Introduction)', 'Not Found'],
#  ['Kulleritova', 'spotify:track:0YPqlOUtY5fO9ryZHYneFV'],
#  ['Im 3. Raum', 'Not Found'],
#  ['Pax Vobiscum', 'spotify:track:7FKfxNZ62msBSWWXy9CeUu'],
#  ['Spirals', 'spotify:track:0cIdnv1XkuaYyZxoXcNyrr'],
#  ['A Hive of Villainy (Star Wars)', 'Not Found'],
#  ['Pathway', 'spotify:track:3RobU9TBEuFSdMRttHr6oj'],
#  ['Ultima Ratio Regum - Chopin Etude 12 op 25', 'Not Found'],
# ...

# %%
# Jazz cheerful dark isntrumental slow not_danceable 142
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 5:
        if alldata[i][26] == 12:
            if alldata[i][27] == 16:
                if alldata[i][28] == 17:
                    if alldata[i][29] == 20:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Mast', 'spotify:track:2TfQiimGAkxHRSrdjdMfsy'],
#  ['The Same Old Throb', 'spotify:track:3dhE1ar1ueBLbPppYr4YLt'],
#  ['Honky Tonk', 'spotify:track:6GU1es1LlRS8vyWhtvOksC'],
#  ['Breakfast At Tiffanys', 'spotify:track:3oqKQoJnijk3Tu97MEtgcd'],
#  ['So That No Matter', 'spotify:track:5rj3FziNJ5HhVSTLWFWkAr'],
#  ['Tug on the Line', 'spotify:track:7kdmnY21U1PXeMEVzqpt53'],
#  ['Return Of The Ancients', 'Not Found'],
#  ['Der Maggot Tango', 'spotify:track:7AcebUyQaYM8jKAbQTgAOH'],
#  ['First Look Inside (Solo)', 'Not Found'],
#  ['Álafoss', 'spotify:track:3sqyTvMpQeKfGfwmtsheF3'],
#  ['Stephanies Song', 'spotify:track:0yjCzWGVjVyyHyFgybD8WY'],
#  ['Prepare For Battle', 'spotify:track:6KZWuzQjcqHbEqrikazAOM'],
#  ['Leather (alternate mix)', 'spotify:track:7n4bR2UA9hzQDjW5kyOcIa'],
#  ['It Wasnt the Hunting', 'spotify:track:28NT1UuWIxwgATaakVyti2'],
#  ['The Gathering', 'spotify:track:4xNsaFIJFK3hGvtBg7lbyw'],
#  ['Ritual Use of Fire', 'spotify:track:50e880MPUwQAhhUHDM3rjL'],
# ...

# %%
# Jazz cheerful dark voice fast not_danceable 138
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 5:
        if alldata[i][26] == 12:
            if alldata[i][27] == 16:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Birds in My Head', 'spotify:track:2IK6NYhgmWlqc7DvxVbSZI'],
#  ['Passed Your Place,Saw Your Car,Thought Of You',
#   'spotify:track:0w0OeAHcTSWyFuLOtvTixT'],
#  ['La Tondue', 'spotify:track:2kl55fdvvqd1MaoAMUB7jW'],
#  ['Insincerity Peeked Through Cloudlessly',
#   'spotify:track:2iLNDOtfw9IkmZ6tiifzYa'],
#  ['Jacks Lament', 'spotify:track:4VCexsNDyC2j8ZrY34RwV0'],
#  ['God Bless The Child', 'spotify:track:75iilmYj5hO3mG1Ywly28w'],
#  ['Bivoj', 'spotify:track:5utxONKPdSxJ9iHP8JiP55'],
#  ['Herald of Free Enterprise', 'spotify:track:70NAuqVliQYiDFNsBo8kTA'],
#  ['Look Behind the Hill', 'Not Found'],
#  ['What A Wonderful World', 'spotify:track:0nSIDY2uQgLuITFqa9JRJx'],
#  ['Grace', 'Not Found'],
#  ['Steven Does', 'spotify:track:0cVJLyDswSV8QHF2irCtgN'],
#  ['Se não chovesse (Fado súplica)', 'Not Found'],
#  ['My Funny Valentine', 'spotify:track:5lKdnN3Awuz6NWvmgfKjSn'],
#  ['Interview (March 1969), Part 9', 'Not Found'],
#  ['Pygmalion', 'spotify:track:68cwHlGcDWyY3TELazOYex'],
# ...

# %%
# Jazz cheerful dark voice slow not_danceable 72
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 5:
        if alldata[i][26] == 12:
            if alldata[i][27] == 16:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 20:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['The Third Hand', 'Not Found'],
#  ['Isobel Goudie: My Lady of the Night / Coitus Interruptus / Virgin and the Hunter',
#   'Not Found'],
#  ['Kozhamyk', 'spotify:track:0GuLwPuZnhqytrLB1PxYmT'],
#  ['Maine Island Lovers', 'spotify:track:2L69a64h74KLVdhbl33wTT'],
#  ['Where no endings end', 'Not Found'],
#  ['Dukes Place', 'spotify:track:1LveDDWOHSztJ0FqgdG1my'],
#  ['Les Malheurs Du Lion', 'spotify:track:5mejRJUI949K6yGlCArsmH'],
#  ['Please Dont Call Me', 'spotify:track:20imB89xhlJhHwcLNmiXRF'],
#  ['Ain’t Got Shit', 'Not Found'],
#  ['Sheepdog (Acoustic Version)', 'Not Found'],
#  ['Anamnesis 3', 'Not Found'],
#  ['After The War', 'spotify:track:1rfDVouDFi4F0q7Jezi0A8'],
#  ['Quando julgas que me amas', 'spotify:track:0iYaitrZ9PuzrTnrBlgzAR'],
#  ['Rosacoke Street', 'spotify:track:7sADV2OQhK7G4RKNfipORg'],
#  ['Hell Understand and Say Well Done', 'Not Found'],
#  ['Hoodoo Man Blues', 'spotify:track:7fKCACJgCEFn6AXLYgfKgc'],
#  ['Čerešne', 'Not Found'],
# ...

# %%
# Jazz aggressive slow 385
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 5:
        if alldata[i][26] == 14:
             if alldata[i][29] == 20:
                list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Lassie Lie Near Me', 'spotify:track:0U3DpauKeI6lM8noTTDUOU'],
#  ['Epilogue', 'spotify:track:1Au4U6wBitSAdDJ4UalBgG'],
#  ['Got to Learn How to Dance', 'spotify:track:5wO3pK4InllVBzeBMjNbcV'],
#  ['The Boxer', 'spotify:track:3MUHmdHaQSQ79hnmJRk5uk'],
#  ['Pipestone Octopus With Horseheart', 'Not Found'],
#  ['Days of Wine and Roses', 'spotify:track:1yegDiVa8d94H07ga1SLOt'],
#  ['Blues', 'spotify:track:0q0rWNdLVrRH3kgZnZxMJp'],
#  ['Kalki the Destroyer', 'spotify:track:2vl5CACaatyUCOlo14UkmV'],
#  ['見えないふたり', 'Not Found'],
#  ['Africa', 'spotify:track:5xA1mq2MUzqcyLnLqxLUy9'],
#  ['Red', 'spotify:track:0rAuzpbeBdwVBbXmKZsKZG'],
#  ['French Suite No. 3 in B minor, BWV 814: V. Anglaise',
#   'spotify:track:5simW00FnetCjacfpFMx8j'],
#  ['Basse danse-Jouyssance vous donneray',
#   'spotify:track:6Q7uCkJRVUV7gdbYheszti'],
#  ['Billie Listens', 'spotify:track:16AnhFTvvbxtQlGBIRkYtD'],
#  ['Lobo', 'spotify:track:6X71nBSO8vIamYzgNblAW8'],
# ...

# %%
# Jazz aggressive bright instrumental fast danceable 110
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 5:
        if alldata[i][26] == 14:
            if alldata[i][27] == 15:
                if alldata[i][28] == 17:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 0:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Turnpike', 'spotify:track:3Dc3Mgpd1dUQXc4FWJZJcV'],
#  ['The Mark of Jazz (alternative take)', 'Not Found'],
#  ['Jism', 'spotify:track:1Gzu5W1s4scMTM5McO5Fxv'],
#  ['Rollin and Tumblin (Remix)', 'Not Found'],
#  ['A Good Time Was Had By All', 'spotify:track:7JnChAS7nrQIvt2RH1DuKr'],
#  ['Wives and Lovers', 'spotify:track:0WgfUTGmOxd91r95egrbcA'],
#  ['Sizzlin', 'spotify:track:2YEljVqHmmGImlfPfAKMIe'],
#  ['Watering', 'spotify:track:1rwSUaFFWzgpvPYs7fDHOy'],
#  ['One More Ride', 'spotify:track:5tNnY3sJpfWyq91A0jfWl8'],
#  ['Samba Yantra', 'Not Found'],
#  ['Maulana', 'spotify:track:5Bq6NwRKr2bWORD716eZhH'],
#  ['That Old Black Magic', 'spotify:track:6wSbECalt1GrqrgH3qr1fO'],
#  ['Perfumeのただただラジオが好きだからレイディオ! 2', 'Not Found'],
#  ['Requiem', 'spotify:track:39wRwWP8UdBiFIjfmDGUrC'],
#  ['Kamli', 'Not Found'],
#  ['Greensleeves', 'spotify:track:7F51MFYNLhse6WqsoA7lrX'],
#  ['History', 'spotify:track:6xBAqC8WoBXY78oI7BD1aL'],
#  ['Blue Black', 'spotify:track:0JHREzo9WzIP4vyybhSKPa'],
# ...

# %%
# Jazz aggressive bright instrumental fast not_danceable 262
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 5:
        if alldata[i][26] == 14:
            if alldata[i][27] == 15:
                if alldata[i][28] == 17:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Stolen Moments', 'spotify:track:2ZBWNspmPkgSB0MQExrx6O'],
#  ['Spetsnaz / Paul Leni', 'Not Found'],
#  ['Last Night When We Were Young/While We Were Young', 'Not Found'],
#  ['Dearly Beloved', 'spotify:track:1UeidqvJupkzwOO0s8OEOA'],
#  ['Unintended', 'spotify:track:6kyxQuFD38mo4S3urD2Wkw'],
#  ['Lover Man', 'spotify:track:7y8oZInBrmZytpac9nB4HP'],
#  ['Villa Hermosa', 'spotify:track:6OsDz8Rex5ZHjdrMUGWimS'],
#  ['2001 (Live)', 'spotify:track:1GhOiBrglutzTd9dc3V6ZX'],
#  ['Two for One', 'spotify:track:7dStofWPTOkwElCypW6BzB'],
#  ['From The Hot Afternoon (Alternate Take 1)', 'Not Found'],
#  ['I Got It Bad & That Aint Good', 'spotify:track:1GChLCOSU0SQkyodA8txae'],
#  ['The Forest Battle', 'spotify:track:4Dpxra8Sl7CI0aED2b1IxE'],
#  ['Super Sister', 'spotify:track:37yK2D6iDC2L963g7ZnY5x'],
#  ['Soulville', 'spotify:track:7b3V9eMh7z0iucPQHwAVtm'],
#  ['Liberia', 'spotify:track:08fPORjYOPjT9Vu6MVrlB5'],
#  ['Mexican Prick Fish', 'spotify:track:4bewDOrhOS1ZYXPD24CElt'],
# ...

# %%
# Jazz aggressive dark instrumental fast danceable 100
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 5:
        if alldata[i][26] == 14:
            if alldata[i][27] == 16:
                if alldata[i][28] == 17:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 0:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Blues Sketch In Clave', 'spotify:track:1qIKhMS6Ju4GlbK5q4xmAL'],
#  ['Sonata in G major, BWV 1019 (alternate movement): Cembalo solo',
#   'spotify:track:3L3wH0PmJb5M9EIaIHXPD8'],
#  ['Serenade to a Savage', 'spotify:track:4G0g8kAOw8Vq2ZB78NIDhK'],
#  ['Photosynthesis', 'spotify:track:7L8EIhvRUIgNNGRRSHA0KH'],
#  ['Final Frontier', 'spotify:track:0cEMapejO7m5FxEEJYtMUE'],
#  ['Snowflake 7', 'spotify:track:5O3nmGCH4MwYudR4k2sLQU'],
#  ['Krell Vid-User', 'spotify:track:2a4tboUwBwLZWEw6oLCE2z'],
#  ['Time Zone', 'spotify:track:7JoTZlNDCmMDzZyGVsDFOe'],
#  ['Ethereal Shadow', 'spotify:track:5Wr0n8O9cdP7GZ9xGMB9O2'],
#  ['Without a Song', 'spotify:track:6NeCoPvzhTHcBu3RFzbY3X'],
#  ['Intro', 'spotify:track:3pQKv27af0NaFfeWa7InFu'],
#  ['A Soulful Bee, a Soulful Rose', 'spotify:track:5BAbbFMLxuSYl9ux0wXs6g'],
#  ['Gmoong', 'spotify:track:7DJVOw9vaxzNZnKrrfvpMB'],
#  ['Trevere', 'spotify:track:5I6UOLcvXafXQUhxSeEpFY'],
#  ['Concierto de Aranjuez (adagio) (alternate ending)',
# ...

# %%
# Jazz aggressive dark instrumental fast not_danceable 613
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 5:
        if alldata[i][26] == 14:
            if alldata[i][27] == 16:
                if alldata[i][28] == 17:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['As Mãos e Os Frutos', 'spotify:track:4A9asVJSPmqtWVcp0OqjnS'],
#  ['Morninglight', 'Not Found'],
#  ['Awakening', 'spotify:track:34eA4TBYCWGmnJkbOCOXM7'],
#  ['Alone With You', 'spotify:track:6wVTAZB9ZPO8HT5kdMwaHO'],
#  ['Un Poco Fabulous', 'spotify:track:14M9FrFsQFNOFG31XgzuID'],
#  ['Do What You Like', 'spotify:track:3XcwbnCGy3uEOj16xwdMHW'],
#  ['Can the Gwot Save Us?', 'spotify:track:5rNaSws9k7wzVLOyJ508IO'],
#  ['Hergest Ridge, Part One', 'spotify:track:5v0CptwAhZ5HoNplFTk4CB'],
#  ['Killers', 'Not Found'],
#  ['Stormy Monday', 'spotify:track:0Xmpqkt8N2BtPMkcPrLpD9'],
#  ['Inflections', 'Not Found'],
#  ['Ultra Lazuli', 'spotify:track:6QqT4jcaIzN2tK6101H1TN'],
#  ['Blues Hour', 'spotify:track:2qK9jQFz8NeeugkmtiKjBl'],
#  ['LAmi', 'Not Found'],
#  ['The Beatitudes', 'spotify:track:0wlP70srmwSjUvDd5Lp3fs'],
#  ['This White Mountain on Which You Will Die',
#   'spotify:track:6UtXQa4Qnx3G2neJA72YX0'],
#  ['(anti-fascistisk tale 2009)', 'Not Found'],
# ...

# %%
# Jazz aggressive dark voice 131
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 5:
        if alldata[i][26] == 14:
            if alldata[i][27] == 16:
                if alldata[i][28] == 18:
                    list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Lassie Lie Near Me', 'spotify:track:0U3DpauKeI6lM8noTTDUOU'],
#  ['Deliverance', 'spotify:track:0N8Q8DUmbQ0QjcCYza9OWo'],
#  ['John the revelator', 'spotify:track:4C8aeZITw13JOx0uHQGSl3'],
#  ['Drive Thru Bottlo', 'spotify:track:3TcuCNNeyrsg2Yr6ISGdyv'],
#  ['Hearts Ne Kotoko', 'spotify:track:0ZuJLLugrvglK95Ogv3qDg'],
#  ['Chasing for Young Blood', 'spotify:track:3DbxKB2UsEftKSkdcoxsCU'],
#  ['Music for Strings, Percussion & Celesta, Sz. 106, BB 114: III. Adagio (rehearsal Sequence)',
#   'Not Found'],
#  ['La sgargianza, parte 2', 'Not Found'],
#  ['White Rabbit (mono single version)',
#   'spotify:track:0B06qo77UwovqxOY3Mwcw4'],
#  ['Frodos Lament for Gandalf', 'Not Found'],
#  ['Poison', 'spotify:track:4QZKM4FxBjk7pemHadPrvM'],
#  ['The Good Life', 'spotify:track:61nsKW9rkI1mgH9ulVdhlL'],
#  ['Our Day Will Come', 'spotify:track:6GuuxJJ63HcmjZI1vT7iQk'],
#  ['I Shall Not Care', 'spotify:track:0Z6CuPLVLe21ljBhkTwplC'],
#  ['ItÂ´s You Baby', 'Not Found'],
# ...

# %% [markdown]
# # Pop Playlists

# %%
# Pop passionate 71
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 6:
        if alldata[i][26] == 10:
            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Letter To The Lord', 'spotify:track:6yJIA230pcYQUaaYeKsvGd'],
#  ['Home', 'spotify:track:552NkuaDuJDCNIkWor3O0f'],
#  ['(Unknown interlude)', 'spotify:track:4K4kgUSwXUEZNGsYx67jyr'],
#  ['La Place du vide', 'Not Found'],
#  ['Smooth Operator', 'Not Found'],
#  ['Lied der Zeit', 'spotify:track:3ccxdVAvmIIwRosCRKsJOz'],
#  ['Judgement Ground', 'spotify:track:6dIpyvETEsFzmctusqVGVK'],
#  ['Mr Lacey', 'spotify:track:1JgpFt8ahKyeNuSgpxnr9S'],
#  ['O Stella', 'spotify:track:4uFVXuSaJcHO08G3T9LBPo'],
#  ['Turhaan mua huudat', 'Not Found'],
#  ['Foundation', 'spotify:track:3w5WHAjLfyTaihHMtvlA6R'],
#  ['03 - Deep Lakes of the Soul', 'Not Found'],
#  ['I Wanna Grow Up To Be A Politician',
#   'spotify:track:0Yw1cwwtbofWFSlCusq3DC'],
#  ['Gold Guns Girls', 'spotify:track:5WH2HL7ZrVu9n51viwbdJw'],
#  ['Gold Rush Pt. II', 'Not Found'],
#  ['Intro - The Endlessness of Eight', 'Not Found'],
#  ['Vengeance', 'spotify:track:53pQ4AjhpoAZG9HiUwlGOt'],
# ...

# %%
# Pop cheerful bright instrumental fast danceable 94
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 6:
        if alldata[i][26] == 11:
            if alldata[i][27] == 15:
                if alldata[i][28] == 17:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 0:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['The Bridal Jig / The Handsome Young Maidens / The Lancers Jig (jigs)',
#   'Not Found'],
#  ['Lucifer', 'spotify:track:4F5ih0ybpKoD5eYOTQIKjy'],
#  ['Strange Entity', 'spotify:track:3zPeX8LNkyUPP3BB7HxSP7'],
#  ['Jeune (radio edit)', 'spotify:track:7x56DtINwPbXziffl7q9XT'],
#  ['You Make Me Sing', 'spotify:track:2b6aCvfmMKAUNrrfmAje8t'],
#  ['Memphis Train Blues', 'Not Found'],
#  ['Hang on Sloopy', 'spotify:track:4YRbp7RAmR4N7cuBajNiC3'],
#  ['Sayonara', 'spotify:track:6DeOcQkwweyF1zEEanJCYs'],
#  ['Sweet Child O’ Mine', 'spotify:track:0yrvG8TOZu3tgXzX0j9KsN'],
#  ['Gunpowder', 'spotify:track:4kNIwgk3h323xUNO9d6hxm'],
#  ['Du temps qui passe', 'spotify:track:2gtpEHtVop54vNw8pUYcox'],
#  ['A Little More Each Day', 'spotify:track:3rop1sC00wHJZK1AIAEfeJ'],
#  ['You Ought to Be Havin Fun', 'spotify:track:0GEMqWyxl6gGHWFnFkB9Cc'],
#  ['More Than This', 'spotify:track:4i7dTAl6pWONVJLRngwuB8'],
#  ['Just a Few More Tears', 'spotify:track:14p0ISI6Xz8eYningVRln1'],
# ...

# %%
# Pop cheerful bright instrumental fast not_danceable 92
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 6:
        if alldata[i][26] == 11:
            if alldata[i][27] == 15:
                if alldata[i][28] == 17:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Jig Horizonto / Dança do Urso', 'Not Found'],
#  ['Black Pine Waltz', 'spotify:track:03UpPq0ZqQ0apddA2ELm10'],
#  ['Pola ponte de S.Xoan', 'spotify:track:0BCDqgy7uSNlZEhwlL0lcE'],
#  ['Velvet sunset', 'spotify:track:0bcyJa8xPOLpvtetxhcd31'],
#  ['Friend', 'spotify:track:6pZHCB6HgFLtmTEDzgiCcC'],
#  ['The Good the Bad and the Ugly (Il Buono, Il Brutto, Il Cattino)',
#   'Not Found'],
#  ['A Letter From the Past', 'spotify:track:3IKEU7r9WCZCFT21oN3l6q'],
#  ['Black Beauty', 'spotify:track:6GjvaFeZ4Bpujm5gLNZL6P'],
#  ['Come To My Table', 'Not Found'],
#  ['Leaving on a Jet Plane', 'spotify:track:6ataS6MNGnn4S2IwYYCQ3W'],
#  ['Ceridwens Curse', 'spotify:track:51YcK8FDVN4lvGK4S9nTza'],
#  ['Stations', 'spotify:track:2tRocSg9vNjghIoJWPBfZu'],
#  ['Parting Should Be Painless', 'spotify:track:7x22TbQN0wM9gj11w1K71f'],
#  ['One Night Only', 'spotify:track:2N0LpQjmiFTbK6OrKilak7'],
#  ['El tiempo está después', 'spotify:track:0tbLOU9BO0mGip1N8sTBZ9'],
# ...

# %%
# Pop cheerful bright instrumental slow 116
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 6:
        if alldata[i][26] == 11:
            if alldata[i][27] == 15:
                if alldata[i][28] == 17:
                    if alldata[i][29] == 20:
                        list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Gone But Not Forgotten', 'spotify:track:5T9cRmBiJNsKqCvA77ONev'],
#  ['Todo tiende', 'spotify:track:5WEZoxQwWQrEaKB4Hi5uVG'],
#  ['Arcanul', 'spotify:track:3Oy2TStLqVhF50zGUpVisw'],
#  ['Traveling Again (Traveling I)', 'Not Found'],
#  ['Love Dance', 'spotify:track:3FEgOe4ms9sIpxmCSqeF9d'],
#  ['Cruel World Enterprise', 'spotify:track:78nHhpEmZtBwmkHAzHntSg'],
#  ['Mellodrama No. 2 A', 'Not Found'],
#  ['All the Love', 'spotify:track:65GqoqL2egf1lmv67dO7Zw'],
#  ['Deer Spirit Song', 'spotify:track:15AkKxgItdz31NkEEYSn7Q'],
#  ['Right On', 'spotify:track:2H8rH8z3QQn6MhVcuayUxi'],
#  ['Over the Mountain, Across the Sea (mono)', 'Not Found'],
#  ['Verliefd op een paard', 'spotify:track:0DPu7lD1rVIyRioe0QO1zR'],
#  ['Leave a Light On', 'spotify:track:7pCzxtDaU0ghOkwvykSA3r'],
#  ['Break My Heart Again', 'spotify:track:2jjRL5w2BvpQjqq1qD44iY'],
#  ['Little Bitty Pretty One', 'spotify:track:32SPRzjmx5TpEg0jAZXSis'],
#  ['WRXZWRXZWRXZ', 'spotify:track:4X61qK8HEjbrItzBO2XPkm'],
# ...

# %%
# Pop cheerful bright instrumental fast danceable 253
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 6:
        if alldata[i][26] == 11:
            if alldata[i][27] == 15:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 0:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Lets Make a Habbit of This', 'Not Found'],
#  ['Tonight the Bottle Let Me Down', 'spotify:track:1lb3Use9zuEt7ZMLRzS3r3'],
#  ['Keep You Much Longer', 'spotify:track:1kiAXXEYooMvsFWyYaDhof'],
#  ['A Man In Love', 'spotify:track:6s0j8P6FPVIWxEJH0ghoaf'],
#  ['Cadillac', 'spotify:track:1IEhX7AL7u9rGdLyD8TSEQ'],
#  ['Staan My By', 'spotify:track:0WaDMtPZoGSuXyXUt4vtIL'],
#  ['Escapar', 'spotify:track:6KnQHJvLVexroVxienplH1'],
#  ['Silver Moon', 'spotify:track:46NSaTu0BJZrfuqhzxXCaC'],
#  ['Im Alive', 'spotify:track:6JxxYjnXwU5xu3leTL7EYn'],
#  ['Automaton', 'Not Found'],
#  ['Chameleon Girl', 'spotify:track:2wovuz6Yw5avtvGBdzy3AY'],
#  ['Tonight Will Last Forever', 'Not Found'],
#  ['Rattler', 'spotify:track:7bCw4rpY4TrLSDU8V3DOc1'],
#  ['I Cant Dance to That Music Youre Playing',
#   'spotify:track:1EsUEEDut23EAaGYdUmn2O'],
#  ['Between Here And Kingdom Come', 'spotify:track:3FYDyvH8KJGmsQ0hUUvFCl'],
#  ['I Cant Help It', 'spotify:track:3rpjb7tVekteT7iBeRzI5W'],
# ...

# %%
# Pop cheerful bright instrumental fast not_danceable 224
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 6:
        if alldata[i][26] == 11:
            if alldata[i][27] == 15:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Dirty Blvd.', 'spotify:track:4TDLfAmx45EpSiQYG6hCzT'],
#  ['Turn My Life Down', 'spotify:track:3KogXHlw6HZMcV783tXSOR'],
#  ['Bring It On Home', 'spotify:track:4I1JYY51J72q3GDVbd6miH'],
#  ['These Are the Days', 'spotify:track:44g0kd30idU74ePM1sV9HO'],
#  ['Me and Bobby and Bobby’s Brother', 'spotify:track:6TZFXq1LiprqGOZPt6gwOc'],
#  ['Nina (Radio-Soft-mix)', 'spotify:track:39av5Fp6nxfbV2piahBSb7'],
#  ['Sounds', 'spotify:track:0wkfSyWswrqCgQgg9Mvzza'],
#  ['Rattlin Bones', 'spotify:track:2SPZKCTMGDjg0AMGhvehLH'],
#  ['Imagine That', 'spotify:track:0jRz6w3g6JsqPJo9CRuKRW'],
#  ['Dont Give Up On Me (1974)', 'Not Found'],
#  ['Something About What Happens When We Talk',
#   'spotify:track:7v6SVPEUd7mq6O8A5ze7cp'],
#  ['Every Little Word', 'spotify:track:2G8JyTYuo8ckYtrqlTqtbc'],
#  ['Late Goodbye (radio edit)', 'spotify:track:00en8GL3DIHV1G9fZWGpVq'],
#  ['I Feel So Good', 'spotify:track:1XRyVvwsM5k2I3NUf7tE1l'],
#  ['Pass It On', 'Not Found'],
# ...

# %%
# Pop cheerful bright instrumental slow danceable 243
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 6:
        if alldata[i][26] == 11:
            if alldata[i][27] == 15:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 20:
                        if alldata[i][30] == 0:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Ave Maria', 'spotify:track:1BIobH6EhjJRNAW9w2s2U8'],
#  ['Make It Up', 'spotify:track:6t7X2wijv2gYLPwPPTAPTY'],
#  ['Aber nein, aber nein', 'spotify:track:14aL4M9nQvpfEaY447W91M'],
#  ['Remedy', 'spotify:track:7xvBjSznydntipiNDKOh32'],
#  ['Los muchachos de mi barrio', 'spotify:track:2dB1qCzBj3MdDj6mncAI51'],
#  ['Little Louie', 'spotify:track:34t4NDBFbBd2zyZewj8MR0'],
#  ['Hide Away Folk Family (live)', 'Not Found'],
#  ['S-E-X-X-Y (radio mix)', 'spotify:track:5zasNG66Ge6IXKQq5dnmVj'],
#  ['Sag seit wann', 'Not Found'],
#  ['Never Been Kissed', 'spotify:track:34IACM4nlSMFfAzLjOSLWa'],
#  ['Way in Way Out', 'spotify:track:3qYqAMYEdMUMhnNDl8IDtb'],
#  ['Dancin And Pantsin', 'spotify:track:4UA1WXu8d4XZk1K94Tshts'],
#  ['20 Flight Rock', 'Not Found'],
#  ['Into the Stars', 'spotify:track:44WEevK7pdotXRkbeVsUYW'],
#  ['Pondělí', 'spotify:track:56rM0LuoSJriLA7bZH7Yh3'],
#  ['Always', 'spotify:track:5QQCp4fQiU9I2FU9FvJVV2'],
# ...

# %%
# Pop cheerful bright instrumental slow danceable 189
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 6:
        if alldata[i][26] == 11:
            if alldata[i][27] == 15:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 20:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Cape Cod Morning', 'Not Found'],
#  ['Pardon Me', 'Not Found'],
#  ['Merle World', 'spotify:track:2VGA4Ws660ZDzv5cFZ78IE'],
#  ['Thats When She Started to Stop Loving You',
#   'spotify:track:7xZVhpPPYcYB4RswozUte8'],
#  ['Cobarde', 'spotify:track:7My3qRIfZAI8dBvckA09YY'],
#  ['Peace', 'spotify:track:0iLggNQp95D0e3Wfo4tE5L'],
#  ['Junkyard Julie', 'spotify:track:3ZiJWomH5ZFaB6ddc3zwJm'],
#  ['Si je tavais écouté', 'spotify:track:5iM5oCBFjCs8zE7sLuTfAo'],
#  ['Fish', 'Not Found'],
#  ['Beg You to Fall', 'spotify:track:31FxmtzTjSKdtgCgjQ5XfC'],
#  ['Things Change', 'spotify:track:6pJEqKYYBZ6CdXX1bxRgEo'],
#  ['Cherish', 'spotify:track:4a3mIp7Mrmom2SXd3S81m7'],
#  ['Jai tendance à rêver', 'Not Found'],
#  ['One Good Man', 'spotify:track:6Twi0KvitBZx50FN6ZbVEA'],
#  ['Reprise', 'Not Found'],
#  ['Tragedy (feat. Shelby Lynne)', 'Not Found'],
#  ['Cryin Time', 'spotify:track:6o4bilk2lWCtyR5bvR0WwD'],
#  ['LONELY (Japanese Ver.)', 'Not Found'],
#  ['People in the Sun', 'Not Found'],
# ...

# %%
# Pop cheerful dark 186
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 6:
        if alldata[i][26] == 11:
            if alldata[i][27] == 16:
                list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['That Line', 'spotify:track:7BC4VvHvfl92UDP23cJAsk'],
#  ['The Guardian', 'Not Found'],
#  ['Yö jota ei ollutkaan', 'Not Found'],
#  ['Wish Myself Away (feat. Graziella)', 'Not Found'],
#  ['The Means', 'spotify:track:3IJJJcoAHQwaCrQQWa8Nso'],
#  ['A City of Shadows', 'spotify:track:5MkUxNByeXB9XpsRCtr0sY'],
#  ['This World Today', 'spotify:track:1xj5CxXre9l4Xb3xdB5xQ8'],
#  ['White', 'spotify:track:5lPZxn7B3pEQvs9snG6Kmo'],
#  ['Halbzeit', 'Not Found'],
#  ['Recept', 'spotify:track:50PCu0INiaHzKuJMD4GcHo'],
#  ['Querer Bem (Birmingham)', 'Not Found'],
#  ['Flora > Fauna', 'spotify:track:0UeiS3QlbvZOUkOA3GgkP8'],
#  ['Enjoy the ride', 'spotify:track:45qSNoBAI6fPzSNX3WwbtN'],
#  ['Drug', 'spotify:track:7n7pEhs7CjqdjmYxVKcXZG'],
#  ['Places Ive Been', 'spotify:track:1bP40fkBHVutRjd7FIbj9J'],
#  ['Piove', 'Not Found'],
#  ['Bridges', 'spotify:track:7naFnJwxnEMBE5tbkJKQIc'],
#  ['Song for a Lost Love', 'spotify:track:5x08Qhkv7RfhfYJxRjMVSJ'],
# ...

# %%
# Pop bittersweet bright instrumental fast danceable 121
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 6:
        if alldata[i][26] == 12:
            if alldata[i][27] == 15:
                if alldata[i][28] == 17:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 0:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Aeria - Vom Wind', 'spotify:track:79eRRFtQ6wk4k4JVPlcsVC'],
#  ['Burning Spear - Calling Rastafari', 'Not Found'],
#  ['Dog Days Are Over (Yeasayer remix)',
#   'spotify:track:0SmiuzWv0mjcZBWfQdQCDC'],
#  ['One Voice', 'spotify:track:3ZdA3QuqHqOJdsczRwT1hg'],
#  ['Se på TV', 'Not Found'],
#  ['Наследники', 'Not Found'],
#  ['See You', 'spotify:track:6thgcpRmjy46aXmrWyprn7'],
#  ['For the Heart I Once Had', 'spotify:track:1jQHkVzpp96U6EbPTBE3Ha'],
#  ['Hands', 'spotify:track:7sLAbo70sbdLXGog7X82tu'],
#  ['Prospects', 'spotify:track:4zzV2q9EWyTI2HvslOgJtV'],
#  ['Every Beat of the Heart', 'spotify:track:2QbcdYFV2J4Ls4SAr4WgS7'],
#  ['Halo', 'Not Found'],
#  ['I Am Going but I Am Not Gone', 'spotify:track:2SOSvbHo3VuOcJQFtpWq53'],
#  ['Our Christmas Prayer', 'spotify:track:5iZ1MhaIhlWV7Lg5Ldeiw8'],
#  ['Ambulances', 'spotify:track:3gesKgOqQEAdhHXlBIWi6c'],
#  ['I Cant Break It To My Heart', 'spotify:track:584gdUKiTuNGl22P4vqXm1'],
# ...

# %%
# Pop bittersweet bright instrumental fast not_danceable 125
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 6:
        if alldata[i][26] == 12:
            if alldata[i][27] == 15:
                if alldata[i][28] == 17:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Another One Goes By', 'spotify:track:4Uq2SHf5NIJyVYcr2J1yLl'],
#  ['Lovers of Today', 'spotify:track:22AqCVfvgbCosjkO6b2DYl'],
#  ['Peace Shall Come', 'spotify:track:2GYo8FwiI8GWpjvedHHchS'],
#  ['Break Whats Broken', 'spotify:track:5GqNWXbnm2b97Lg3MxcsTk'],
#  ['Woman Without Pride', 'spotify:track:0x1XThEEobYu3gX3AbCumY'],
#  ['Yantra', 'Not Found'],
#  ['Ill Find My Way Home', 'spotify:track:2UUPd83rV19BPDbjlp0RU6'],
#  ['Drunk Tank', 'spotify:track:1D41a1XoALidr40ImwFzjW'],
#  ['Days Gone Down (Still Got the Light in Your Eyes)',
#   'spotify:track:2F4OVzPcb3KXIvQg9MgEXo'],
#  ['Oil, Sweat, Blood', 'Not Found'],
#  ['Lullaby', 'spotify:track:1QijFEB8TfVgDHdBqPczo6'],
#  ['The Suffering Machine', 'spotify:track:0ut0IqbG4w1nYR9OtTCfky'],
#  ['Näinkö meille aina täällä käy', 'Not Found'],
#  ['Onze Fitas', 'spotify:track:1xShMNwfu78cZraduXSH08'],
#  ['Illusion', 'spotify:track:3ID8CH6UCMCIhcGg4Yfy4d'],
#  ['When They Came for Us', 'spotify:track:2vpW6OSYQT4OngdsQOkzYq'],
# ...

# %%
# Pop bittersweet bright instrumental slow 97
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 6:
        if alldata[i][26] == 12:
            if alldata[i][27] == 15:
                if alldata[i][28] == 17:
                    if alldata[i][29] == 20:
                        list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['REEEWIND! -Tomita Lab. Remix-', 'Not Found'],
#  ['Beautiful Lady', 'spotify:track:1khgCYXnq7Y4XIGS9UJ2bb'],
#  ['Any Cold Wind (Sweet Selene)', 'spotify:track:2eQwaUnXJNQsIbkr6oJi8l'],
#  ['07 - Me Huele La Rumba', 'Not Found'],
#  ['Miopia', 'Not Found'],
#  ['Within the Grove', 'spotify:track:7HkbZduZDZwkAxhpy6nFk9'],
#  ['Bandera', 'spotify:track:0PFSwgsWdePTE6tQw5MIb8'],
#  ['Hurricane Drunk (instrumental)', 'Not Found'],
#  ['Angel in the Snow (edit)', 'spotify:track:5bacGRsW345UNkKUZ8WF2l'],
#  ['Every Way I Can', 'spotify:track:5X3Z5MiEA94ahtfdDSeD4X'],
#  ['Baby I (feat. Taro Hakase)', 'Not Found'],
#  ['Starbound', 'spotify:track:62pjLGerzeRDL8dse3X45P'],
#  ['Neighbours Dream', 'spotify:track:0sDU1gg5omdTAld9DoAKxs'],
#  ['Дождь', 'Not Found'],
#  ['By The Rivers of Babylon', 'Not Found'],
#  ['Jonahs Oak', 'spotify:track:2hzn3ZtisNHqQHw09hviG7'],
#  ['The Right Side?', 'spotify:track:2Gvm8T3WIXI21LxEn4vApF'],
# ...

# %%
# Pop bittersweet bright voice fast danceable 313
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 6:
        if alldata[i][26] == 12:
            if alldata[i][27] == 15:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 0:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Ill Always Be Your Fool', 'Not Found'],
#  ['Blood', 'spotify:track:1M3OS4wlS7KedJnn5fTrQV'],
#  ['Welt hinter Glas (radio edit)', 'Not Found'],
#  ['50s: Empire Central: Come on Lets Go', 'Not Found'],
#  ['Dreamin', 'spotify:track:4KvbH0GiowrUxQDY9uoSLd'],
#  ['Ich schenk dir mein Herz', 'Not Found'],
#  ['Lazy Bones', 'spotify:track:3WMEhDXc0gCJsBPpj3aZ5T'],
#  ['Live High', 'spotify:track:0XIVmUXrwk0IjQEOWFnyn1'],
#  ['Thanks for the Killer Game of Crisco® Twister',
#   'spotify:track:3D57DpittXM4CXCgsW4Iuv'],
#  ['Paradise of Joy', 'spotify:track:7iQOb8MD0Y8bcbQJWU6Iv1'],
#  ['Aint Gonna Wait', 'spotify:track:4RI0SyIBVzfJWJr4yhk1MY'],
#  ['Hallo', 'spotify:track:6hwWF40BTDeMblKBaEpsTI'],
#  ['Love on the Rocks', 'spotify:track:45bHK5dR8PeWcuMJqmpsP1'],
#  ['The Other Side', 'Not Found'],
#  ['Tal mãe tal filha', 'spotify:track:4Got76zQdLSUR6XvLo7smC'],
#  ['Lucy Lucy', 'spotify:track:3zX5VfSjfXABx06t52NUJa'],
#  ['Real Gone Kid', 'spotify:track:13Rxl4KVhg0oBXH8nLWc2f'],
# ...

# %%
# Pop bittersweet bright voice fast danceable 321
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 6:
        if alldata[i][26] == 12:
            if alldata[i][27] == 15:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['How Long', 'spotify:track:4AjKVyNUMdUveKK5OH1OJD'],
#  ['Easy Money', 'Not Found'],
#  ['Give a Little Love', 'spotify:track:5fj78iX50sJsDyXUxAqcvL'],
#  ['Vanity', 'spotify:track:7J5Su6t7ohZdwXvOp0Uwqb'],
#  ['Cry of the Broken', 'spotify:track:4ItiId0pncXohPtL3Oh7md'],
#  ['Wires', 'spotify:track:2ZeJRaisaFv5MpXViiQilq'],
#  ['Broken', 'spotify:track:4UlifI2lKgMiQrKTxDZmZU'],
#  ['Are You Lovin Me Too', 'spotify:track:7h244lcWRrwMh8Ept5C9uE'],
#  ['Ilse DeLange - 11 - Im Not So Tough', 'Not Found'],
#  ['One in a 1,000,000', 'Not Found'],
#  ['Dont Wanna Leave You Now', 'spotify:track:1IEZV9uR5uTraJmzJghp1o'],
#  ['If I Knew', 'spotify:track:0bHskKvXeutOpbbIGXMuX7'],
#  ['Morgenrot', 'spotify:track:3up7o7kfxKUeiXhDmQJ230'],
#  ['Happiness Comes In A Box', 'spotify:track:2egD0ru1xdYdgGF1nq901s'],
#  ['Summer of Love', 'spotify:track:5CP2t8ob13BZXVXByFazt1'],
#  ['Words', 'spotify:track:07PIhdmyYIw8dMeDMsx9FU'],
# ...

# %%
# Pop bittersweet bright voice slow danceable 138
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 6:
        if alldata[i][26] == 12:
            if alldata[i][27] == 15:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 20:
                        if alldata[i][30] == 0:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Sad Colored Tears', 'spotify:track:7FtyUR9M6mKmJqBLG7uMTP'],
#  ['Arms of Love', 'Not Found'],
#  ['Satis Vixi', 'Not Found'],
#  ['Se tu mi tenti', 'spotify:track:43JBCLa4Ch1DWirA7N0Sb0'],
#  ['Winter Paradise', 'spotify:track:4xHkpZjjHlF5HokipznMdS'],
#  ['Just In Case (feat. Alex Mali)', 'Not Found'],
#  ['Hello Josephine (Single Version)', 'Not Found'],
#  ['Nous', 'spotify:track:1tMs6ak4neDut56ObZvYfm'],
#  ['Hard To Let A Good Love Go', 'spotify:track:0bOJ7mO2RhrfhOCkASih5y'],
#  ['Funny Looking Angels', 'spotify:track:6oDuuwjzeaP6XpRJWueEQy'],
#  ['Tears on the Pages', 'spotify:track:78P8M5RBB1kP8Qx50r4V4w'],
#  ['How Brave You Are', 'spotify:track:6Fv4QzuuE07CMGDQwUO10a'],
#  ['You and I', 'Not Found'],
#  ['Die Zeit Heilt Alle Wunder', 'spotify:track:3PcyKitFzPFFavugrrmvH5'],
#  ['Ein Haus Ist Kein Zuhause', 'spotify:track:1rqsm0M8r3dFji6gO2SdQC'],
#  ['Girl in the Moon', 'Not Found'],
#  ['Above My Head', 'spotify:track:3ZhJ5d9IlqCfGJjAALSr7a'],
# ...

# %%
# Pop bittersweet bright voice slow not_danceable 152
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 6:
        if alldata[i][26] == 12:
            if alldata[i][27] == 15:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 20:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Goodbye in His Eyes', 'spotify:track:6W0qwhCgHp7Q2qY9FzT48G'],
#  ['White Lipstick', 'spotify:track:7B5HN152mCGUfZv8rakwVC'],
#  ['Where Sorrys Not Enough', 'spotify:track:0QTyAFFsTq5hyQi5t7AAiP'],
#  ['Sure Enough', 'spotify:track:3WUaMxGv8oCoEYm9Bny17S'],
#  ['Guillotine', 'Not Found'],
#  ['Turning Ground', 'spotify:track:1B53Uecac30G7cQzrm4jR4'],
#  ['Death Death (Devil, Devil, Devil, Devil, Evil, Evil, Evil, Evil Song)',
#   'spotify:track:6BhjjEMSlbpKhHuXpR5UKp'],
#  ['When You Were Mine', 'spotify:track:1dTUbIA7u2jza57MVtjZbN'],
#  ['Its Hard to Say Goodbye', 'spotify:track:4NpJOpa40SAAMHgeOvGZLH'],
#  ['Medley; Slipping Away-Here Is Kazmeyer', 'Not Found'],
#  ['Vom Himmel Hoch, Da Komm Ich Her', 'spotify:track:0Hvt2dgMZ2s6ZHFhv5gXJA'],
#  ['Oh You Bring', 'spotify:track:3nx11shfYYMprPRJYZcQoQ'],
#  ['Me and Bobby McGee', 'spotify:track:3U2tDMQSLem1NsQUyUlmF8'],
#  ['The Golden Road', 'spotify:track:7cyT1O7LXfSuR7I9DpXGdk'],
# ...

# %%
# Pop bittersweet dark 380
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 6:
        if alldata[i][26] == 12:
            if alldata[i][27] == 16:
                list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Translators Clos I', 'spotify:track:5roxXiY8ew7emfeBnDV8pe'],
#  ['Sleep Baby Sleep', 'spotify:track:1dxh9W4wUe1DWEEZiJylEB'],
#  ['Back After The Break', 'spotify:track:0gFrb7s6n2Cxh5YzkyaNZw'],
#  ['Who You Talking To?', 'spotify:track:2a3qyXGQRhQntmnepnDCbv'],
#  ['Diamantta Spáillit', 'spotify:track:7CmXwfebvzHQGQMOfGKi9d'],
#  ['Dwelling', 'spotify:track:0uo7GPFOiWw2qQ4K7U3846'],
#  ['Panic Attacks Are What Make Me Me', 'spotify:track:5zMWT5IP8PCLb55mJ61TN3'],
#  ['Humankind, As The Sailor', 'spotify:track:3R6KHpZoSRjOSJSuAHaSTH'],
#  ['A Dança das Ondas', 'Not Found'],
#  ['The Word', 'spotify:track:3MsU9e4MZvKlidY0xvP1mT'],
#  ['Bring On The Music (with Ty Taylor)', 'Not Found'],
#  ['Il Ny A Pas Dailleurs', 'spotify:track:54mNKubBzYKcCec3JY8ZF6'],
#  ['Whatever Its Moves', 'Not Found'],
#  ['Tuwa - Międzylesie - Turcja', 'Not Found'],
#  ['Ive Just Lost Somebody', 'spotify:track:1RZ3I8OVsBu9lEIxgrQ74L'],
#  ['Nebel', 'spotify:track:0Jcjqx0IPMmK7se9Qn0B54'],
# ...

# %%
# Pop humurous bright slow 153
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 6:
        if alldata[i][26] == 13:
            if alldata[i][27] == 15:
                if alldata[i][29] == 20:
                    list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Stronger Than Before', 'spotify:track:4Xt62tjE20m3ATFv9zXrgi'],
#  ['Meteorites', 'spotify:track:3dn4i6EKzZQKV5JNidkOrK'],
#  ['Comet Halley', 'spotify:track:6Bk7wGEuzD2eSXJfrSwGDJ'],
#  ['My Uprising', 'Not Found'],
#  ['I Fall for You', 'spotify:track:1X5ddm0B7E2rd7a5Bs1IgN'],
#  ['Gold Fever', 'spotify:track:6pXT1A2kImCsuYevVEc0fP'],
#  ['Are You Ready', 'spotify:track:1HCTnmG6T5txZHYZglA2P9'],
#  ['Transistor', 'Not Found'],
#  ['Playing for Keeps', 'spotify:track:5Sp4KSxDacrlkiS4v2eEgc'],
#  ['i dream about you', 'Not Found'],
#  ['Zwijgen', 'spotify:track:7LEPY3OhVOv73FPzMnVPVP'],
#  ['Your Magic Is Working', 'spotify:track:0Khglq7RzCkdC1X30NWqMm'],
#  ['To Know Him Is to Love Him', 'Not Found'],
#  ['Oasis', 'spotify:track:6EL06oyQyXUHOsPXdMRdMC'],
#  ['Ayo', 'Not Found'],
#  ['Rhinestone Eyes', 'spotify:track:1foMv2HQwfQ2vntFf9HFeG'],
#  ['Suspicious Behaviour', 'spotify:track:4xcxvHxjioTXswT3sMfeT8'],
#  ['Hurricane', 'spotify:track:6mWOAh7fKnQ1YE9BzPOw9V'],
# ...

# %%
# Pop humurous bright voice instrumental fast danceable 151
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 6:
        if alldata[i][26] == 13:
            if alldata[i][27] == 15:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 19:
                        list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Wait', 'spotify:track:2sWj9oQNvqv8abqqQn02RF'],
#  ['Rot blüht der Mohn', 'spotify:track:51A0W3w2H5yT1EdMXRjbPr'],
#  ['100 kleine feestjes', 'spotify:track:0JK9dhIJvUpVjmSbtHr01i'],
#  ['Full Circle', 'spotify:track:0OQTIY7qPwyufiVZV3XIYi'],
#  ['Robinson Crusoe', 'spotify:track:1RMW6wC8jLWlUjkuQPiyJ4'],
#  ['I Still Love You More', 'Not Found'],
#  ['Tears', 'spotify:track:3964lt4bZK4Sk0azmxaQT8'],
#  ['Nothin to Do but Today', 'spotify:track:64rJx6rGpqGAwF4jHuKQKa'],
#  ['Mama Talk to Your Daughter', 'Not Found'],
#  ['Tzena, Tzena, Tzena', 'spotify:track:0crZK5dDQP0f1QC6kqwoDA'],
#  ['Hold On', 'spotify:track:3wzEd738dNCyyTGDIgHt3k'],
#  ['Sie will es nun mal', 'Not Found'],
#  ['-Tu Jardin con Enanitos', 'Not Found'],
#  ['A Big One', 'spotify:track:5WWs6MA1478saoPOtO1tRb'],
#  ['Whiskey Headed Woman', 'spotify:track:0umEMVeHEb4y3F4pmFlo0P'],
#  ['Get Rid of Her (Previously Unissued)', 'Not Found'],
#  ['Alma Mater', 'spotify:track:658elGePmaXtBTgPwDFi1S'],
# ...

# %%
# Pop humurous bright voice instrumental fast danceable 151
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 6:
        if alldata[i][26] == 13:
            if alldata[i][27] == 15:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 0:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Rot blüht der Mohn', 'spotify:track:51A0W3w2H5yT1EdMXRjbPr'],
#  ['100 kleine feestjes', 'spotify:track:0JK9dhIJvUpVjmSbtHr01i'],
#  ['Robinson Crusoe', 'spotify:track:1RMW6wC8jLWlUjkuQPiyJ4'],
#  ['I Still Love You More', 'Not Found'],
#  ['Tears', 'spotify:track:3964lt4bZK4Sk0azmxaQT8'],
#  ['Mama Talk to Your Daughter', 'Not Found'],
#  ['Hold On', 'spotify:track:3wzEd738dNCyyTGDIgHt3k'],
#  ['-Tu Jardin con Enanitos', 'Not Found'],
#  ['Whiskey Headed Woman', 'spotify:track:0umEMVeHEb4y3F4pmFlo0P'],
#  ['Get Rid of Her (Previously Unissued)', 'Not Found'],
#  ['Alma Mater', 'spotify:track:658elGePmaXtBTgPwDFi1S'],
#  ['What We Live For', 'spotify:track:1KgZOCjN3nGRTk3c87oIj6'],
#  ['Theyre Stealing Our Coal', 'spotify:track:3zcyBeQ8IeeORYhQg4qG0s'],
#  ['You Gotta Dance With Who You Came to the Dance With',
#   'spotify:track:22AdYxaCjx0CIkNJlzdIgF'],
#  ['Honey', 'spotify:track:7uJhE8ZmWcysVFeq5KLDSL'],
#  ['The Other Me', 'spotify:track:3ZmNfbBidTEvMOgJ7ylCdy'],
# ...

# %%
# Pop humurous bright voice fast not_danceable 79
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 6:
        if alldata[i][26] == 13:
            if alldata[i][27] == 15:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Wait', 'spotify:track:2sWj9oQNvqv8abqqQn02RF'],
#  ['Full Circle', 'spotify:track:0OQTIY7qPwyufiVZV3XIYi'],
#  ['Nothin to Do but Today', 'spotify:track:64rJx6rGpqGAwF4jHuKQKa'],
#  ['Tzena, Tzena, Tzena', 'spotify:track:0crZK5dDQP0f1QC6kqwoDA'],
#  ['Sie will es nun mal', 'Not Found'],
#  ['A Big One', 'spotify:track:5WWs6MA1478saoPOtO1tRb'],
#  ['Lie With Me', 'spotify:track:6ipiRzTQszraswbO9E4RM3'],
#  ['Triple Crossroad Blues', 'spotify:track:7pdNgsFcMKLiRC4cRWCREV'],
#  ['Lightning', 'spotify:track:2EzmA3zhDBN96EKvnZ7sOe'],
#  ['Please Listen to Me', 'spotify:track:63vkuzKsHKGa21ZpHhE5sV'],
#  ['In a Rainbow', 'spotify:track:3CQRxgdbaKXXVXLHBHg7PJ'],
#  ['How the Hell Did They Get There', 'Not Found'],
#  ['Flash a Hungry Smile', 'spotify:track:6nilz2zvJXMZSM7yJKsilq'],
#  ['Shady Grove', 'spotify:track:5tyFD6SXPUEvNOp9MWcyUl'],
#  ['Big Road Blues', 'spotify:track:1EhF1Qr6ceoPue1yhNdR89'],
#  ['Steel Drivin Man', 'spotify:track:6zzrUpvyZKvsFb950iQxi2'],
# ...

# %%
# Pop humurous dark 102
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 6:
        if alldata[i][26] == 13:
            if alldata[i][27] == 16:
                list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Car Crash', 'spotify:track:2rC9oaV3lthiRcokhTeuo9'],
#  ['Life in the Sea', 'Not Found'],
#  ['Uptight (Everythings Alright)', 'spotify:track:1fsiq3Ix887BYsN4JY3Ghz'],
#  ['Lenore (I Miss You)', 'spotify:track:301vBX8QwmxVD4xx5eb03X'],
#  ['Fragän', 'Not Found'],
#  ['On My Feet Again', 'spotify:track:7BmzwtB8dhCAKXPktK6Rzc'],
#  ['Hes Comin (video edit)', 'Not Found'],
#  ['Last Night the Sky (instrumental)', 'Not Found'],
#  ['Without A Word', 'spotify:track:27cYq2mKEktEnWnYNXW1h9'],
#  ['Válka', 'spotify:track:382HuCZ3hNeV73FV4thYLC'],
#  ['Beyond Words (feat. Burhan G)', 'spotify:track:2yU0r9p3EPtvU0TSCIDd82'],
#  ['Coal Into Diamonds', 'spotify:track:5sqEco0YX4Jm1J3ie8h39Y'],
#  ['Rascalize', 'Not Found'],
#  ['Chémia pokračuje', 'Not Found'],
#  ['Follow That Dream', 'spotify:track:0EkwlBGDj4h1UkVuWpSLK2'],
#  ['Rack My Mind', 'spotify:track:2jyBWoVMuv3Na7fsN1q7x6'],
#  ['Once You Got It', 'Not Found'],
#  ['Get Back', 'spotify:track:59Xb5YkZ1AFrMD19T6cKr8'],
# ...

# %%
# Pop aggressive bright instrumental fast danceable 312
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 6:
        if alldata[i][26] == 14:
            if alldata[i][27] == 15:
                if alldata[i][28] == 17:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 0:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Love', 'spotify:track:5PVtbnMD6Q5x6fSSOHw9LS'],
#  ['The Enemy', 'spotify:track:71GL8hwI9SpDds3ZNlcwsH'],
#  ['Der Mann mit dem Koks ist da', 'spotify:track:1uyRSXTaiadBsRtcXGVWzg'],
#  ['Castaway', 'spotify:track:2WDctLpTaE2REFotpZznB3'],
#  ['Jukeboxin luona', 'Not Found'],
#  ['Beast', 'spotify:track:34AAdGo3vKl59Dj4H8tXzW'],
#  ['LÉléphant', 'Not Found'],
#  ['Swoon (Boys Noize instrumental)', 'spotify:track:2Cjo3SUfKpB8RsWGWBJhAG'],
#  ['Sleep Wont Sleep', 'spotify:track:0QSldFlIEIsMzsTdopuulR'],
#  ['China Girl', 'spotify:track:5Ei9o2fHEnfHb84YrPuz4v'],
#  ['Burning Up', 'spotify:track:48YZhmKL3aZKhQUfpvkelu'],
#  ['Widow of the Web', 'spotify:track:1LA2zLkhmTw8wSekT6KrSo'],
#  ['Traccia 01', 'Not Found'],
#  ['The Renaissance Man/Rebirth', 'spotify:track:6rYY9SvAPaKl2mKKzfwRyp'],
#  ['No Kisses on the Mouth', 'spotify:track:5kZ3H3vlG6S1DUzCBNvAe4'],
#  ['Section 60', 'spotify:track:4wBWwIgRRrdoPF2eSEqChL'],
#  ['Mach Auf', 'Not Found'],
# ...

# %%
# Pop aggressive bright instrumental fast not_danceable 174
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 6:
        if alldata[i][26] == 14:
            if alldata[i][27] == 15:
                if alldata[i][28] == 17:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Is She Ready', 'spotify:track:0XVQ6yagMmNUDhXcclV6jm'],
#  ['Calling You', 'spotify:track:0UWpLly9sG9qr7srZHSQ2f'],
#  ['Tenesh Kelbe Lay', 'spotify:track:5qJKkCBUCpFVYwvehqMktS'],
#  ['Le Cose Che Vivi', 'spotify:track:7qNtV5oSvYLPOlvWjRQ0qa'],
#  ['Djinamory', 'Not Found'],
#  ['Kuvat', 'spotify:track:5fBNJVNkJ97gayI63eL6d1'],
#  ['I Will Burn', 'spotify:track:0YfTefxEFITnzI8AUo3ooJ'],
#  ['Master Blaster (jammin)', 'spotify:track:5EAgXGJ8Kw5QAfhQkZXYqT'],
#  ['Silver Screen', 'spotify:track:7LYeJyJoAOBFNUNlCMhSQZ'],
#  ['Nothing Is Real but the Girl', 'spotify:track:0kbylTPh23TzIf5zvofLku'],
#  ['The Girl That Taught Me To Drink And Fight',
#   'spotify:track:0MVNeZWIhxlTRzJq3d4nIO'],
#  ['Alien (Live)', 'spotify:track:6hQ7pog9YAxFWaIjAcbiBb'],
#  ['Las cosas que vives', 'spotify:track:0Kk7mbNEkBHO8AMc08g9cY'],
#  ['Не больно-больно', 'spotify:track:2ispT5WF5UmG1bkXV7pjIZ'],
#  ['Stockport', 'spotify:track:4KL4tNheGNqRtOI70ukI7T'],
# ...

# %%
# Pop aggressive bright instrumental slow 103
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 6:
        if alldata[i][26] == 14:
            if alldata[i][27] == 15:
                if alldata[i][28] == 17:
                    if alldata[i][29] == 20:
                        list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['07_Masters Of Illusion', 'Not Found'],
#  ['Camouflage', 'spotify:track:4bxjjysA7lmrBb01oVQLYv'],
#  ['What Goes Around Comes Around', 'spotify:track:77KgAUE6wQBIOP6xX2lJJp'],
#  ['Part One: Jazz', 'Not Found'],
#  ['Uncle Jam', 'Not Found'],
#  ['Julius (Live)', 'spotify:track:0c5zLASnvI7Ls31hIIlmJ3'],
#  ['Impressions', 'spotify:track:7bEMkHBJgPCK5HZ4g0TRJY'],
#  ['Heavens Tears', 'spotify:track:0CvXuqo69CXWFXgwTM1FfI'],
#  ['La Telecabine', 'Not Found'],
#  ['Chromium', 'spotify:track:1yH4vofZZxiL7bbwXi9B3b'],
#  ['Dobilutėlis', 'spotify:track:4Ir6fQA7n9wHjpCvrQ4hJ8'],
#  ['Goin Down the Road', 'spotify:track:19kZKCZr6DSrkpYZV6EgoI'],
#  ['Penicillum', 'spotify:track:1S5pB52Rk2FooRWj9mdxpK'],
#  ['What Does It Take (To Win Your Love)',
#   'spotify:track:3wHrCLE8i1lfqIxXv8ssVS'],
#  ['Pieśń emigranta', 'spotify:track:02kHneqfB3ngYyMsaAl7Z0'],
#  ['Charisma Kommando', 'Not Found'],
#  ['Fiesta', 'spotify:track:1F9zEi0OpO83PSEEhOhJh5'],
# ...

# %%
# Pop aggressive bright voice fast danceable 411
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 6:
        if alldata[i][26] == 14:
            if alldata[i][27] == 15:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 0:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Mr. Blue', 'spotify:track:13qKrEKwPLmIz30uOoG5Rr'],
#  ['Seven Whole Days (live)', 'spotify:track:0be6Gi3PUhx1rT1hqFCUhI'],
#  ['Wilhelm hat’s schwer', 'spotify:track:2fIYZAkdkPiA0b1xGsjW17'],
#  ['Romeo and Juliet', 'spotify:track:1ecKBIADlXbSI9ek5FKEIb'],
#  ['Its Only Dancing', 'spotify:track:7wrjhTFYrgYvaexaZpoShe'],
#  ['Wenn Dein Spiegel bricht', 'spotify:track:3Q5pOHN2IiqtUq58VvaaCC'],
#  ['Mickey Mouse in Moscow', 'spotify:track:5NXJ6HaHhsHM4HuGrVLVfV'],
#  ['The Show Must Go On', 'spotify:track:4ASh12wEh5N8KqGM0r8e3P'],
#  ['Karma Police', 'spotify:track:3SVAN3BRByDmHOhKyIDxfC'],
#  ['Even Better Than the Real Thing', 'spotify:track:4bK2vKMdkS0rNhbzRqAZe0'],
#  ['Stronger Than That', 'spotify:track:5j4SxeNANGaNRbxZHaU6I9'],
#  ['Tragedy', 'spotify:track:3Yqk2pdNJUtI7VOtweASV8'],
#  ['You Win My Love', 'spotify:track:2lKA9bNdd4kAoeHiufa0aK'],
#  ['Горючее', 'spotify:track:6J4NHm6DZUcQf4Dg9M4QDJ'],
#  ['Dither', 'spotify:track:2sNGX06BuSld1GhUE4L16B'],
# ...

# %%
# Pop aggressive bright voice fast not_danceable 155
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 6:
        if alldata[i][26] == 14:
            if alldata[i][27] == 15:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['The Coming Rains', 'spotify:track:58VEb8apv7edAilqu6FDOW'],
#  ['Weigh It Down', 'spotify:track:6WXuicKNAad2WuUx1Ku4VH'],
#  ['liebe war es nicht', 'Not Found'],
#  ['You Showed Me (electric version)', 'Not Found'],
#  ['8_Welcome To Paradise', 'Not Found'],
#  ['Nočná optika', 'spotify:track:4dRhCFTsOYJKsF0KR9bvoG'],
#  ['Осень', 'spotify:track:3MHwbvByC1oMMKfh3DH7Gs'],
#  ['Hold Me Forever', 'spotify:track:6mWMYAg242pZuxdR3vlETW'],
#  ['Intersecting Hypocrisy', 'Not Found'],
#  ['True Blue Love', 'spotify:track:0QUZYtRJ7dGe8fY9iuHd5E'],
#  ['Не звезда', 'Not Found'],
#  ['Please Let Me Wonder', 'spotify:track:0rttThNJX5cZLtQUASghA7'],
#  ['Undercover Cowboy', 'spotify:track:1WR7mS8ThyXabWJgKlZpe3'],
#  ['Restless', 'spotify:track:73nYjLyEtNZHRyDtIFFQIC'],
#  ['Solo con te', 'spotify:track:5r9QUxvWA5sJPt3rPNyrzj'],
#  ['Glad Man Singing', 'spotify:track:6JyXh6XtthTly0c6KXD99r'],
#  ['Here Comes the Hotstepper (Allaam mix)',
#   'spotify:track:48jdIkvRLnbcvkX2hWZVFn'],
# ...

# %%
# Pop aggressive bright voice slow 158
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 6:
        if alldata[i][26] == 14:
            if alldata[i][27] == 15:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 20:
                        list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Not Enough Time', 'spotify:track:4nwgKaHg9TJahiSSmt3X1x'],
#  ['Kiss you', 'spotify:track:3FGcQkWQlkeB82RdZwlw8V'],
#  ['Give a Little Love', 'spotify:track:4bRjjCJ7KUm6dJVbSrbosE'],
#  ['We Dream The Dreams About Dreams', 'Not Found'],
#  ['Postcard Poverty', 'spotify:track:36E7Vmu5DKkQztjqNL4NZr'],
#  ['This Night', 'spotify:track:26yBhQ2br7yo0A3CE31XLn'],
#  ['Crazy (James Michael mix)', 'spotify:track:27cJHbsqx5idVLRZ4f5VsN'],
#  ['Reeperbahn (2)', 'Not Found'],
#  ['Worried About', 'spotify:track:5KSGz3QIGfoGctpDjD2Z1k'],
#  ['Daisy', 'spotify:track:6YmO4aElYRmtA7q5NpYVX6'],
#  ['Nada es fácil sin tu amor', 'spotify:track:0tWlRdfVtfcUNqFpTL2LVP'],
#  ['Without You Here', 'spotify:track:2OetRiA7svb9KwiXkRjhLw'],
#  ['Jeremiah Blues, Part 1', 'spotify:track:3GUjoxCRyjfAgBJ5dxUMwo'],
#  ['Het gaat maar door', 'spotify:track:1gKX9JViAvmztrDCObmv4e'],
#  ['Galileo', 'spotify:track:5k6PqEbyX3NT4oTMJn2tj6'],
#  ['I Name You Sleep', 'spotify:track:5ElMHEG9uMIUujgpay4XRd'],
# ...

# %%
# Pop aggressive dark instrumental fast danceable 301
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 6:
        if alldata[i][26] == 14:
            if alldata[i][27] == 16:
                if alldata[i][28] == 17:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 0:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Malmaison', 'spotify:track:74duuaLBZOCz3tf0Svbd9o'],
#  ['Hey Ho on the Devil’s Back', 'spotify:track:4Cbghsi8vmIrUOUgSRN6bt'],
#  ['Colony 5', 'spotify:track:7AnB7mFwyn1eqGJEy9G1WG'],
#  ['Set Me Free', 'spotify:track:5WxN2yKWRmiaNThdMmuSxr'],
#  ['At the Station', 'Not Found'],
#  ['It Happened Today', 'spotify:track:45B5CrwbDC749O3P1NT4Ha'],
#  ['Let It Be (feat. Veela)', 'spotify:track:4ChBLndekjzQveHPsn3r6W'],
#  ['Main Titles', 'spotify:track:3at4HxXO8SAJsiaOc72Xtv'],
#  ['Allimbrunire', 'Not Found'],
#  ['Power to the People', 'spotify:track:7dTFUnfqXMqK3Qu0TjIIHC'],
#  ['March of the Pams', 'spotify:track:0FR9R8TbPSdnT92pFh8bSv'],
#  ['Cachaca', 'spotify:track:5NNcksW8D9MgEWCFpT0MCk'],
#  ['Neverland', 'spotify:track:2RYOOtEcnJZK5YSpeVLuMW'],
#  ['Inchtomania', 'Not Found'],
#  ['Stürm', 'spotify:track:0V3gfWeWyJQkIsWYF6XVHL'],
#  ['The King Will Come (live in Genf)', 'Not Found'],
#  ['Sister Apocalypse', 'Not Found'],
# ...

# %%
# Pop aggressive dark instrumental fast not_danceable 575
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 6:
        if alldata[i][26] == 14:
            if alldata[i][27] == 16:
                if alldata[i][28] == 17:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['8 Years', 'spotify:track:0VDMoqr0eW5yJ8vrnyt7Ac'],
#  ['My Skateboard!', 'spotify:track:34yI0ZsVU1BOM4kH55HUvv'],
#  ['Sally Was a Legend', 'spotify:track:7giTMRSwcETCrIbCDv1L3p'],
#  ['Electric Blues', 'Not Found'],
#  ['Blakey Ridge / When the Waters Meet',
#   'spotify:track:1SZWPeC9UIYABgYHXsyhMZ'],
#  ['Faith in Something Bigger', 'spotify:track:7vZ1vjNYC8PFfQbtYF8t4J'],
#  ['Puella! Puella!', 'spotify:track:3IcjDSOKP2spL8xM9s0CCu'],
#  ['The Willing Well IV: The Final Cut',
#   'spotify:track:7fEu3L69PUzcrIkyn0HPhy'],
#  ['Cousin Randy', 'spotify:track:7KNKQGlbEjijpUSDUl3yJh'],
#  ['We Do Wie Du', 'spotify:track:1YqnVgzk9CEu8iOmcIy5J4'],
#  ['Daylight', 'spotify:track:4MRDF26fDhkRDjnCQV9K10'],
#  ['Harem in Tuscany (Taranta)', 'spotify:track:1bNKdb6QOKWPCbaxlsSRna'],
#  ['Run Like Hell', 'spotify:track:2okMt0c1OIweHsuCAOqep1'],
#  ['Youth Serrated', 'Not Found'],
#  ['Evil Wind', 'spotify:track:3blJeTyKbTHGATyyvN4ScK'],
#  ['Восстанем', 'Not Found'],
# ...

# %%
# Pop aggressive dark instrumental slow danceable 114
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 6:
        if alldata[i][26] == 14:
            if alldata[i][27] == 16:
                if alldata[i][28] == 17:
                    if alldata[i][29] == 20:
                        if alldata[i][30] == 0:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Years Go By', 'spotify:track:1ILE0PIo6qoRYo0DhdLggi'],
#  ['Dämmrung senkte sich von oben', 'spotify:track:1x8Qp3vmiNXtWYegLr7xq8'],
#  ['Out From the Deep (rock version)', 'spotify:track:3BLlv43nqS3FocjI5WvLe7'],
#  ['Love Me Harder', 'spotify:track:5J4ZkQpzMUFojo1CtAZYpn'],
#  ['Lakkal (Watch Out) (feat. Eric Krasno)', 'Not Found'],
#  ['Ultraviolet Arms', 'spotify:track:4hE49mZgMPPRRqKwHGSWyk'],
#  ['Esto está que arde', 'spotify:track:5fhgt7g6SlCrQd7bD8gPT6'],
#  ['Abi Virus (Feat. SPL, John Zorn & Masada String Trio)', 'Not Found'],
#  ['Affliction', 'Not Found'],
#  ['Im So Small', 'spotify:track:2J1XaTR86Wp4s8CfvdhiCX'],
#  ['Ixion', 'Not Found'],
#  ['Hot House', 'spotify:track:5BNuyjZ4TGwD7UYNaxOtnG'],
#  ['Schwaches Gift', 'spotify:track:3lxoqI98CVApTXPbdYFjqS'],
#  ['Jesus Is Cumming', 'Not Found'],
#  ['Out of Tunes', 'Not Found'],
#  ['A New Day', 'spotify:track:34sv4ChJ4mkBXuaE9AMK2j'],
#  ['Paleta', 'spotify:track:6Z6OuBpZiViRiXveZqAUqH'],
# ...

# %%
# Pop aggressive dark instrumental slow not_danceable 231
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 6:
        if alldata[i][26] == 14:
            if alldata[i][27] == 16:
                if alldata[i][28] == 17:
                    if alldata[i][29] == 20:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Two Continents', 'spotify:track:1jPoFXkGPFFEx1wBimhJG8'],
#  ['In 3 Minutes Till Massacre', 'spotify:track:07HVD4ysnPKQATSM2uHhUD'],
#  ['To Hell We Ride', 'Not Found'],
#  ['Barricades in Time', 'spotify:track:2CM3D31ioFSBnF9jmEHvM6'],
#  ['Telling Ghosts (Giorgia OQueef mix)',
#   'spotify:track:2iHXHBMKkWbY9bBIVEz8cq'],
#  ['For a Lifetime', 'spotify:track:5AEmJJyKVnWyVtO1xa9PaJ'],
#  ['Get It Hot', 'spotify:track:7Dgb3HyF79QbOE3BeGJPg0'],
#  ['The Remedy', 'spotify:track:0lciJolA7URnsCRbc4zMxX'],
#  ['Death March', 'spotify:track:3nUgynzGy7RQgQNuN1myum'],
#  ['Red Money', 'spotify:track:3xfvgzz6erOPTFGZFrr45F'],
#  ['Street Wars', 'spotify:track:5MATf9MyxVbxp8Oz4AJms2'],
#  ['We Ride Together', 'spotify:track:7Ii4DF7AfbZUOlIfbq4gZ0'],
#  ['Ether', 'spotify:track:4FGSwIiszfJ8kl9SRWBdlE'],
#  ['Pray', 'spotify:track:1luVSQzb1LtLWxFd9xNDYL'],
#  ['Your Saviour', 'Not Found'],
#  ['Hypocrite', 'spotify:track:6pm0v6XZoxlqVL6JaUpasm'],
#  ['サスペンス劇場', 'Not Found'],
# ...

# %%
# Pop aggressive dark voice fast danceable 303
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 6:
        if alldata[i][26] == 14:
            if alldata[i][27] == 16:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 0:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Les Programmeurs', 'spotify:track:7MZHvdgfqahhWxw73B6byP'],
#  ['Intro', 'spotify:track:3JX35kwMAXdbsLNoOI5jn7'],
#  ['Wash Jones', 'spotify:track:455CnhhqXCgFugNXkX1gmI'],
#  ['Work to Do', 'spotify:track:6CZd52tAm2Cms0px3idmoc'],
#  ['Music Is My Boyfriend', 'Not Found'],
#  ['Pray (acoustic album version)', 'Not Found'],
#  ['Smokin Trees', 'spotify:track:4RCaUsivNKd7AcN94gBIfk'],
#  ['MVP', 'spotify:track:6opKYwz2L0zSyIrZpNfcoK'],
#  ['Bez tebe', 'spotify:track:3nym6r7ywM13gNdhA1ised'],
#  ['Like Tears in Rain', 'spotify:track:6p4ERQrrTzsreil7ggsuy4'],
#  ['Khyber Pass (TX Bush Ranch mix)', 'spotify:track:5fYHsFWRbGqLdbqZo1AMNp'],
#  ['Pandemonium', 'spotify:track:6gZ8xTPOVYyYFh6mYKivG0'],
#  ['Ive Been Losing You', 'spotify:track:5pzEYTNR667VbDAUmMpF0S'],
#  ['Denial', 'spotify:track:0r8Dmv67rVsQBLYqWjWwmg'],
#  ['Cold Army (feat. Gabriel Wolf-Infra Black)', 'Not Found'],
#  ['Dream On', 'spotify:track:5MxNLUsfh7uzROypsoO5qe'],
# ...

# %%
# Pop aggressive dark voice fast not_danceable 127
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 6:
        if alldata[i][26] == 14:
            if alldata[i][27] == 16:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Free My Heart', 'spotify:track:0q1YJ2dLmVT8thmJvv0ynl'],
#  ['Title Card', 'spotify:track:1bJju9nvuxhk88FxCmd8Er'],
#  ['Kid 2000 (edit)', 'Not Found'],
#  ['People of America', 'spotify:track:0bUvRyhsULSXsLTsRFfqMN'],
#  ['Under the Bridge', 'spotify:track:1AK5AYYFRCnd6qKrmh1N5t'],
#  ['Kt Event', 'spotify:track:0xu6CuS0QbJnPzdGT8NfIt'],
#  ['Sukellan humppaan', 'spotify:track:6GlW6rDY5eXPNozgCbIj1S'],
#  ['Ajos de gata', 'Not Found'],
#  ['This Used to Be the Future', 'spotify:track:5dAb93ruKNKj2RX0X5fkEQ'],
#  ['R.O.C.K.-Rock', 'spotify:track:0pyNCNnSzqtJOTFtCTkSO7'],
#  ['Be Natural', 'spotify:track:4oxjE2HOQEouXj6BPnum51'],
#  ['За мной', 'spotify:track:1neWPwirR2IbKHcMnXUEdC'],
#  ['This Is Halloween', 'spotify:track:1CYjYSg9sdtbBoxSf8uhFD'],
#  ['Sugar', 'spotify:track:7vuMqTpIsWljCDlAhsgPBd'],
#  ['Istanbul', 'Not Found'],
#  ['Wings', 'Not Found'],
#  ['Samson', 'spotify:track:4qUAUrNJACbDByCfx6vwyD'],
#  ['Elephants', 'Not Found'],
# ...

# %%
# Pop aggressive dark voice slow danceable 137
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 6:
        if alldata[i][26] == 14:
            if alldata[i][27] == 16:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 20:
                        if alldata[i][30] == 0:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Respect Yourself', 'spotify:track:0fPp6mSq6zZKpOPbefXyBS'],
#  ['Do It Again', 'spotify:track:564eifpC3REPrL8nlHzlyQ'],
#  ['Deadbeat', 'spotify:track:0jf4YGL2GLIgPVy1ZQAU8Q'],
#  ['Static In The Flow', 'spotify:track:44U9UnJfdnkzDGuuVpHsTY'],
#  ['You Sent Me Flying', 'spotify:track:2Zrnqh5nA5lYeiehF23Nu7'],
#  ['Morpheus', 'spotify:track:5yQJkVnqvlam7sDua0JJ2K'],
#  ['Marathon (Ft. Floetry)', 'Not Found'],
#  ['Empty Skies', 'Not Found'],
#  ['Hell and Back', 'spotify:track:4EptRLpFrAIeiCrdKXs7Ef'],
#  ['Als wären wir für immer', 'Not Found'],
#  ['Universe', 'spotify:track:6s6SiM2Es1Fl8KtWdiannH'],
#  ['I Wont Give In', 'spotify:track:5MuWGLrqeqYEcpqWMq5M1w'],
#  ['Run (Run Run Run)', 'spotify:track:4FZh4eCn12tSZsf0iXQkRQ'],
#  ['Viva Life on Mars', 'Not Found'],
#  ['Cityboy', 'spotify:track:1h2YoicpE6x8yiDroArV3z'],
#  ['Ghost', 'spotify:track:1Sao6YuJ4c133gemipn2lg'],
#  ['Slave to the Rhythm', 'spotify:track:3di2SUB3jU1v5HPQCkc84L'],
# ...

# %%
# Pop aggressive dark voice slow not_danceable 55
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 6:
        if alldata[i][26] == 14:
            if alldata[i][27] == 16:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 20:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Niečo sa chystá', 'spotify:track:6hW292JgJUv5eQnirmgw08'],
#  ['Dead Wood Falls', 'spotify:track:7agxxUtpgE3kl5RhSQy9YD'],
#  ['My Recipe For A Happy Life', 'Not Found'],
#  ['Fathers House Lament', 'Not Found'],
#  ['Tangerine', 'spotify:track:5FXN0PrlVKqOIboUgFDqPC'],
#  ['Thats Why God Made the Radio', 'spotify:track:7bmiIJ98JjFCNwH27LUKSv'],
#  ['Cosmic Slop (single edit)', 'spotify:track:5u6i7rf8dNYbKZ5Gl7spoR'],
#  ['Burning Circles in the Sky', 'Not Found'],
#  ['Two Fingers', 'Not Found'],
#  ['Shallow Then Halo', 'spotify:track:0x2k5tosNNyGDWZpCcGmWQ'],
#  ['The Last Straw', 'spotify:track:3Av5ZMS1Oqvm8wHNZo8KOk'],
#  ['증오는 나의 힘', 'Not Found'],
#  ['Demonstrate', 'Not Found'],
#  ['Running in Place', 'spotify:track:2RZ0Zh2mMKJ087T58vWt6V'],
#  ['Get Up Jonah', 'spotify:track:4OQ0spO8aahuosVBTRMX9s'],
#  ['Mr. Raven (2012)', 'spotify:track:48H4KeN5CraD6wEJDHPmsq'],
#  ['Nocturnal Eden', 'Not Found'],
#  ['Atlas', 'spotify:track:6nRA8R7JZehi3On88EX52Y'],
# ...

# %% [markdown]
# # Rhythmic Playlists

# %%
# Rhythmic passionate 56
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 7:
        if alldata[i][26] == 10:
            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Slim Jenkins Place', 'spotify:track:277pHePclnKynKdg73t9pI'],
#  ['Boo Bop da Caa Caa', 'spotify:track:6ZcN9AFsu2G88NkKKHEz8w'],
#  ['In the Skies', 'spotify:track:526nHQfF4e5fqr6I2WwyVE'],
#  ['Interlude', 'spotify:track:3Ofnd2LjZYnS07vZwRKKE4'],
#  ['(Come Round Here) Im the One You Need',
#   'spotify:track:5YvokzRkNONpj5c0TIqTjQ'],
#  ['On the Sly', 'spotify:track:31tb6wb9huKJmZHyyXjPNK'],
#  ['Intro', 'spotify:track:6EoVcpxq70VFTrMGNzc6LR'],
#  ['Mouvement: The Flesh Is Weak', 'spotify:track:7MWs6CbwGUPW0n5qbk1dUP'],
#  ['Intro', 'spotify:track:0g8NBqc7h9EuUMtcPXjayT'],
#  ['Sweet Lew', 'spotify:track:5UZQLBnip2GdQBknnckQBr'],
#  ['Mama, ik snap je', 'spotify:track:2UzrLqqstaiCP4GzPWblOR'],
#  ['Coco', 'spotify:track:2JI71GHwq2LN8mtq3iCLYo'],
#  ['Lawdy Mama Version 1', 'Not Found'],
#  ['Candyland, Part 1', 'spotify:track:4XaLfMgltkHpiHQTTNOifb'],
#  ['Шамбала', 'spotify:track:5BVKo2uLBrQgr9PTA4EfWc'],
#  ['Interlude', 'spotify:track:5YFjY9FVE43k7FKMVWiUbP'],
# ...

# %%
# Rhythmic cheerful bright instrumental fast danceable 70
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 7:
        if alldata[i][26] == 11:
            if alldata[i][27] == 15:
                if alldata[i][28] == 17:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 0:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Tired Robot', 'spotify:track:0HBvmZX9GGiHYpyJCZ7Rz8'],
#  ['Clavier-Büchlein Für Anna Magdalena Bach 1725: Menuet G-Dur, BWV Anh. 116',
#   'Not Found'],
#  ['Arabian Song', 'spotify:track:2gdxQeDjYxCxYvKqEOqFZv'],
#  ['You’re So Tight', 'Not Found'],
#  ['Bastille blues', 'Not Found'],
#  ['100 Lb. Weight', 'spotify:track:4JGONOylWr9r7lZBhDnYl3'],
#  ['Lee Harvey Oswald', 'spotify:track:6OhXJqkMvZ4vGuY4RIBl2R'],
#  ['Smoking Japanese (Sweat mix)', 'Not Found'],
#  ['Jump The Fence', 'spotify:track:2MAfa1iNMnGmcG38mTOvc9'],
#  ['Loves in You, Loves in Me', 'spotify:track:7KaNnqFZJsjDxgkOSUYLYV'],
#  ['Goin Outta Business', 'spotify:track:7fJs3ZT2Qk9Y6KbCtJEwlp'],
#  ['Reinlender i Det norske hus', 'spotify:track:6GVXFGNXgKXGDLHVKUXVrl'],
#  ['Ring of Fire (remix)', 'spotify:track:3mYubREXUB4tTAYFT0TvX0'],
#  ['Only the Lonely', 'spotify:track:1BZMMt9H0TheQGWQy44KmO'],
#  ['No Raise No Praise', 'spotify:track:7LFRoJxG7NBc52s1GpIhMu'],
# ...

# %%
# Rhythmic cheerful bright instrumental fast not_danceable 86
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 7:
        if alldata[i][26] == 11:
            if alldata[i][27] == 15:
                if alldata[i][28] == 17:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['I Wont Last a Day Without You', 'spotify:track:42CX3VhPsCG75BFp07r9Vj'],
#  ['Cant Stop the Girl', 'Not Found'],
#  ['Double Clutch', 'Not Found'],
#  ['Anything', 'spotify:track:7deJzxo1XDdvd9eMA3Ce9m'],
#  ['Letter to Heaven', 'spotify:track:4W1IDU9yyt04eQPJNI0a1O'],
#  ['Hey, Thats No Way to Say Goodbye', 'spotify:track:2acZx9K8kOdLkO52yF2sgf'],
#  ['Song of India', 'spotify:track:4ou73CMygT62S9gubMZxIe'],
#  ['Colour March', 'spotify:track:3jYQ89DUasmHbvSm2lQXxc'],
#  ['Strawberries Dress', 'spotify:track:3hvbTc49HHViANwFVc6s8i'],
#  ['Simple Assembly', 'spotify:track:1p1WylpPvaqxjfFxk7hFmw'],
#  ['The Star of the County Down', 'spotify:track:3r8Mgef6iL58ME1Srfm3cR'],
#  ['Love So Right', 'spotify:track:2rVxsVGLFssDfM5B9BUL0K'],
#  ['Living on an Island', 'spotify:track:1ulyxZ2uSxtl3oqZqcRFoL'],
#  ['Five Hearts Breaking', 'spotify:track:6zBIsVPOtEO5YvmaEMrcRJ'],
#  ['Downtown', 'spotify:track:3vhgQ5Y8Y8NyHdwhLSNxxL'],
# ...

# %%
# Rhythmic cheerful bright instrumental slow danceable 72
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 7:
        if alldata[i][26] == 11:
            if alldata[i][27] == 15:
                if alldata[i][28] == 17:
                    if alldata[i][29] == 20:
                        if alldata[i][30] == 0:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Next To You', 'spotify:track:2M7fA5L6zH9oxq53WsaYB4'],
#  ['Light Me Up', 'spotify:track:6pQfHpMKbKsUIFHu2jQ2jW'],
#  ['Please Dont Hurt My Baby', 'spotify:track:5QYkNGQPJc3C9EnzLfIual'],
#  ['Dont Pick Me for Your Fool', 'spotify:track:5J4wvQOBG936QRJXNPKNpn'],
#  ['Can We', 'spotify:track:2GpR7fKshezuroONNvp0Mp'],
#  ['Thethings I Used to Do', 'Not Found'],
#  ['Stand in Front of Me', 'spotify:track:6VaCm70vKXOoieQ82kBED0'],
#  ['Then I Knew', 'spotify:track:6a2XXG7tnVFZ3g4YlvSn2f'],
#  ['History', 'spotify:track:2nMoYVrfWFf22OW8SmKDId'],
#  ['Quest for Thrills', 'Not Found'],
#  ['I Feel It All (Escort Remix)', 'spotify:track:4TrhIhkCG9EeB54JgcP7Ff'],
#  ['Fall Again (Feat. Robin Thicke)', 'Not Found'],
#  ['Anima', 'Not Found'],
#  ['Lines Between Us', 'spotify:track:21eBmWaItv4lQ8fjuESuuW'],
#  ['Another Day in Paradise', 'spotify:track:4AYhsnQ43KBckV3RBagFPJ'],
#  ['Camille', 'Not Found'],
#  ['Treasure Island', 'spotify:track:1jfJQGdgaULxfI4EQIs0in'],
# ...

# %%
# Rhythmic cheerful bright instrumental slow not_danceable 78
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 7:
        if alldata[i][26] == 11:
            if alldata[i][27] == 15:
                if alldata[i][28] == 17:
                    if alldata[i][29] == 20:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['World Of Trouble', 'spotify:track:6cpQ9NBM9uv2lJM3vQH38x'],
#  ['Biggest Mountain', 'spotify:track:6LvJguWhNCbFcJu8qzUTPD'],
#  ['Down Yonder (We Go Ballin)', 'spotify:track:2AxEvZfRqFkQvFiq2EWJ62'],
#  ['Бомбей', 'spotify:track:2U5v5rwyBXDSRJ45QPqvXs'],
#  ['Goodbye Robbie', 'spotify:track:2KwyAh6K9ySO8UBQDSkI0x'],
#  ['Ground Expansion', 'Not Found'],
#  ['Down on the Corner', 'spotify:track:1G94iOtvExyCWSYja7PQeF'],
#  ['The Runner', 'spotify:track:202Jzt8Vd0Si9FsgYynbLt'],
#  ['Hold on II', 'spotify:track:6xC3ho4Md5aS9ilV1aupK2'],
#  ['Ive Never Found a Girl', 'spotify:track:6aTTKGTp7E5QjjDdq1ZoOV'],
#  ['Rising, Rising (Bassnectar remix)', 'spotify:track:1gnumv6nuMJjuadZbRSoqU'],
#  ['If I Love You', 'spotify:track:2CFFZgiQKMpbez6ApdUADd'],
#  ['Just Aint Gonna Work Out', 'spotify:track:2jJulR1CTEuHsXpS6bGDou'],
#  ['Erica moody', 'spotify:track:14ImfuCoNxrvjNJ26UsInt'],
#  ['Tell It Like It Is', 'spotify:track:2ClfhEMRWE7LrEwsDIYoXe'],
# ...

# %%
# Rhythmic cheerful bright voice fast danceable 176
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 7:
        if alldata[i][26] == 11:
            if alldata[i][27] == 15:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 0:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
len(list1)
# Out:
# 176

# %%
# Rhythmic cheerful bright voice fast not_danceable 466
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 7:
        if alldata[i][26] == 11:
            if alldata[i][27] == 15:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Mind Your Business', 'spotify:track:6MogZKDqwPROGFksZYGVs1'],
#  ['Howzat!', 'spotify:track:0ErrB0366clNbfso4Ns69t'],
#  ['Zeg me wie je ziet', 'spotify:track:1tsu97ivWfIzfwb3p4d9bh'],
#  ['Ou Ryperd', 'spotify:track:02CdafySiW9JoKIXb5RheG'],
#  ['Put Your Lovin On Me', 'spotify:track:6pMifJgApqpeN91OqVCgvy'],
#  ['The Flight of the Dove', 'spotify:track:1bBcBZ2U7CIjqtpAmgBfxp'],
#  ['Memorial Drive', 'spotify:track:12TvkB2WdNJfsKPZ7P8v2a'],
#  ['What a Wonderful Thing Love Is', 'spotify:track:6vNYzKRCHP6LcRh0RprXLi'],
#  ['Ya plus dhiver', 'spotify:track:5xGGdXRFNpEQRipzzT6dYY'],
#  ['Ive Been a Long Time Leaving (But Ill Be a Long Time Gone)',
#   'spotify:track:0r8dEfqyiVgAPSv2Q6grMy'],
#  ['What Am I Worth', 'spotify:track:0lkTmfPDMXzLcIDMcIZzK2'],
#  ['Streetrunner', 'spotify:track:3d6JW3CS0hMIwRFJLwIFPc'],
#  ['Rosewood Casket', 'spotify:track:05VGcvK4bs4eQBdTaNwpra'],
#  ['Innocent   ', 'spotify:track:3E2V9AD4BHrIp6y3rkvwEI'],
# ...

# %%
# Rhythmic cheerful bright voice slow danceable 240
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 7:
        if alldata[i][26] == 11:
            if alldata[i][27] == 15:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 20:
                        if alldata[i][30] == 0:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['You Can Run But You Cant Hide', 'spotify:track:02odV6Pm0Jj3UkRlEwaOJb'],
#  ['Just One More Morning', 'spotify:track:5bCmP09ZobLXHvHfSUeKhx'],
#  ['I Keep Telling Myself', 'spotify:track:4WVgytpxZ2AjXKXkTenX4a'],
#  ['95', 'spotify:track:3kKwXmY6vhSAMshFVFfixy'],
#  ['Boo Bop da Caa Caa', 'spotify:track:6ZcN9AFsu2G88NkKKHEz8w'],
#  ['Help Me Dr. Dick (The First Aid remix)',
#   'spotify:track:2TeuxDTZMr4jDfZBar5ljD'],
#  ['02 - Mio fratello', 'Not Found'],
#  ['Lets Get Smooth', 'spotify:track:06qlwjcgYNrqa4NBIr1J6r'],
#  ['If You Go Away', 'spotify:track:1cqRcHG4qduO5GRtf0pS63'],
#  ['Does He Love You', 'spotify:track:35XU5n3C1kNk1N0PiZ7seX'],
#  ['Keep On Running', 'spotify:track:4DLLx77IXv3lY0oWK7q5mx'],
#  ['Epistel 68 Movitz, I Afton Står Baln', 'Not Found'],
#  ['Anteeksi', 'spotify:track:2wTozT2TahxGhASaoKXZxc'],
#  ['Ann-Maria', 'spotify:track:5iIgEc3CcBqyI95je0LD98'],
#  ['No Woman No Cry (remix instrumental)', 'Not Found'],
# ...

# %%
# Rhythmic cheerful bright voice slow not_danceable 304
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 7:
        if alldata[i][26] == 11:
            if alldata[i][27] == 15:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 20:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Get Down', 'spotify:track:6L7F7H2m63jmgDYHmQ9IrR'],
#  ['Castles in the Air', 'spotify:track:1Wogzzn5mF1JgE9EeCGyu0'],
#  ['Nice', 'spotify:track:7smL88GiM3r29W67eyJSpz'],
#  ['Please Believe Me', 'spotify:track:1bplAGC76JxwTltR5pX4pE'],
#  ['Saturday Night', 'spotify:track:4FVo181bAKBEA4e1aMBtP1'],
#  ['Isole del sud', 'Not Found'],
#  ['I Put a Spell on You', 'spotify:track:3uEF0fPk6LQUMl6n0V8fdi'],
#  ['There Are More Questions Than Answers',
#   'spotify:track:5nM8blXSt3gaZYdfL4UA32'],
#  ['When a Man Loves a Woman (master)', 'Not Found'],
#  ['Always Wanting You (1974)', 'Not Found'],
#  ['California English, Pt. 2', 'spotify:track:2U90b6durzAnQZgIjWdhjP'],
#  ['Dim, Dim The Lights (Live)', 'spotify:track:4ujmLHnhtMGfuLdtXWou42'],
#  ['Out of Words', 'spotify:track:20uiL4h9hRIndPkcuHABOe'],
#  ['Strangers in the Night', 'spotify:track:1eKvUumt07s6WfD2F5sLB4'],
#  ['My Rosalie', 'Not Found'],
#  ['Comme Une Blessure', 'Not Found'],
# ...

# %%
# Rhythmic cheerful dark 352
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 7:
        if alldata[i][26] == 11:
            if alldata[i][27] == 16:
                list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Shoulder To Shoulder', 'spotify:track:70NCYyk61Lsa9W1U1A1JLW'],
#  ['Rexs Blues (Townes Van Zandt)', 'Not Found'],
#  ['Santas Coming Over', 'spotify:track:3zwW3wfJtRcOsE2SQot0B5'],
#  ['Kiss', 'spotify:track:5yS9sEq26OjXsoko8MItE8'],
#  ['Live by the Water', 'spotify:track:73SISEo89cSxFh4RvujZqv'],
#  ['Intro', 'spotify:track:2dnRDUmizj7MG8FRpjbQga'],
#  ['Going Home', 'spotify:track:4a1dvKHMBg9PQTJBZrMjKJ'],
#  ['Lone Child', 'spotify:track:4vbw65Ws2kbbOvGwk9Y8xw'],
#  ['Du courage', 'spotify:track:3ClCjmBe5b3BUkI2rzTp0i'],
#  ['Liebes Lied (single version)', 'Not Found'],
#  ['Tomorrow Is Like Today', 'spotify:track:4JvGfLC72K87wa9e8SlP3Z'],
#  ['Was fuckt mich das jetzt alles ab', 'spotify:track:1hEf9YygUmxbaSGg7o29cj'],
#  ['Kaint', 'spotify:track:51SmvSeNicfc5wdpQzUvAT'],
#  ['Love Me Less', 'spotify:track:0MvN2K16kSWcaj0mfjmitr'],
#  ['Beat::Skip (NutnBerry remix by Prince of Tennis)', 'Not Found'],
# ...

# %%
# Rhythmic bittersweet bright instrumental fast danceable 96
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 7:
        if alldata[i][26] == 12:
            if alldata[i][27] == 15:
                if alldata[i][28] == 17:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 0:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Hide Away (alternate version)', 'Not Found'],
#  ['Mirza', 'Not Found'],
#  ['Loneliness', 'spotify:track:6SlWCurtdulduFHCzTbKKJ'],
#  ['Intentions', 'spotify:track:0jZFuP4AOr2QlFrvbglkqD'],
#  ['Civilized Man', 'spotify:track:3EHrDbDcaIN43do5S5lbug'],
#  ['He Dont Live Here No More (songwriting version)', 'Not Found'],
#  ['Tricentennial', 'spotify:track:51zFYYxpDBfQBg8yjEVJuc'],
#  ['Woman in the Dark', 'spotify:track:5obLfh7cx4tkl5lV6U1F2Q'],
#  ['Frozen Boy', 'spotify:track:4c6T49BVWK9MFB6ZONOOEY'],
#  ['Giamonios', 'spotify:track:2wbnKCaZrCLXJS5f1b7NTc'],
#  ['Swamp River Days', 'spotify:track:0eZhcBGQnYTFzNbjOZgw5A'],
#  ['Bye Bye Love', 'spotify:track:0mQzdLsJFULP2EmRoWT3M0'],
#  ['Poison Trees', 'spotify:track:2WyPgtBv1kwtG3tpO4kC1d'],
#  ['If I Had a Mountain', 'spotify:track:3O6MDBkjANed9l8Zt3j93J'],
#  ['Kulkuri', 'Not Found'],
#  ['À lombre de Bumcello', 'spotify:track:7KVXEoSMk47dGRvxi8nmqZ'],
#  ['Night Nurse', 'spotify:track:4DQttwipnILl88cru3BRZx'],
# ...

# %%
# Rhythmic bittersweet bright instrumental fast not_danceable 236
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 7:
        if alldata[i][26] == 12:
            if alldata[i][27] == 15:
                if alldata[i][28] == 17:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Ice Cream Man', 'spotify:track:2zaHTFarVLY6BOrxxAjhIU'],
#  ['I Will Be Blessed', 'spotify:track:4PFhGZLzpWQk7CumiCyNH7'],
#  ['Olé hiljainen kaupunki', 'Not Found'],
#  ['Macarthur Park (Revisited)', 'spotify:track:0YSMBdWMOxmIWWkFzBefTY'],
#  ['Mind Body Soul', 'spotify:track:26J2HZuOsCGr1A6HdwcynU'],
#  ['Droptop', 'spotify:track:5RuxXDsQEEnhgkwVGTzpzV'],
#  ['Two Streaks of Steel', 'spotify:track:1932Q6A57P2cAIypaanN9P'],
#  ['Main Title', 'spotify:track:4SnXMlF03pGItpNkxZ6iaj'],
#  ['Two Sides to Every Story', 'spotify:track:4VWgLesWikHFf9hdCSJjob'],
#  ['Звёздочка', 'Not Found'],
#  ['Hello', 'spotify:track:0jTx7OoVLTm1aderzw9wGN'],
#  ['De Store Smerte', 'spotify:track:03VRyOVlVtuWJnSLTa0evK'],
#  ['Revelations', 'spotify:track:1WyJGWIPi2FTH2p4jenS2M'],
#  ['Cosmicon', 'spotify:track:2b1colagvBkeEjBA8gmhzk'],
#  ['Simple Directions', 'spotify:track:0xBL2wXhKgfbuCcOXr4T9H'],
#  ['Again (Cuffia remix)', 'Not Found'],
#  ['Shadows on the Street', 'Not Found'],
# ...

# %%
# Rhythmic bittersweet bright instrumental slow 141
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 7:
        if alldata[i][26] == 12:
            if alldata[i][27] == 15:
                if alldata[i][28] == 17:
                    if alldata[i][29] == 20:
                        list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Green Light', 'spotify:track:1ZWGPl1GTZPdOR6lE6ghzw'],
#  ['Floras Song', 'spotify:track:7sjll4p96C3uU4poAK9xtF'],
#  ['Spacy Country', 'spotify:track:7oMfpYkcmKi3myvmaOWaff'],
#  ['Saudosa Maloca', 'spotify:track:7jCvNfmgEod3IU1yiIRP7W'],
#  ['Dont Know Why', 'spotify:track:0xw6MY59Mdx5GJAVAuomaS'],
#  ['I Cant Help It (If Im Still in Love With You)',
#   'spotify:track:6rWctWxNcImOuzSIt07rcB'],
#  ['Manda dHayye', 'spotify:track:4DiBNiiVflhKHqeqnYvgJX'],
#  ['I May Not Be A Star (Light Piece For Vanessa) (Previously Unreleased)',
#   'Not Found'],
#  ['Korsika', 'spotify:track:3zIbrPiY8VG7pRYZ1dg4Ll'],
#  ['Adiós, Mi Corazón', 'spotify:track:4hgDlkOhMJ7uVAq0auCiNq'],
#  ['Replicas', 'spotify:track:2AVE84sk5qWuDr4TvakARM'],
#  ['Lucys Talking', 'spotify:track:4tTV11MEfDfuJSJOeeTrIx'],
#  ['Fridge', 'spotify:track:5RhGvGj5rrSqZQyxFSlwZw'],
#  ['Raining in My Heart', 'spotify:track:3BNZqcKefd2AfMdfojlQSf'],
#  ['Bvongodza Muto', 'spotify:track:7M2FUugkyPnZIwhEf5u7yi'],
# ...

# %%
# Rhythmic bittersweet bright voice fast danceable 214
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 7:
        if alldata[i][26] == 12:
            if alldata[i][27] == 15:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 0:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Youve Got the Love', 'spotify:track:6u9RqxALwkjJ1ukB1y8vuP'],
#  ['Sabine Largam', 'spotify:track:22G6dmOx4yTC7nAIwm8VIg'],
#  ['Ultraviolet', 'Not Found'],
#  ['Die Mutter ist immer dabei', 'spotify:track:5DDBm4VvVJ3ega0HQfznQi'],
#  ['Money Make Me Come (featuring EbonyLove)', 'Not Found'],
#  ['The Wolf And The Butter', 'Not Found'],
#  ['This Love, This Love', 'Not Found'],
#  ['Faith', 'Not Found'],
#  ['One Wish', 'spotify:track:5qrzhg9Fmu8Amg2uMhHfe5'],
#  ['Sem você', 'spotify:track:3zVJiKrw0IL98eWsLFtVYv'],
#  ['Heart of the Matter', 'spotify:track:5RE8TJLPabUd3yFNAqP1Ik'],
#  ['Wolke 4', 'spotify:track:6RxnOMdjeegcAnHoeecudU'],
#  ['Someday (Youll Want Me to Want You)',
#   'spotify:track:5DqG1wmfKUnlkUOUDo31hI'],
#  ['Boppin the Blues (single version)', 'Not Found'],
#  ['Jeune de cité', 'spotify:track:37KB1KtECGveclnb2Rx6N5'],
#  ['Čas odejít', 'Not Found'],
#  ['Slow Jam', 'spotify:track:0VdSyCb1n7F5G0XkePzAlf'],
# ...

# %%
# Rhythmic bittersweet bright voice fast danceable 708
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 7:
        if alldata[i][26] == 12:
            if alldata[i][27] == 15:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Afraid', 'spotify:track:7fCFecvXW9lHZoEX9bJPlX'],
#  ['Madman', 'spotify:track:2Yadv7FwqvLGyJjWqKnrHr'],
#  ['Andorra (alt. version)', 'Not Found'],
#  ['Muddy Waters', 'spotify:track:5IOMr4Bqo4t4rc9LakROYL'],
#  ['What Child Is This? (vocal)', 'spotify:track:7aCBUtAz41DQHKUGydks0m'],
#  ['No Story To Tell', 'spotify:track:7ho8f1HRtjrl62uD6JkGpu'],
#  ['Which Will', 'spotify:track:1on0uQvTRnTJRxXH7fbTI1'],
#  ['Love to the People', 'spotify:track:4ek7VT7ZoA2sBUBrC8Gdf3'],
#  ['Lay Lady Lay', 'spotify:track:4uYwlMp841PLJmj1gJJwIq'],
#  ['So Whats New', 'spotify:track:58cDp1U9CejUWErQNsul6O'],
#  ['Thief', 'spotify:track:0II6nWTRkBZ2VnusGqokJ7'],
#  ['Two-Way Lovin', 'Not Found'],
#  ['La Voix du Bon Dieu', 'spotify:track:3U1WIfm1jdSUTOSaUo89Cd'],
#  ['Six Ribbons', 'Not Found'],
#  ['All I Needed', 'spotify:track:7c94QbwtCWPd7sjM8p3a8z'],
#  ['Babette', 'spotify:track:4VeadsXSZEhsH2ZthHLFEt'],
#  ['Lost', 'spotify:track:5zqh7XZa0Wk8EAPqq88fTA'],
# ...

# %%
# Rhythmic bittersweet bright voice slow danceable 142
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 7:
        if alldata[i][26] == 12:
            if alldata[i][27] == 15:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 20:
                        if alldata[i][30] == 0:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Wie Das Wohl Wär', 'spotify:track:5PPy76hkysMHwaaZiEQCm5'],
#  ['Dubaddisababa', 'Not Found'],
#  ['Wave of Mutilation (UK Surf)', 'spotify:track:2KSSbWLAWSzaso01DEP32W'],
#  ['Way Down South', 'spotify:track:3yW3Z07mfc7QalayOPksY0'],
#  ['Hairdo', 'spotify:track:1EKGPbTFaI1xdzD2DpG7Lt'],
#  ['Epelo', 'spotify:track:3ikpmYvqXnmbzig1zeyYuh'],
#  ['Плюс 28', 'spotify:track:4Hyku94RoZ9a4v0LzOIIcj'],
#  ['Land Called Far Away', 'spotify:track:5B4AWiUGjzYxRzAzJT1dT8'],
#  ['This World Is Crazy', 'spotify:track:72PCioDxOHdq2EbIzBebOk'],
#  ['Always the Winner', 'spotify:track:2W87PrrQsce7workm1oHvJ'],
#  ['Aint Nobody', 'spotify:track:2NVpYQqdraEcQwqT7GhUkh'],
#  ['Until the World Stops Spinning', 'spotify:track:4wLIWnjZbGFbmpSe85Xnxy'],
#  ['If I Only Had a Brain', 'Not Found'],
#  ['Please Judge', 'spotify:track:5pLGa6LrNcknsiSWccDTb4'],
#  ['Upside of Down', 'spotify:track:5rh9FdiBbKWSNn8dpemlL8'],
#  ['Rocking Time', 'Not Found'],
# ...

# %%
# Rhythmic bittersweet bright instrumental fast not_danceable 236
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 7:
        if alldata[i][26] == 12:
            if alldata[i][27] == 15:
                if alldata[i][28] == 17:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Ice Cream Man', 'spotify:track:2zaHTFarVLY6BOrxxAjhIU'],
#  ['I Will Be Blessed', 'spotify:track:4PFhGZLzpWQk7CumiCyNH7'],
#  ['Olé hiljainen kaupunki', 'Not Found'],
#  ['Macarthur Park (Revisited)', 'spotify:track:0YSMBdWMOxmIWWkFzBefTY'],
#  ['Mind Body Soul', 'spotify:track:26J2HZuOsCGr1A6HdwcynU'],
#  ['Droptop', 'spotify:track:5RuxXDsQEEnhgkwVGTzpzV'],
#  ['Two Streaks of Steel', 'spotify:track:1932Q6A57P2cAIypaanN9P'],
#  ['Main Title', 'spotify:track:4SnXMlF03pGItpNkxZ6iaj'],
#  ['Two Sides to Every Story', 'spotify:track:4VWgLesWikHFf9hdCSJjob'],
#  ['Звёздочка', 'Not Found'],
#  ['Hello', 'spotify:track:0jTx7OoVLTm1aderzw9wGN'],
#  ['De Store Smerte', 'spotify:track:03VRyOVlVtuWJnSLTa0evK'],
#  ['Revelations', 'spotify:track:1WyJGWIPi2FTH2p4jenS2M'],
#  ['Cosmicon', 'spotify:track:2b1colagvBkeEjBA8gmhzk'],
#  ['Simple Directions', 'spotify:track:0xBL2wXhKgfbuCcOXr4T9H'],
#  ['Again (Cuffia remix)', 'Not Found'],
#  ['Shadows on the Street', 'Not Found'],
# ...

# %%
# Rhythmic bittersweet bright voice slow danceable 426
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 7:
        if alldata[i][26] == 12:
            if alldata[i][27] == 15:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 20:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Heartbreak Hotel', 'spotify:track:1t9ZDYo0cWqD24hYkv4vaV'],
#  ['Mr. Bojangles', 'spotify:track:0A4KAZPslogFqWNuLcm5WC'],
#  ['Say It (Over and Over Again)', 'Not Found'],
#  ['Der Knabe im Moor', 'Not Found'],
#  ['Getting Used to Losing You', 'spotify:track:3SxIQ6rZmDIk8L9ZpYWEOy'],
#  ['Schraders Filmpalast', 'spotify:track:6YU4qnZJMO9kTXtDTr1M3c'],
#  ['Private Sorrow', 'spotify:track:6xTQTYLIbzC0TLoSe2H4ve'],
#  ['All Out of Love', 'spotify:track:7dQC53NiYOY9gKg3Qsu2Bs'],
#  ['Get Back in the Saddle', 'spotify:track:6OmhKxJ2vEupoux264HofV'],
#  ['Boukay', 'Not Found'],
#  ['Twenty-Points (The Ballad of Sexual Dependency)',
#   'spotify:track:1wMobuxsVs1aFoC75xLjN5'],
#  ['I Wish I Was Eighteen Again (live)', 'Not Found'],
#  ['Around the Bend', 'spotify:track:7jIANvGKV3F6omPTX8UEhI'],
#  ['Milk Cow Blues', 'spotify:track:37WsJ4osU50jLuszrwbO2T'],
#  ['Today I Started Loving You Again', 'spotify:track:1U4jSJmNhszdZMoCdPrsbL'],
# ...

# %%
# Rhythmic bittersweet dark instrumental fast danceable 117
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 7:
        if alldata[i][26] == 12:
            if alldata[i][27] == 16:
                if alldata[i][28] == 17:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 0:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Islands', 'spotify:track:4KWBSmOecDOUONthIBAHND'],
#  ['Thump, Cry', 'Not Found'],
#  ['Never Met Her', 'Not Found'],
#  ['I Thought I Knew You Well', 'spotify:track:6slGXPQGJAKN09iFldjQu2'],
#  ['Leading To Death', 'spotify:track:7dCABSnJPPnemtd43EZI6e'],
#  ['Tape Rock', 'spotify:track:3M2SLkzFTTg7jFmD58zWxX'],
#  ['Veins', 'spotify:track:27Ksddpw1cjyZnrWLFmBQ2'],
#  ['En ausencia de ti', 'spotify:track:0I2feE3ac2r9QFhi6y4MDx'],
#  ['Improvised Jam', 'Not Found'],
#  ['The Crumb', 'spotify:track:2eKhXqaV92N71khuBk0Sj7'],
#  ['Passing Through the Heart', 'Not Found'],
#  ['Daze of the Weak', 'spotify:track:3PSJQyJ4Z57ptOAMKdaXuK'],
#  ['Jason Phones It In', 'spotify:track:2KM3lNJyLDEGZbgSmBO0cO'],
#  ['Path 5 (Clark Remix / Edit)', 'spotify:track:1898uLV2yCQK4zgQSSsLjW'],
#  ['Marc Antoine - Universal Language - 06 - N.Y. Strolling', 'Not Found'],
#  ['Black Girl', 'Not Found'],
#  ['These Nights Never End', 'spotify:track:1kV6GozWS0azRJeR4REW6N'],
#  ['Chickpea', 'Not Found'],
# ...

# %%
# Rhythmic bittersweet dark instrumental fast not_danceable 162
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 7:
        if alldata[i][26] == 12:
            if alldata[i][27] == 16:
                if alldata[i][28] == 17:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Cool Waves (String Session mix)', 'Not Found'],
#  ['Columbus Avenue', 'spotify:track:0gxKcbfN88tl2pgLU7HX5v'],
#  ['His Behavior Inspired Us With Distrust', 'Not Found'],
#  ['Matilda', 'spotify:track:5c3AHuo6VAgMyAbi7Vk2Uh'],
#  ['Клофелин', 'spotify:track:3YmI6hKivhqMjDb7ANyRQz'],
#  ['This Moment Is Golden', 'spotify:track:26oigx5D8D8lNmhDqOcLrw'],
#  ['Ticks & Twitches', 'spotify:track:5NiG5po0Cnx1y9pAkd4TaO'],
#  ['Faltered Fractions', 'spotify:track:70sjhBmi8t3pcRVAeczmF0'],
#  ['Chorale', 'spotify:track:7rbYtyPOMsTJNrjcBtcCPc'],
#  ['Tokyo Late Night', 'spotify:track:3Yu6KXOfdgny5XCx3Cfcp8'],
#  ['California Revisited', 'Not Found'],
#  ['Face to Face', 'spotify:track:1zBWn4eAu1PAJyx6UK5ni7'],
#  ['Connor’s Life', 'spotify:track:6nAlSE3qRnRZPqf4Mo9iNJ'],
#  ['Exhibit 13', 'spotify:track:0Pq0ySxydSjl6UYjEc78B0'],
#  ['Broken Radio Echo', 'spotify:track:71Sck2XNaxGs5eqKA9CrO4'],
#  ['Ess', 'spotify:track:1WGJ88sBlpXnhmzo3gfmex'],
#  ['As We Watch the West', 'Not Found'],
# ...

# %%
# Rhythmic bittersweet dark instrumental slow danceable 79
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 7:
        if alldata[i][26] == 12:
            if alldata[i][27] == 16:
                if alldata[i][28] == 17:
                    if alldata[i][29] == 20:
                        if alldata[i][30] == 0:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Goost', 'spotify:track:70rqG0yXHzqOQ0wWBbEaKI'],
#  ['Left Speaker Blown', 'spotify:track:0ZvFzPWnl2LM7MdieMubnM'],
#  ['Worker Ant Uprise', 'Not Found'],
#  ['Bleach Black', 'spotify:track:6SiOnvow9sVln2ARUtGBI1'],
#  ['Homme', 'spotify:track:3yD1shRTOXi7V4evCDxkHx'],
#  ['Slo Drone', 'Not Found'],
#  ['Break Them Down (instrumental)', 'spotify:track:0ephlsHGvg6pXPnorfW65n'],
#  ['Deep Summer', 'spotify:track:6o7UY9nor78yKEtQoMvyhD'],
#  ['M. Dupont', 'spotify:track:5PVGKs7sAoDdK0cvMDaKqR'],
#  ['Dont Try So Hard', 'Not Found'],
#  ['Transcended', 'Not Found'],
#  ['Looking for Quiet Seeds', 'spotify:track:0CoOeK4Szkt2PjT7EYzdNB'],
#  ['Camp Bird Mine', 'spotify:track:2DCq33Lr1XwTXeYHxHJCuj'],
#  ['Dinoh Dinoh', 'spotify:track:4Pbc0ffFvRPxEKfxmNHe0f'],
#  ['Girl Next Door', 'spotify:track:6gQGtbb2Yhbg2XqD0WYyZq'],
#  ['Sick', 'spotify:track:3cGyD41slrGW1e6UZnBlxf'],
#  ['Lack of Dub to the Brain', 'spotify:track:2nrYALEEuqlrFWTq4TDNWv'],
# ...

# %%
# Rhythmic bittersweet dark instrumental slow not_danceable 99
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 7:
        if alldata[i][26] == 12:
            if alldata[i][27] == 16:
                if alldata[i][28] == 17:
                    if alldata[i][29] == 20:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Interstellar', 'spotify:track:5UOrr7d3H1VV53knXl8p6w'],
#  ['Must Fight Current', 'spotify:track:44DqQ9vITd9LFEIYsOD9DZ'],
#  ['Hearing Voices in Ones Head', 'spotify:track:4t4nDQfLdoqQC2fpN1TJkO'],
#  ['Forever', 'spotify:track:0aAAjxCX8BuhcILhnqYoHi'],
#  ['Part I: Mindslide', 'Not Found'],
#  ['A Moment in the Sun (interlude)', 'spotify:track:6tgTHxL7xbE2zuToXw8ZdX'],
#  ['Emilys Poem (alternate take)', 'Not Found'],
#  ['Sophonisba', 'Not Found'],
#  ['Container Ships', 'spotify:track:1P8M1bHfjTOO5MlshlXhT3'],
#  ['The Drowning of St Christopher', 'spotify:track:5OJFe9cH72wmtLhiYSwWsq'],
#  ['Forgive Me', 'spotify:track:0ydaRbRvXAcY5bgom5JEZF'],
#  ['Tears for ASIMO', 'spotify:track:4z7mMjjzXj6VkFmAq3i7gN'],
#  ['Passage', 'spotify:track:6WnhYwLIDSxcZSQFSMMKuD'],
#  ['Not There', 'spotify:track:0s563YgQqZDw7GIGHkGMoi'],
#  ['Coastline', 'Not Found'],
#  ['Arachidog', 'Not Found'],
#  ['Umami', 'spotify:track:1PxjlnJJUrrbJ8TxKyLhgZ'],
# ...

# %%
# Rhythmic bittersweet dark voice fast danceable 93
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 7:
        if alldata[i][26] == 12:
            if alldata[i][27] == 16:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 0:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Jeszcze sen', 'Not Found'],
#  ['Come Into My Life', 'spotify:track:0Gms0Ad9iBfwoInbDbSoLn'],
#  ['Komodo (Video Edit)', 'spotify:track:5Nr2HWBHyu50PymtfJ40JB'],
#  ['Too Soon', 'spotify:track:1vykaKN6Ze4mVPSlDZNFB2'],
#  ['Jeres søn', 'spotify:track:73ztZo3oYnwk56sXQHI6l6'],
#  ['If I Ever Fall in Love (remix)', 'spotify:track:58HONnHW8ZvMDb4In757x4'],
#  ['Luna y Sol', 'spotify:track:21sSlNqgdX6n24AiugmMy8'],
#  ['We Had Seen God!', 'spotify:track:5Se05rMqlhXZHSq8Jht3jM'],
#  ['Snowbird', 'spotify:track:0taWysDhIRFvSJ5DWc7oCU'],
#  ['The Rider On The White Horse', 'spotify:track:46LcI0lRjugNJvg7hdB7Gf'],
#  ['Weather', 'Not Found'],
#  ['Transit', 'spotify:track:2ZnDqRYU66DRtwlhjUZYCq'],
#  ['Sovereign System', 'spotify:track:7ru97vYZUFhr6ol5DCem6n'],
#  ['Chronicles of a Fallen Love', 'spotify:track:7xUbaLCX82QXUoFafhfBlS'],
#  ['Set Me Free', 'spotify:track:7x6INkakWgSoTBg80ILzrE'],
#  ['More of a Euphoria (feat. Alori Joh)', 'Not Found'],
# ...

# %%
# Rhythmic bittersweet dark voice fast danceable 169
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 7:
        if alldata[i][26] == 12:
            if alldata[i][27] == 16:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Winter', 'spotify:track:1EOiKIkZJsnFCEsuIsVtMI'],
#  ['Swoon', 'spotify:track:0GdLoLHWxsFSXSzmSYxTMy'],
#  ['Ill Be Around', 'spotify:track:26jR40IsdTesLrckDVGm18'],
#  ['Ive Been Loving You Too Liong', 'Not Found'],
#  ['untitled', 'spotify:track:18qunoZCfSVGf3t539DRjU'],
#  ['The Preppy Pimp', 'spotify:track:7KNflaG3AGJks4DeZuR57J'],
#  ['Georgia (live from Melbourne)', 'Not Found'],
#  ['New York State of Mind', 'spotify:track:6yjKlmm7vOszkXEUku1EM1'],
#  ['Cry Baby Cry', 'spotify:track:5XmetMMUFNXClbiYnGdVmP'],
#  ['All By Myself', 'spotify:track:0gsl92EMIScPGV1AU35nuD'],
#  ['Death Comes in March', 'spotify:track:6CBD5Dulmkz5nJ7UN3C5I2'],
#  ['I Can See the Wind', 'Not Found'],
#  ['Be My Woman', 'spotify:track:3EQppp2wiL5uKivL9VkYHg'],
#  ['Donal Og', 'spotify:track:2r0KR4sDH3oscErQnRO8QU'],
#  ['Someone Told My Heart (1966)', 'Not Found'],
#  ['Gutters Full of Rain', 'spotify:track:7EfTAkUXiXLLRFTteU1j8Y'],
#  ['Be Aware', 'spotify:track:3cNTGb1K0Hz4i6DkIykaEt'],
# ...

# %%
# Rhythmic bittersweet dark voice slow danceable 72
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 7:
        if alldata[i][26] == 12:
            if alldata[i][27] == 16:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 20:
                        if alldata[i][30] == 0:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
len(list1)
# Out:
# 72

# %%
# Rhythmic bittersweet dark voice slow not_danceable 125
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 7:
        if alldata[i][26] == 12:
            if alldata[i][27] == 16:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 20:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Dead Rabbit Hopes', 'spotify:track:1oVk3syQBcgwYef0EEOZAo'],
#  ['Think About You', 'spotify:track:4Y6ykA8iEpXTEmrOPvjBIw'],
#  ['Yes, Im Your Angel', 'spotify:track:6zNfdm9rz8yNeL8B6mCwrQ'],
#  ['Sticks & Stones', 'spotify:track:1ppdJKtMHQErnyXLUxrYX7'],
#  ['Fuir Le Bonheur (Live Au Palace 2009)',
#   'spotify:track:4CkO6BuiqMMHt3w1B0Fwcu'],
#  ['Kristove roky', 'Not Found'],
#  ['Watching The Trains Go By', 'spotify:track:05fkOwCRgGbZgCWmRhV77L'],
#  ['Redeemed', 'spotify:track:3OkHnYO6bSQexjS2mYJ4Aj'],
#  ['Charged With Murder', 'Not Found'],
#  ['Diary Entries Over a Major 7', 'Not Found'],
#  ['Ill Take Care of You', 'spotify:track:5bqaFVXy7NES4MIuDWmPTr'],
#  ['Queen of Hearts', 'spotify:track:3Xk6MdisBGIYplafgbf2QH'],
#  ['Amour de Saint-Tropez', 'spotify:track:3RIgRgMNqWlGWJyeUIBsYp'],
#  ['Hero', 'spotify:track:7c2MDOjnXBIZ5ZGNGPXcyH'],
#  ['Big Louise', 'spotify:track:7A2ZmF9DJRSHQzkzF7ndPE'],
#  ['Coney Island Ride', 'spotify:track:2QQdpAxsrcVEmWOV296cNp'],
# ...

# %%
# Rhythmic humorous 306
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 7:
        if alldata[i][26] == 13:
            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Dont Mess With My Baby', 'spotify:track:4l90z9tZ0YXSRCCUR4Kq6R'],
#  ['Pelastaja', 'Not Found'],
#  ['Dance Wit Me', 'spotify:track:0jWJErPlKX5o9tbcJk644S'],
#  ['Rubbish', 'spotify:track:7edI9Y6jc9bwmzNfi5diBu'],
#  ['Im on My Way to Atlanta (alternate take)', 'Not Found'],
#  ['Dont Be Angry', 'spotify:track:77uoalAAlQiX6ADH6bD4Ib'],
#  ['Cry and Moan', 'spotify:track:59D7rFTBRhGP3jbei7m1sv'],
#  ['Stormstout Brew', 'Not Found'],
#  ['Good Woman, I Hate You', 'Not Found'],
#  ['Cabins', 'spotify:track:3Vsn1i60pr3FxiLlpzr6Zo'],
#  ['Uncloudy Days', 'spotify:track:2SNsnY3uwCYAAAOpdl62oE'],
#  ['Walk Like a Worm, Part 13', 'Not Found'],
#  ['Perfect', 'spotify:track:0FGcrHLP39q3vd0JALN7i3'],
#  ['Through The Pain Ft.Ryan Toby & Claudette Ortiz', 'Not Found'],
#  ['Inside Out', 'spotify:track:7lKcWu0IsA9p7RTxUCyw3H'],
#  ['Goodbye My Love (Verzeih My Love)', 'spotify:track:0ZzY93V2BCF2BZcbDQws7I'],
#  ['The Everlasting First', 'spotify:track:6LeEjpgJ8lttSsGtXBiihA'],
# ...

# %%
# Rhythmic aggressive bright instrumental fast danceable 226
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 7:
        if alldata[i][26] == 14:
            if alldata[i][27] == 15:
                if alldata[i][28] == 17:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 0:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['How Come, How Long (Laws & Craigie Remix)', 'Not Found'],
#  ['Owed To The Dip', 'spotify:track:5cvg4Okeu9bhtFYvguFR7L'],
#  ['Lockdown', 'spotify:track:66tJk1o8nXeYITOWQs06pb'],
#  ['Jumping to the Party (D.J.G. mix)', 'spotify:track:0w0UqGD7E3Wf9wogo7v2Yf'],
#  ['Breath of Life (Swiss mix)', 'Not Found'],
#  ['Collaboration', 'spotify:track:6kcvf7npaePr5XCwiBRJeZ'],
#  ['54-46, Thats My Number', 'spotify:track:1tUyILhqf385u0Mut0esPC'],
#  ['I Gotta Move Out of This Neighborhood/Nobody Loves Me but My Mother',
#   'spotify:track:0goZRZTmQll5Ys7heMvsA7'],
#  ['Release (MAW main mix)', 'Not Found'],
#  ['Canicule', 'spotify:track:6vxxvupfmYp9dJjXIGcYw0'],
#  ['Hear Me Lord', 'spotify:track:3mT1ary1IciE9XJ3saD94A'],
#  ['Bag Lady', 'spotify:track:7BgUcOjSOlKJXASLgJ6bx1'],
#  ['Three Times the Music, Part 3: Western Movement', 'Not Found'],
#  ['Tainted Love (Dakeyne remix)', 'spotify:track:4gg4Juatb3dfoiwR4gXLaC'],
#  ['Chicago', 'spotify:track:3tS932CzD7Wv6BBCqXy5JP'],
# ...

# %%
# Rhythmic aggressive bright instrumental fast not_danceable 226
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 7:
        if alldata[i][26] == 14:
            if alldata[i][27] == 15:
                if alldata[i][28] == 17:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Truth Never Lies', 'spotify:track:0MHuNZCcEyW2Jpzyk9R4D6'],
#  ['Námořnická', 'spotify:track:5ieSZCSMvarrm5zVh52aT3'],
#  ['02 - Astimelusa (Key Chimes Version)', 'Not Found'],
#  ['Red Sky', 'Not Found'],
#  ['Your Latest Trick', 'spotify:track:4UK1g9Z1lWedkmIQuSyCe5'],
#  ['The Front Door', 'spotify:track:4UK7HAqhQ0GOeJnPibJrzJ'],
#  ['China', 'spotify:track:7nb8MyKClJsuw9bzOqs7Ln'],
#  ['To Be Over', 'spotify:track:7h8Jv7VtxSLU5V6e0FAx6e'],
#  ['Eisbaden', 'Not Found'],
#  ['Space Race', 'spotify:track:7trtbYZS2Pj5CjKG8RBQgw'],
#  ['Armageddon', 'spotify:track:1dZ9dy8sOVmBI4G1IuxtJb'],
#  ['Leprechauns Dream, Part 1', 'Not Found'],
#  ['Dance the Devil Back Into His Hole',
#   'spotify:track:3pVt7Auqf4wOgIldJlSskA'],
#  ['The Best of Times (extended version)',
#   'spotify:track:23nm21ENcAg7nC8AWpQKoT'],
#  ['April', 'spotify:track:4f2fzFZJa68j56lPBBFDre'],
#  ['Put the Book Back on the Shelf', 'spotify:track:0QnM29ObB9KShdkfEG2mvN'],
# ...

# %%
# Rhythmic aggressive bright instrumental slow 91
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 7:
        if alldata[i][26] == 14:
            if alldata[i][27] == 15:
                if alldata[i][28] == 17:
                    if alldata[i][29] == 20:
                        list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Down on Love', 'spotify:track:5Eq333iar5SVWfGi2IW7w7'],
#  ['Angel', 'spotify:track:1H5vVq1HPdFI7IitfdCGl5'],
#  ['Truth', 'spotify:track:7Kw4V7ATeEmI7kdMT32WQB'],
#  ['Call Me Satan', 'spotify:track:4VQ5x7bEbdJy2wkIycZtxY'],
#  ['7 Months, 39 Days', 'spotify:track:4HJusmphJxeodZV1vJbrvI'],
#  ['Dont Let Them Control You', 'Not Found'],
#  ['Stiff Jazz', 'spotify:track:07Vp8mqbrIFtj7YgPMnoCE'],
#  ['Entspannung im Dampfbad (remix)', 'Not Found'],
#  ['Ausbruch', 'Not Found'],
#  ['Latona', 'spotify:track:0VdWdKOc89hIgldDdWSJ6R'],
#  ['Top of the Hill', 'spotify:track:5CxdlBKtiB0nqPj1QcIiem'],
#  ['Driftin Blues / Ramblin on My Mind (live at Long Beach Arena, California)',
#   'spotify:track:5sIfH0fIXgKsJgp9qXpxbw'],
#  ['Got Me Going', 'spotify:track:6Qqp1NCiy8Ps6EtOL1yjeb'],
#  ['Fly Like An Eagle', 'Not Found'],
#  ['Never Trust a Woman', 'spotify:track:4oDMie6uCi4KNwWDyISbWm'],
#  ['Pop Ya Collar', 'Not Found'],
#  ['Head High', 'spotify:track:45ew5YfSe3XnEms5aOkptw'],
# ...

# %%
# Rhythmic aggressive bright voice fast danceable 178
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 7:
        if alldata[i][26] == 14:
            if alldata[i][27] == 15:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 0:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Le Barbu Sans Barbe', 'spotify:track:3IjIzt1FOsL0LbpsK6ReMo'],
#  ['A dc Christmas Medley', 'spotify:track:05ktN4x8Rp4rAJwjVIFpUM'],
#  ['Papagaio do futuro', 'spotify:track:3OFjyXcEla8rD1Oxb8tu0Q'],
#  ['Abbaon Fat Tracks', 'spotify:track:4EGO2fsS5KL1Ump7b66MNv'],
#  ['Nothing Without You/Tery Bina (The Dhol Foundation & Fun^Da^Mental remix)',
#   'Not Found'],
#  ['Love of a Lifetime', 'spotify:track:3GhNbHLTEhrZhGOGQKzYpw'],
#  ['Not Right', 'spotify:track:1FGn2qk6qYM3iHuBpBltOc'],
#  ['Youre Always on My Mind', 'spotify:track:4zAxfkmJqsaHqFu1YPMS5a'],
#  ['Kekkonen-rock', 'Not Found'],
#  ['On the Shoulders of Freaks', 'spotify:track:0CQyHB1M05AQglMoXWcl9m'],
#  ['Jesus Oh What A Wonderful Child', 'spotify:track:7zAoR3Od28Xj97fTLgnaGi'],
#  ['Prodigal Son', 'spotify:track:1U1GIOidiZ2SUyLnB4ZIaW'],
#  ['Il Gatto Mangia Il Topo', 'Not Found'],
#  ['Emergency (Dial 999) (extended remix)', 'Not Found'],
#  ['Diamonds', 'spotify:track:0dzOmBFRS4m2x3PL2KMW2U'],
# ...

# %%
# Rhythmic aggressive bright voice fast not_danceable 180
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 7:
        if alldata[i][26] == 14:
            if alldata[i][27] == 15:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Seein Spots', 'Not Found'],
#  ['Lony', 'spotify:track:6KztaoCa5ooeLhNwVrJuuc'],
#  ['Ghost of A Horse', 'spotify:track:5bK7NewSdAX0PjokJDQr9l'],
#  ['Non smetto di aspettarti', 'spotify:track:5l6jyYg0XEOptl5ewXKrjB'],
#  ['In My Dreams', 'Not Found'],
#  ['I Can Feel', 'spotify:track:1hlYmJqPDXh50irBkXar8G'],
#  ['Cobra Moon', 'spotify:track:7fxJEhbvh96daiTbfCSx8P'],
#  ['Preaching Blues (Up Jumped the Devil)',
#   'spotify:track:7uNSAYKVgOUMgXMpovq20W'],
#  ['God Bless the Fool', 'spotify:track:3OFd2shSH88GEOLMHi7VQD'],
#  ['RTZ', 'Not Found'],
#  ['We Ride Tonight', 'spotify:track:66NC7kqsT1KWnvGEYc4wKi'],
#  ['My Christmas', 'spotify:track:0cEvgfwn6OlUdrO3cvzHPc'],
#  ['Here I Am', 'spotify:track:38mMrNPAJKXMBK2l9actEA'],
#  ['Take Me Back', 'spotify:track:0jzZC93GIP2r3vTgyDCr8p'],
#  ['Pay The Fiddler', 'spotify:track:17dFkZwunmLVvxqIat7NLM'],
#  ['High Rise', 'spotify:track:1aSCb1cGnu7EtQlajHOKLj'],
#  ['Niilo yli-mainio', 'Not Found'],
# ...

# %%
# Rhythmic aggressive bright voice slow 107
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 7:
        if alldata[i][26] == 14:
            if alldata[i][27] == 15:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 20:
                        list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['9 to 5', 'Not Found'],
#  ['Gotta Find A Way', 'Not Found'],
#  ['Look at Mary', 'spotify:track:3PJ1h83etFzhO0awXje2Yt'],
#  ['Money', 'spotify:track:3yqOgJjidTSQuNfH7nFvnH'],
#  ['Pedestrian Walkway (demo)', 'spotify:track:1JSk1ynvfqDvcKNhgvQIkU'],
#  ['So Doggone Lonesome', 'spotify:track:10QGw1IQGLaslKp5liNkNL'],
#  ['Great Dane', 'spotify:track:6yLwYDb8M8KbjemmXHcoru'],
#  ['Wir haben ja uns', 'spotify:track:4xOoPNCcKKIVFUVAQU7INw'],
#  ['Do That Stuff', 'spotify:track:2Es7L5xt6GmxZSNoISTW1I'],
#  ['Save Black Music', 'spotify:track:3LxtthwoKrhSpZCLtNjc2D'],
#  ['Oooh', 'Not Found'],
#  ['El Deseo de Tu Amor', 'Not Found'],
#  ['The Levee', 'spotify:track:6T4QqQmSoz4WMLfcLDAxy9'],
#  ['Simple X', 'spotify:track:2arDOcoBX9yJ1XviBVbZzU'],
#  ['Tourbilloner', 'Not Found'],
#  ['Would You Want Me', 'spotify:track:3rYWhEu2SOBeEFLGRTumaK'],
#  ['Runaway Love (Kanye West remix)', 'spotify:track:0esMJjir6P5YsfQinJANmm'],
#  ['Rain', 'spotify:track:4DDHGyE3y6sNGRB4hKBDyF'],
# ...

# %%
# Rhythmic aggressive dark instrumental fast danceable 420
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 7:
        if alldata[i][26] == 14:
            if alldata[i][27] == 16:
                if alldata[i][28] == 17:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 0:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Play the Guitar Boy', 'spotify:track:590KLkT4fEooJaPGDQV9h8'],
#  ['Without The Trees', 'spotify:track:2dDvirernOlspuLkVpl65a'],
#  ['Liquid System', 'spotify:track:1BaE2tWOUI1UhgkCWP9yDw'],
#  ['Five Fathoms (Club 69 Future Club mix)',
#   'spotify:track:02bFsc9GEIQdn5Qz9K5RwF'],
#  ['Electronic Music', 'spotify:track:0AFZ9pf3lWJKrTVDNtnFQm'],
#  ['How Does It Make U Feel', 'spotify:track:17pp4M5TvX4H3fsW3yOqbS'],
#  ['Hot Karl', 'spotify:track:407SRbpODm6grX43kooiZX'],
#  ['07 - Madraykin', 'Not Found'],
#  ['Pitié', 'spotify:track:4lawKowwrC3VwjsP3qV9PY'],
#  ['Seven Petals', 'spotify:track:1dhzgmNP0WhyXztIa7M0WO'],
#  ['Guards of the Gate', 'Not Found'],
#  ['Live from Heart', 'spotify:track:7nzQf1lOLPLUFIcmekZ5vR'],
#  ['To New Shores', 'Not Found'],
#  ['Altered States (Carl Craigs East Side remix)', 'Not Found'],
#  ['07-jonas_bering--wissant', 'Not Found'],
#  ['Drugs', 'spotify:track:3sF9v2qDFDGTyYismssCFI'],
#  ['Mother Fuyer', 'spotify:track:3l1BKvEkgqNfLH3TP4cuqc'],
# ...

# %%
# Rhythmic aggressive dark instrumental fast not_danceable 789
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 7:
        if alldata[i][26] == 14:
            if alldata[i][27] == 16:
                if alldata[i][28] == 17:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Eros (remix)', 'spotify:track:3z5VLYMOSBO4KGZR6C6rWZ'],
#  ['Agate Scape', 'spotify:track:6mf31IXOpo1WYlcUFO3lOJ'],
#  ['Hope I Never Find Me There', 'spotify:track:0h79qzX931TOUg8kB8qbNc'],
#  ['Akasha', 'spotify:track:53Pnxus2L9YTZuvu4lb9a2'],
#  ['House of Cards', 'spotify:track:3Jc6X15OZCCyhGSHBF4hwB'],
#  ['Position', 'spotify:track:2c8kj8BKDC6kFWNcDO20eH'],
#  ['Leaving Behind...', 'spotify:track:0spRNk4hcv6rQ8BVAQlJN9'],
#  ['The Queen Symphony: III. Adagio', 'spotify:track:2gGuLk6BB7TGXeOhYlAWIT'],
#  ['A King and a Queen', 'spotify:track:4Zg89DzBZH6oFfnMuff812'],
#  ['Épisode 5', 'Not Found'],
#  ['Whisk', 'spotify:track:2cOC02uKidQQkUd6TLDsOx'],
#  ['Nevergreen', 'spotify:track:6DsGpDGIDRv8EFGgW10T1p'],
#  ['When I Live My Dream', 'spotify:track:4xHp0sbeXzc8U8GKnKAaFd'],
#  ['Virðulegu forsetar, Part 1', 'Not Found'],
#  ['They Cant Feel Anything', 'spotify:track:3FXjIQfl832rtK9LrjdG3q'],
#  ['Lost at Sea', 'spotify:track:6NIgxWqQcOAP2uFTwkQM2a'],
# ...

# %%
# Rhythmic aggressive dark instrumental slow danceable 140
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 7:
        if alldata[i][26] == 14:
            if alldata[i][27] == 16:
                if alldata[i][28] == 17:
                    if alldata[i][29] == 20:
                        if alldata[i][30] == 0:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Inflation Blues', 'spotify:track:0efgt5sBNXJpSpNgLqwQXr'],
#  ['Evil Roots - Part III', 'Not Found'],
#  ['Mouvement: Shielded by Death / Suspended in Light',
#   'spotify:track:0hyW2NwMkHayPsxaiqPlIb'],
#  ['Qué Onda Guero (Islands remix)', 'spotify:track:2tFilynNIVWtwtwXWPgGPa'],
#  ['Budapest Eskimos', 'spotify:track:0UyePAZAztpBjA9sKMhKfz'],
#  ['The Genesis', 'spotify:track:4N0olzsMpr5cAPFrzNErGv'],
#  ['The Heart', 'Not Found'],
#  ['Bad Up', 'Not Found'],
#  ['New Life', 'spotify:track:2hogcC0rx7pVgjvTr6CBbP'],
#  ['Never Fade Away', 'spotify:track:41toJESaEkOBhBO6qM1Fyp'],
#  ['Holoscene', 'spotify:track:5cUVkeAq4fZBt7WRtvtQQm'],
#  ['B-Boys in the Cut', 'Not Found'],
#  ['Guts', 'spotify:track:0rKqM0SRNtXBcelKBsdkca'],
#  ['Born To My Soul', 'spotify:track:2pEQcIsO8E0RcwUtnzkoi1'],
#  ['18 Long Way', 'Not Found'],
#  ['Modular Existence', 'spotify:track:2JlrDlxBLSYMFGq1SLLTeU'],
#  ['Good Day to Die', 'spotify:track:6FkRO5GF3EpCnaaoxy3h5a'],
# ...

# %%
# Rhythmic aggressive dark instrumental slow not_danceable 278
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 7:
        if alldata[i][26] == 14:
            if alldata[i][27] == 16:
                if alldata[i][28] == 17:
                    if alldata[i][29] == 20:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Living Room', 'spotify:track:33l7cBLgsmjIrLMziJL3Ma'],
#  ['Memories of Old Days', 'spotify:track:3H6D435PGLo2mN2rfdHYSW'],
#  ['Short Pig', 'spotify:track:5JE2JAgbTjhXuidbYfBM5m'],
#  ['Mr. Skulls New Years Eve Song', 'Not Found'],
#  ['Go Slowly', 'spotify:track:4gq2bc2770XvbJdEtfUbmw'],
#  ['MAKE UP YOUR MIND', 'spotify:track:57lsrKp924qzkACV5IVzIG'],
#  ['Close Encounters of the Third Kind (Theme)',
#   'spotify:track:2hKovQCqsluuBsPHC4Z7de'],
#  ['8 - Part I', 'Not Found'],
#  ['Basin Street Blues', 'spotify:track:2BzTgusoJPLgxapEF3guIf'],
#  ['What Are You Wearing Tomorrow (Summer Songs)',
#   'spotify:track:3sHmMR8nP7fP4ygfLlXFwF'],
#  ['Eternity', 'spotify:track:2oO5OrzKmENxna997IvisN'],
#  ['On Your Wings', 'spotify:track:4ieqyL4M2nh1kfQ4tddVRx'],
#  ['Roy (Back From the Offworld)', 'spotify:track:1lwvVGEp2k8VJGcssk9Xpc'],
#  ['Set the Fire to the Third Bar (feat. Martha Wainwright) (feat. Martha Wainwright)',
#   'Not Found'],
#  ['Christmas Wont Be the Same This Year',
# ...

# %%
# Rhythmic aggressive dark voice fast danceable 174
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 7:
        if alldata[i][26] == 14:
            if alldata[i][27] == 16:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 0:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['11 - Tabla TalkinDub', 'Not Found'],
#  ['Woo Bi', 'Not Found'],
#  ['Natures Fruit', 'spotify:track:3lDWuqdYRuliDW5r7Vyswd'],
#  ['Good Enough', 'spotify:track:7H5AlHvNK6H2KADlv4G9W4'],
#  ['If You Only Knew (Feat. Syleen', 'Not Found'],
#  ['Daedulus (mix by Keef Baker)', 'Not Found'],
#  ['Once', 'spotify:track:4XP5CYpx05KM3149NydAUF'],
#  ['Slow Motion', 'spotify:track:3ThhyGXB8nsDvwow6IQEYj'],
#  ['Dive Bombers', 'spotify:track:6V8l1PTI4AUPKfxVg4HO1C'],
#  ['I Found You', 'spotify:track:770lDJeZHPtW358cl8xJml'],
#  ['Animal X', 'spotify:track:5HkQwwo2r0unzqEdRtHI1u'],
#  ['Nichts', 'spotify:track:5uPdMbsAVJgdkcCkMPKlBa'],
#  ['Save The Children', 'spotify:track:1opfxXBPOdVfdMKeNH6Sg7'],
#  ['Zanzibar (album version, Unfaded)', 'Not Found'],
#  ['Flood Corps', 'spotify:track:1zJn95n21fTSuutDdENLEW'],
#  ['Djembe Dub', 'Not Found'],
#  ['Speargun', 'spotify:track:5yOAOFhnYTTOihlWKoidr7'],
#  ['Wooden Ships', 'spotify:track:6reF60Z1fDFvCpIVLlGupg'],
# ...

# %%
# Rhythmic aggressive dark voice fast not_danceable 162
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 7:
        if alldata[i][26] == 14:
            if alldata[i][27] == 16:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Mary Poppins: Stay Awake', 'Not Found'],
#  ['The Gods Are Small Birds, but I Am the Falcon', 'Not Found'],
#  ['Four Women', 'spotify:track:6hjZ05TOrIKcI0p9zyHVl3'],
#  ['Robot', 'spotify:track:56xZslJeFSMyozcBfPMSRj'],
#  ['One River, Two Streams (Sam Hue Tinh)', 'Not Found'],
#  ['Modern Soul', 'spotify:track:0ADFdBeamLf1sUlXnd91SE'],
#  ['White Ashes (Black Smoke)', 'Not Found'],
#  ['Sect3n-n-e', 'spotify:track:6EzuBBflG0tNlm9WmQUOES'],
#  ['Implanted Thoughts', 'spotify:track:24uZiZksUPhGQcVv5Ttnuy'],
#  ['Safety Space', 'spotify:track:6y2WU4BEaCZrS2BuizQoar'],
#  ['Remote/Beauty', 'Not Found'],
#  ['Dinga', 'spotify:track:2hNFpmfpu7IareSD3AvuGc'],
#  ['愛し子よ', 'Not Found'],
#  ['Rabbitdome', 'Not Found'],
#  ['Chicago, Now!', 'spotify:track:4pUDd3RGzmg8B2hoTVkY1L'],
#  ['Adrift', 'spotify:track:1RTaQ91ql440D7Fs5ifEeM'],
#  ['Babe (I`m Gonna Leave You)', 'spotify:track:3S9BZ3K1q4ODSG2Hm9NWTU'],
#  ['Südwest', 'spotify:track:0m3tMy3mWsi0fYEhv6mV9e'],
# ...

# %%
# Rhythmic aggressive dark voice slow 131
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 7:
        if alldata[i][26] == 14:
            if alldata[i][27] == 16:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 20:
                        list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Pieces of My Heart', 'Not Found'],
#  ['Pulsar', 'Not Found'],
#  ['Warning of Winter', 'Not Found'],
#  ['Wooden Ships', 'spotify:track:1okzeFirduuD5oPvAstVtA'],
#  ['Raindance', 'spotify:track:0osYki4aJJj64aFmJ2B3BO'],
#  ['Summa the Time', 'Not Found'],
#  ['Master Piece', 'spotify:track:3JGlfWrVKNreLNjoUeUhb9'],
#  ['Chimes II', 'spotify:track:6TFFvXCWzMa9BKgHLasZK0'],
#  ['Shared Worlds', 'spotify:track:2wktECyRMuCjBYvX99Bfk1'],
#  ['Im Tired', 'spotify:track:1JIX5EajRrHM13g8aprl7i'],
#  ['Mighty Mighty (Spade and Whitey)', 'spotify:track:16WdDpMNAYT6Tn0EsOR2r4'],
#  ['Blood', 'spotify:track:510SAQVymnFSFVEIx3rAQM'],
#  ['Part 9 voice', 'Not Found'],
#  ['Sleep', 'spotify:track:6PnaCW9Q3qDnXqtPFnIpKx'],
#  ['01 - Oceans Heart', 'Not Found'],
#  ['Hurt', 'spotify:track:1lo9k4PrxFd5Np4cAxXoKo'],
#  ['Mijn dochter / Brief aan Kees', 'Not Found'],
#  ['Gula Gula (Chilluminati Mix)', 'spotify:track:2IXAC8zqVPQtXZQuHzkV45'],
#  ['I cant stand it.mp3', 'Not Found'],
# ...

# %% [markdown]
# # Rock Playlists

# %%
# Rock Passionate fast 136
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 8:
        if alldata[i][26] == 10:
            if alldata[i][29] == 19:
                list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['I’ve Been Waiting for You', 'Not Found'],
#  ['Fade Out Guitar Loops III', 'Not Found'],
#  ['Dont Know How to Say Goodbye', 'spotify:track:3rBpbtPBz46RazXYe1Fx5m'],
#  ['Luonto tuli lähelle', 'spotify:track:4ZHLbzYMyDPVBIPmI7RlBJ'],
#  ['Kids In Uniform', 'Not Found'],
#  ['Hold My Home', 'spotify:track:0rdDsipOqcoq9Zdq5Nzp4b'],
#  ['Break My Body', 'spotify:track:5pVSOZVIWaRxF0zhjlnEUy'],
#  ['The Nightmare Continues', 'spotify:track:1gQtwcnVpgXTcUvmcHtQak'],
#  ['Particles in Acceleration', 'Not Found'],
#  ['My Baby Left Me', 'spotify:track:3KvQK0HNBjID5vHjlcq6uG'],
#  ['Paralyzed', 'spotify:track:5qUQThrxQcneMLHjDWK62Y'],
#  ['Anxious Mo-Fo', 'spotify:track:7uZoHcTmsCn73ed2NedThJ'],
#  ['What Is This', 'spotify:track:5pdNMdOb7ZXSzctLaaqwNk'],
#  ['Just Like You', 'spotify:track:6uL6vMmE1BHHPlDwchYscG'],
#  ['Right/Wrong', 'spotify:track:11V92gxnJcPnL02Eq9ASnJ'],
#  ['Te estoy amando locamente', 'spotify:track:5QfmCmdL4qnzqMz5Z0gvzV'],
# ...

# %%
# Rock Passionate slow 193
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 8:
        if alldata[i][26] == 10:
            if alldata[i][29] == 20:
                list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['You Open My Eyes', 'spotify:track:4Dgy7L2kmn75VBwHYcOIyD'],
#  ['F.C.A.', 'spotify:track:3JJeouMFWuct8ExOpbAvwu'],
#  ['Gene Hackman', 'Not Found'],
#  ['100 Fresh Disciples', 'spotify:track:3brqoSyntaTlh95LO5YVxC'],
#  ['Lies! Lies! Lies!', 'spotify:track:6Qe93QtoHbAuCzYcYGCoiR'],
#  ['Tu seras... Et tais toi !', 'Not Found'],
#  ['Deaf As A Bat', 'spotify:track:0FJOjSp9a76eZ62hUFPjgx'],
#  ['Grand Canyon', 'spotify:track:04x5qTcWEgsJaDOPivQJsA'],
#  ['Dead Boy', 'spotify:track:2DDq0N2OOZKq9cqb7AeBYi'],
#  ['Frösche', 'spotify:track:13T5NoJywY9EPVfxmXg7dp'],
#  ['The Electric Co', 'spotify:track:6G0HdcvBhjzuoneFvWZJQm'],
#  ['Lonesome Bop', 'spotify:track:7bPMP4tVggGlVgzTOI8Cls'],
#  ['I Dont Want To Hear It', 'Not Found'],
#  ['Float', 'Not Found'],
#  ['We Bite', 'spotify:track:6TbkNVoYaQLXBKenflHvRh'],
#  ['Le Sacre du Printemps : Ladoration de la terre : VI. Cortège du sage',
#   'spotify:track:2zVj3BpIptgsaivspjuXup'],
#  ['Circus Maximus (snippet)', 'Not Found'],
# ...

# %%
# Rock cheerful bright instrumental 111
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 8:
        if alldata[i][26] == 11:
            if alldata[i][27] == 15:
                if alldata[i][28] == 17:
                    list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Stay With Me', 'spotify:track:01FomkWy4vd8yGlHFjVBTd'],
#  ['Rise', 'spotify:track:6nNHaRcfyu8pToMfHk9O7O'],
#  ['The Introduction', 'spotify:track:4AMiYjkLUJ54lWNit0MY2c'],
#  ['Speak Our Minds', 'spotify:track:3pOD1fQDAg7GkOb3bNPiB6'],
#  ['Evalia', 'spotify:track:4jIxCQKG8I2o6X4n9vhRsD'],
#  ['Tommy Unplugged', 'spotify:track:5ydAkORsB2pm2I0eXQgw70'],
#  ['My Little Town', 'spotify:track:7zB3ZPcgVX3Ti2KfdL0Euw'],
#  ['Breathe (album version)', 'Not Found'],
#  ['Here We Are Again', 'spotify:track:7LMQ1do9hAvdD42OwEalZq'],
#  ['Don’t Let’s Start', 'Not Found'],
#  ['Leaves', 'spotify:track:42cPoMuDlPwWwmQPyLO7Ql'],
#  ['Mine to Keep', 'spotify:track:1oXGh0505zOcAUdhPWuVXs'],
#  ['Its Magnetic Me', 'spotify:track:1ieIHrotoYFPUQ6sfig8aE'],
#  ['Disappear', 'spotify:track:3etCLXE25Lleo18QhviGk6'],
#  ['White Days', 'spotify:track:2aGGhnqymOdfWHtpBABvjh'],
#  ['Hunchback II', 'Not Found'],
#  ['Honey, Honey (Swedish version)', 'spotify:track:1iVrhKdchYGmRWKgEuX0Fe'],
# ...

# %%
# Rock cheerful bright voice fast danceable 99
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 8:
        if alldata[i][26] == 11:
            if alldata[i][27] == 15:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 0:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['How crazy', 'spotify:track:2CWyo6t10bx6cNq2e7U2Pv'],
#  ['Mass Pike', 'spotify:track:1YIecOW5WCDUU58UZjkoeP'],
#  ['Never Gonna Be Alone', 'spotify:track:7aySoZnwt7c6lA54qVVUOk'],
#  ['M.O.N.E.Y.', 'spotify:track:1Ij4cmQteKslDqCpenSFhF'],
#  ['Sweet Skinny Jenny', 'spotify:track:2isNld9xTCsIT2yvD27Hvt'],
#  ['Baby Im Yours', 'spotify:track:39YRSVJKwEM1E7Eptij2Cl'],
#  ['Any Time at All', 'spotify:track:5HcEoqggG10H7KhcP94jyo'],
#  ['Bring It Back Again', 'spotify:track:6qgbI3qX8hMkM2nqDUNXEZ'],
#  ['Earthquake', 'spotify:track:6FrfCOWO328eVsbQJs5epz'],
#  ['Feel It Coming Back (feat. Diego Torres)',
#   'spotify:track:2FJW928xaTBuOzQPz2qaYU'],
#  ['Problems', 'spotify:track:42TZzpborhrkkLfKUAJ95l'],
#  ['Everytime', 'spotify:track:7gmTqfrUH7GgtkbGkwjOuG'],
#  ['Starman', 'Not Found'],
#  ['Free Girl Now', 'spotify:track:1ayC8ThLb56mKdLsF3ognO'],
#  ['Boba niña nice (teenage superstar)',
#   'spotify:track:7oIXQNqGfaijrHJdyW52J1'],
# ...

# %%
# Rock cheerful bright voice fast not_danceable 115
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 8:
        if alldata[i][26] == 11:
            if alldata[i][27] == 15:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Adirondacks', 'spotify:track:6Zhv6wQyS22UHR1phLfnlH'],
#  ['Jack of Shadows', 'spotify:track:4mX5uDjqsv4u0uNF6WcoXn'],
#  ['Giants in my Field', 'spotify:track:4lWPiMI9mM6DR5kuE7IZ1F'],
#  ['Cool It Down', 'spotify:track:4Hh6Q9GhhE8DeON2iUtYMT'],
#  ['Little Blossom', 'spotify:track:5zvkma5yqQpG8Vf9lqqlv3'],
#  ['Under My Thumb', 'Not Found'],
#  ['10-Pista de audio 10', 'Not Found'],
#  ['Hound Dog', 'Not Found'],
#  ['Yölaulu', 'spotify:track:0vjXEPlk4QxMUv3ryAZpk5'],
#  ['Im Walkin', 'spotify:track:4AIitsBrTqUUff9oVqlMqz'],
#  ['Bloody Barefoot Blues', 'spotify:track:5WMu8MrJ8BfRbnHo9HH1TC'],
#  ['If I Should Die Tonight', 'spotify:track:45zsxqrCDXcWfzQQq1FVe4'],
#  ['Come on and Dance', 'spotify:track:2Xuzlq1PEL8grGyERKRW9v'],
#  ['The Dice Man', 'Not Found'],
#  ['Someone to Love', 'spotify:track:4Y0b8PJQyFULLKFRxDHqlz'],
#  ['The Seabirds', 'spotify:track:2ImCB7nr7wdIjmKljOCx7U'],
#  ['Colonel Bogey', 'spotify:track:0ouwv76T1FeJbR41sd7J0G'],
# ...

# %%
# Rock cheerful bright voice slow danceable 67
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 8:
        if alldata[i][26] == 11:
            if alldata[i][27] == 15:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 20:
                        if alldata[i][30] == 0:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Im Beginning to Think You Prefer Beverley Hills 90210 to Me', 'Not Found'],
#  ['Running With The Boys', 'spotify:track:0wL87Fd27L4ow9CoMDP9wI'],
#  ['Dead, Drunk, and Naked', 'spotify:track:6IjWuJHAOpoR2MDfyjo2zF'],
#  ['Say Youre Mine', 'spotify:track:0tioBfc3X93P1h6EODdZbn'],
#  ['One After 909', 'spotify:track:50qHmeex1nPTyQTwBXjSE4'],
#  ['South Carolina', 'spotify:track:7xloUzsOrH0Cd2CeR3M84w'],
#  ['À Vot Bon Coeur', 'spotify:track:7ayNa9pY9tBwd9B6IqYEVn'],
#  ['Somethin to Believe in', 'spotify:track:7JuQdRJC1UJ93elkTXxjp4'],
#  ['Whole Lotta Shakin Goin On (Off-Air live)', 'Not Found'],
#  ['Cant Believe You Want to Leave', 'spotify:track:4m8gQBFaa40SujMl85CLeD'],
#  ['Satisfied', 'Not Found'],
#  ['Where Do We Go From Here', 'Not Found'],
#  ['Pałac', 'spotify:track:2w0u8cCLdLj0aXHKsvMcsS'],
#  ['Thats New York', 'spotify:track:3WUTMrgHmKZVCO5WjmTyrc'],
#  ['Caretakers Theme', 'Not Found'],
#  ['Communion', 'spotify:track:72rFTLgINK8dKcJkkJmRo7'],
# ...

# %%
# Rock cheerful bright voice slow not_danceable 76
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 8:
        if alldata[i][26] == 11:
            if alldata[i][27] == 15:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 20:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['You Get Me Up', 'spotify:track:4MwJrJMmybB7h1hd95bmz8'],
#  ['This Is Not a Game', 'spotify:track:1sLXPXDWhas8rhCQU45D0b'],
#  ['Make Up Your Mind', 'Not Found'],
#  ['Still', 'spotify:track:4JZnfdFzJWHJg1CRAiKTS3'],
#  ['Jupiters Child', 'spotify:track:7Fh79kzkNMPqlPqZEEOZso'],
#  ['Fairyland', 'Not Found'],
#  ['There Goes My Inspiration', 'spotify:track:6GukLhREhZTKaW2TJeVbvx'],
#  ['Now That We’re Gone', 'Not Found'],
#  ['Bad Moon Rising', 'spotify:track:20OFwXhEXf12DzwXmaV7fj'],
#  ['Chasing Moonbeams', 'spotify:track:1yGbJNkAFzLYpAslA8QWG9'],
#  ['Eraser', 'spotify:track:3xBn40ciGfKD7YozLRiyzt'],
#  ['Silence Is Easy', 'spotify:track:1oPuQTM7LExPzaFrF0DXzD'],
#  ['Scared of the Lights', 'spotify:track:2Ni9c5KGbHQl3drHsTmDR4'],
#  ['Never Tear Us Apart', 'spotify:track:2iAAPpGOoyIbo0V8r2kyht'],
#  ['Love Kills', 'spotify:track:6Dlc1l4IAfpDUF9apQbvo8'],
#  ['A Second Change to Make a First Impression', 'Not Found'],
#  ['Solo Una Sana E Consapevole Li', 'Not Found'],
# ...

# %%
# Rock cheerful dark 67
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 8:
        if alldata[i][26] == 11:
            if alldata[i][27] == 16:
                list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['The Girls', 'Not Found'],
#  ['Sharpen Up Those Fangs', 'spotify:track:5Rj1JHx5WTF3pzDOIYs7Dv'],
#  ['humming song (alone together)', 'Not Found'],
#  ['Miss Fortune', 'spotify:track:1Y7GBrBM179GYeiGm8s3Au'],
#  ['Retsligt efterspil', 'spotify:track:4FJulNlZS8hkOPaOBbW4zH'],
#  ['Spillage', 'spotify:track:0aocsnZlGirqzJSbisPa15'],
#  ['Mountain Man', 'spotify:track:0rmiHZ4mWQFmkMUvYsaff4'],
#  ['Cause', 'spotify:track:4TwlbTAxjJiIRvJEWpoA03'],
#  ['Lean To The Glass', 'Not Found'],
#  ['(Your Love Is Like) Nuclear Waste', 'spotify:track:6HFLUVhjyU3LQedp8AxzyH'],
#  ['Your Bullshit', 'spotify:track:1hyV46vO3Et3Sa1eqvdOiq'],
#  ['Zatrollené hvozdy', 'Not Found'],
#  ['Half a Mind', 'spotify:track:0lxinq1tQiD3b7IDHyUgmt'],
#  ['The Nectar of Perversity Springs From the Well of Repression', 'Not Found'],
#  ['Semaine rouge', 'spotify:track:59HoQEDngGxCLrDVlPASny'],
#  ['Biosphere (Reprise)', 'spotify:track:69NIJncUKXMigcwgh10Rmn'],
# ...

# %%
# Rock bittersweet bright instrumental fast 61
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 8:
        if alldata[i][26] == 12:
            if alldata[i][27] == 15:
                if alldata[i][28] == 17:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 0:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['On With the Song', 'spotify:track:6GsMKwcl7syNbheq1qOvW1'],
#  ['Nothing but You', 'spotify:track:7IcazPr28aKHRQ2DAjWFZT'],
#  ['Stop Fighting', 'Not Found'],
#  ['Just To Feel That Way', 'spotify:track:6MdXZgsKL3UU1NoxcpDSCJ'],
#  ['If', 'spotify:track:1WPOPJ5jWPpiTVCbnP6GU7'],
#  ['Zapruder', 'spotify:track:3XMmlop71jNrXRUEMUdTbm'],
#  ['Stay Visible', 'spotify:track:5SEqDWbzDQxbE7muhZ45Sg'],
#  ['My Baby Thinks Shes French', 'spotify:track:5ANScD0jrrMShKiDI6gThd'],
#  ['Lay Down Your Arms', 'spotify:track:3cQ4Qs2LkzuvViv6rSICfA'],
#  ['Machines', 'spotify:track:0BVo3WUmrVipXh5EpIGh4k'],
#  ['Night Time', 'spotify:track:4dYyNLBYXpP7nOtRwl5kJ3'],
#  ['Crazy (acoustic)', 'Not Found'],
#  ['Order/Disorder', 'spotify:track:6XrQMOpwEcHKq1rby1KDlN'],
#  ['Velvet', 'Not Found'],
#  ['AMTV', 'spotify:track:75uQJHqKUSnWnLgknwULBh'],
#  ['If She Could See Me Now', 'spotify:track:5lIyZPP3F45TStqOXwgg8v'],
#  ['God Bless Mom', 'spotify:track:5HZwi7QdiPC2vRGg2sZNhN'],
# ...

# %%
# Rock bittersweet bright instrumental fast not_danceable 100
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 8:
        if alldata[i][26] == 12:
            if alldata[i][27] == 15:
                if alldata[i][28] == 17:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Vulcano', 'spotify:track:3r6wgoRoBtC1Wytb3g71f9'],
#  ['Erwachen', 'spotify:track:4VXsK6gKnrYMsMcgHvUk9e'],
#  ['Partners in Crime', 'spotify:track:63yPhXF1mZfq7h2YK2lfho'],
#  ['Dont You Love Me Joan?', 'spotify:track:6NjFUFVq7pWjyKuW9Rn8Pr'],
#  ['Old Joe Clark', 'spotify:track:0llUi0xI5yYjh1s6n69bsN'],
#  ['Im Talking About You', 'Not Found'],
#  ['Rose Gold', 'spotify:track:4NU22i2vQEfDQhHmDsy8F4'],
#  ['Siin', 'spotify:track:13jJmDyFCslJf1rpJJGFsg'],
#  ['Shotgun Rider', 'spotify:track:3LbvNFkqDTrE1liGMmZBDL'],
#  ['Let It Ride', 'spotify:track:3ekDaG8NOWKGffLbUnGYbz'],
#  ['I Love You For All Seasons (Ft. The Revelations)', 'Not Found'],
#  ['Leaning on a Cane', 'spotify:track:1xmuC56qcPi4hFUOL84WXb'],
#  ['Losing My Religion (live)', 'spotify:track:0svaiEE8lMG6Q3PjMWdxLq'],
#  ['Tidite Tille', 'spotify:track:6fokAI312UqI4WkFyycPpu'],
#  ['¿Por que me llamas a esta horas?', 'spotify:track:55G9YLyQkU0cs805wgLpmf'],
#  ['The Draughtsmans Contract: An Eye for Optical Theory',
# ...

# %%
# Rock bittersweet bright instrumental slow 35
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 8:
        if alldata[i][26] == 12:
            if alldata[i][27] == 15:
                if alldata[i][28] == 17:
                    if alldata[i][29] == 20:
                        list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Bells Chiming in an Empty House', 'spotify:track:2K0TQ1DX1SKI7YgLgv6J5y'],
#  ['Hanuman Chest', 'Not Found'],
#  ['Space Walk', 'spotify:track:4HtL8YlrABgueh0Sw1bR6G'],
#  ['Better To Die', 'spotify:track:5quIzDuHL2bCJrfewdFSWQ'],
#  ['Made to Break Your Heart', 'spotify:track:7hPAmpQDXXH8WUo2IEJerr'],
#  ['Let Me Be Free', 'spotify:track:67aJ66a8fpmtSfctjfy844'],
#  ['Concerto', 'spotify:track:4UTeePwWKGOdgk4O64tA8z'],
#  ['Salt in the Rainbow (alternate mix)', 'Not Found'],
#  ['Buttah (Jack Ruby Version)', 'Not Found'],
#  ['Shadows', 'spotify:track:14tXijQN67BRnw1eFnFItk'],
#  ['Illuminating', 'spotify:track:15aTOjql9VV9v13cQ9SvkD'],
#  ['Papir IIII.I', 'spotify:track:5LBtU80gRMblLnpZDBKCBQ'],
#  ['October Jam (1)', 'spotify:track:0fZUiXJDnuIGDQzaicdwK0'],
#  ['Region of Fire', 'spotify:track:6JxtGMCvpEBxt8Nur8s4Gk'],
#  ['Rik och lycklig', 'spotify:track:0wsRTMGMum5S0RlAS51s0k'],
#  ['El Rayo-X', 'spotify:track:3bcueDtFYhABQPraFxYdkj'],
# ...

# %%
# Rock bittersweet bright voice fast danceable 140
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 8:
        if alldata[i][26] == 12:
            if alldata[i][27] == 15:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 0:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Flame Trees', 'spotify:track:5qBmTXgCdtvCqKc9yrLoWg'],
#  ['If You Want Me', 'spotify:track:2CxtYjdmUSXSJFJ94YATbJ'],
#  ['You and Me', 'spotify:track:77lmukTxzqh28gQq1QuFwo'],
#  ['Lean on Me', 'Not Found'],
#  ['Someday', 'spotify:track:7oh5hz5wnDWsDVRu4Q8t6V'],
#  ['A Ride With Violence', 'spotify:track:6LeZSsXJRWrEDPNUUdAnIH'],
#  ['And Then Some', 'spotify:track:3rRqQvhK3JAqg6Ct5hu27s'],
#  ['Cold River', 'spotify:track:0MUMC0FLShZ8XYdRlYO79Y'],
#  ['Last Days Of Summer', 'spotify:track:17vAPwkecsLVdXYeQaQgcv'],
#  ['God Blessed Texas (2)', 'Not Found'],
#  ['Hide', 'spotify:track:6A8NNKbpS6mKp9KGLfxAru'],
#  ['Dont Exist', 'spotify:track:659IKyFo7w7vJn1npBl1B6'],
#  ['Stranger', 'spotify:track:49fjTge4g9JAuOIZN6LYGC'],
#  ['Ray', 'spotify:track:5P677uaWuL8QtZHhqOuA1X'],
#  ['The Warm Parade', 'spotify:track:7EvWITGsvf1lrWhmCosSZ4'],
#  ['Walk Away', 'spotify:track:0rIUfnPMR3WiFXd53vjJ2x'],
#  ['My soft return', 'spotify:track:2zdbWcDUSQ2kroZYGalWzv'],
# ...

# %%
# Rock bittersweet bright voice fast not_danceable 231
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 8:
        if alldata[i][26] == 12:
            if alldata[i][27] == 15:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Window to the World', 'spotify:track:4gdAEGARXBthlnQO4xmJXH'],
#  ['Rock n Roll Winter', 'Not Found'],
#  ['My Own Sweet Bed Tonight', 'spotify:track:6il7fqhR3aL3zAEe25Mxzh'],
#  ['Everlasting', 'spotify:track:0ydFJY6cjRMtibvMqxc2MJ'],
#  ['Revolt', 'spotify:track:7BGg9wSF98j6FzvHGkq3f0'],
#  ['Angeline', 'Not Found'],
#  ['Still Not Home', 'spotify:track:0GwWiTgN7APDlfuZXmAF4w'],
#  ['Fakin NYC', 'Not Found'],
#  ['Fall Like Rain', 'spotify:track:15mPzHn4o6qz5TMHjBws7q'],
#  ['Since I Met You', 'spotify:track:4IGcIPounFQHgYC4vkwefb'],
#  ['As You Want', 'spotify:track:352DtwXHuSQX0MgbEVX3V3'],
#  ['Mein bester Feind', 'spotify:track:63M3tpVTHDhuZWnpS3hrIh'],
#  ['Auschwitz 89', 'Not Found'],
#  ['11 Ritual', 'Not Found'],
#  ['Amarillo Highway', 'spotify:track:71uxj30fYEtjUY1fQ1jPEq'],
#  ['Misery', 'spotify:track:3d8ETcwbXv5SR43rq5liOa'],
#  ['Reyes de la noche', 'spotify:track:3nnDwYz3dEd4p2ESdpS1G0'],
#  ['Catch', 'spotify:track:2pjZYR7jEnkRR5xhsRlrWx'],
# ...

# %%
# Rock bittersweet bright voice slow 124
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 8:
        if alldata[i][26] == 12:
            if alldata[i][27] == 15:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 20:
                        list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Big Boss Man', 'spotify:track:1aJ94YB9fbrW1ejuJghMM9'],
#  ['Persiana americana', 'spotify:track:7JZP7kQsuFFWOrtAI7uNiW'],
#  ['Greenage', 'Not Found'],
#  ['Voin luopuu mistä vaan', 'Not Found'],
#  ['Old Photographs', 'spotify:track:7x63FCRPBtbBzLXAG2DwGu'],
#  ['10-the_pigeon_detectives-say_it_like_you_mean_it', 'Not Found'],
#  ['Breakeven (live from Aviva Stadium, Dublin)', 'Not Found'],
#  ['My Lost Soprano', 'spotify:track:11utMtW3EPeTe1UoUWLfFM'],
#  ['Mud on My Boots', 'Not Found'],
#  ['I Can’t Take It', 'spotify:track:02UopdYeXlXMf8WRlIeP6x'],
#  ['Crazy (live)', 'spotify:track:3ubgzwyM2lex91EvjeORrp'],
#  ['Pebbles', 'spotify:track:1gbLw3cNtsgLds9ZSNZg25'],
#  ['Good Man - Another Life', 'Not Found'],
#  ['The Clock', 'spotify:track:3GrSaGUD5FD7QODhdtOef5'],
#  ['A Ray of Hope', 'spotify:track:7osQgwNLoDtLFoZJ4Rwkqq'],
#  ['Days Like These', 'spotify:track:7qfY6oFskXAgdhwiUQYZJS'],
#  ['Best God in Show', 'spotify:track:4tGhJGC4qpMvrfhhbE2XoD'],
# ...

# %%
# Rock bittersweet dark fast 189
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 8:
        if alldata[i][26] == 12:
            if alldata[i][27] == 16:
                if alldata[i][29] == 19:
                    list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Chains and Pounding Hooves', 'spotify:track:1rbljVsQDVtu57V4D6WYRl'],
#  ['I', 'spotify:track:4crzvvlqbCjaYVVU9AKINx'],
#  ['The Conception and Creation', 'Not Found'],
#  ['New Fire', 'spotify:track:1uAnbQOgbO1Q7J479ElNp6'],
#  ['The Reigns', 'spotify:track:5wUcGn5DQS5bsyI8voRIdY'],
#  ['Youri', 'spotify:track:0fklfYlFp9EDMKTojQuYXf'],
#  ['Intro - Bloodchilling Tales', 'Not Found'],
#  ['Alright (live)', 'spotify:track:3BSzRLZQTjrLmSfbAIKMae'],
#  ['Boulevard', 'spotify:track:6SGc7gjqweR45bM3VN2JqL'],
#  ['The Fog (Early 1991)', 'spotify:track:4MFlVDp9VWHfzd4DPMHSRT'],
#  ['The Hypno-wheel', 'Not Found'],
#  ['Punk Song No. 15', 'spotify:track:5Y3j03NfnxpaMxA56Wie7A'],
#  ['Passing', 'spotify:track:2j3GHMUA5AbcxgXZ4ecINZ'],
#  ['Happier Times', 'spotify:track:64SyJAn0Bii6fAzKTmWQRD'],
#  ['Halftones and Metatones #3', 'Not Found'],
#  ['My Kingdom for a Horse', 'spotify:track:1Pwa3ILjpcJLw2Cfdxroqq'],
#  ['The Miracle and Finale', 'spotify:track:6EvxCFQTQBYM0hX4psbK02'],
# ...

# %%
# Rock bittersweet dark slow 78
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 8:
        if alldata[i][26] == 12:
            if alldata[i][27] == 16:
                if alldata[i][29] == 20:
                    list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Wey Wey Hep Uh Hole', 'spotify:track:7gk8FKc2ccGZ4Rs2KC8T5K'],
#  ['International Dateline (Harmonium Session)', 'Not Found'],
#  ['Timeless', 'spotify:track:6YwvmhbBszqKZnCi5RzwOv'],
#  ['Pelt', 'spotify:track:0QWhJfWCYVUfQJiTZtG2RU'],
#  ['Many Pieces of Large Fuzzy Mammals Gathered Together at a Rave and Schmoozing With a Brick',
#   'spotify:track:061BS4OQ2DzV2bUKLdNRL6'],
#  ['Didn’t Understand', 'Not Found'],
#  ['Broken heart tattoos', 'spotify:track:0uOGYOUzy7zH8xAH6UM3aF'],
#  ['Feedin’ Birds', 'spotify:track:5Qj25LBkejv5qevBmUZ4Ml'],
#  ['Pearl Bastard', 'spotify:track:4n84HtALrdLLC8TncWzv2D'],
#  ['Radio Silence', 'spotify:track:4hV3qu8o72XHEqcEZfkDjm'],
#  ['Dont Wanna Be Like That', 'spotify:track:3ngLx41Vp4ZMdr9MGJEEwL'],
#  ['Dark Is Easy', 'spotify:track:2jpIOtJuBZ5ISmF1awh5NA'],
#  ['Morning Born', 'spotify:track:6HSRbxhMQrkD2F1dDjOkhF'],
#  ['Good Morning Riot (instrumental)', 'Not Found'],
#  ['Los Dias De Junio', 'spotify:track:3RjnKLKTsbbvPvc6nYdqD7'],
# ...

# %%
# Rock bittersweet dark slow 78
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 8:
        if alldata[i][26] == 12:
            if alldata[i][27] == 16:
                if alldata[i][29] == 20:
                    list1.append([alldata[i][0],alldata[i][24]])
list1
len(list1)

# %%
# Rock humorous bright instrumental 48
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 8:
        if alldata[i][26] == 13:
            if alldata[i][27] == 15:
                if alldata[i][28] == 17:
                    list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Spirit', 'spotify:track:31pso4niJhfROOmrQrqywk'],
#  ['Pickpocket', 'spotify:track:4P1XxfsDxTeZscLpXEK6Gq'],
#  ['Mother Freedom', 'spotify:track:6xWK7NpSgWRK9dxBoHziNQ'],
#  ['Back Up Girl', 'spotify:track:48yYQ6HOiCjYDfOiusBdFO'],
#  ['Wooly Bully', 'spotify:track:5ktiUksyzbIq6mkWN7zaCA'],
#  ['Rhythm Section Want Ad', 'spotify:track:43DXgLIIVpLCBopD3iK2iG'],
#  ['Non-Violence', 'spotify:track:0c5DnpXrI1aRuU1luVYPtK'],
#  ['Wildwood Flower', 'spotify:track:6NtMXcWyN34MqrmItKNEVG'],
#  ['Rockin Pneumonia and the Boogie Woogie Flu',
#   'spotify:track:20OVbaIrsu70Qab39PsE3X'],
#  ['I Wait', 'spotify:track:4IRj5CyW42RWIz7etpuByJ'],
#  ['Lonely People', 'spotify:track:5coTcHT7K8O3G97y9T4LOU'],
#  ['Guess You Had to Be There (feat. Kacey Musgraves)', 'Not Found'],
#  ['Big Blue', 'spotify:track:5TXDta9sz0h1nX0oZb1GJ8'],
#  ['Meseno horo', 'Not Found'],
#  ['Reng Ding Dang Dong', 'Not Found'],
#  ['Tomorrow Never Knows', 'spotify:track:6ihPJ1WVi7LfpP2d9XH6Sw'],
# ...

# %%
# Rock humorous birght voice fast danceable 74
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 8:
        if alldata[i][26] == 13:
            if alldata[i][27] == 15:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 0:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Lover Lover', 'spotify:track:7BUltNQenAlQGfJoadPg0z'],
#  ['Im a Hog for You', 'Not Found'],
#  ['Were Gonna Have a Real Good Time Together',
#   'spotify:track:0oPZUCKjSIlQclVrUJDf2l'],
#  ['Love Is in the Air', 'spotify:track:0wLJsSmUxUVksbdjmg2WQT'],
#  ['Good Livin', 'spotify:track:5Ggm4A6WS58sa4izgLJQOj'],
#  ['Rescue', 'spotify:track:5Nl36DnAwuOFelnkP3vHzE'],
#  ['Ive Crossed That Line', 'spotify:track:2v9pYrelHM2SzTTtQeNnzA'],
#  ['Just Play Music', 'spotify:track:57qkAQdcTqTV2kdZmTzAG8'],
#  ['I Dont Know (The Beetlejuice Song)',
#   'spotify:track:2IfPLgSaWby9WSRsLdqNWW'],
#  ['A Day At A Time', 'spotify:track:1DpHRIWlMB9D3FZYAVyqCf'],
#  ['Allentown', 'spotify:track:59xhCcRskqyMtKzdvLZDfV'],
#  ['Yesterday and You (Armens Theme)', 'spotify:track:1oB6UQzxeh4E6dLnTjTQnd'],
#  ['No Second Prize', 'spotify:track:7tajkbb5MRLzySbCSBC72c'],
#  ['Dont Start Me to Talkin', 'spotify:track:1f9FEeBWZkuT4ItJZwsJ2l'],
#  ['Greenback Dollar', 'Not Found'],
# ...

# %%
# Rock humorous birght voice fast danceable 108
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 8:
        if alldata[i][26] == 13:
            if alldata[i][27] == 15:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['The Freefaller', 'Not Found'],
#  ['The Hardest Part', 'spotify:track:4Tw9JYF9HOuPRyccNWMgwf'],
#  ['Wild Honey', 'spotify:track:5Phhw1cIA41fyoXABRBaZs'],
#  ['Pass Me by (If Youre Only Passing Through)',
#   'spotify:track:6WsIgc7AAGBi7IedC0p7Sm'],
#  ['Karma', 'spotify:track:3lLDMAOp1XY6j0kqYNUsWe'],
#  ['Fleas', 'spotify:track:6iOdWcQt1XwFiPnHPWv8VO'],
#  ['Hello Josephine', 'Not Found'],
#  ['Too Much Fun', 'spotify:track:38CnG9HxpVtqXVqpESBr6H'],
#  ['L.A. Town', 'spotify:track:5UlkIDJ7kVcZjGTJr0YExN'],
#  ['Love Me Like I Love You', 'spotify:track:2gnRkE13FRxGcUFqg7FZ1j'],
#  ['Just That Kind of Man', 'spotify:track:4WjNoAqIYCjRA427DsLlNO'],
#  ['The Magic Touch', 'spotify:track:2TbtSZCVimnbMU3assaL3M'],
#  ['Who Cares', 'Not Found'],
#  ['Where Have You Been All My Life', 'spotify:track:4Pk0ldQsxbOB3g7kX2vw7u'],
#  ['Violent Decline', 'spotify:track:6CfzSjST368p4GF2vAboHU'],
#  ['Fall on Me', 'spotify:track:3xPKSMgZl4N3rfTyIgSPfa'],
#  ['Step One', 'Not Found'],
# ...

# %%
# Rock humorous birght voice slow 54
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 8:
        if alldata[i][26] == 13:
            if alldata[i][27] == 15:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 20:
                        list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Big Time Operator', 'spotify:track:4G59PDOr2U13ztLwIpiH5W'],
#  ['The Writings on the Wall', 'spotify:track:2KWB1SkJ8v0ljkzwHzLvco'],
#  ['90%', 'spotify:track:0btRU8PpCO2TkX5iHVizIh'],
#  ['Rock the Universe', 'spotify:track:7f52zXqdKjnKQfGRF4mRwa'],
#  ['Reichtum', 'Not Found'],
#  ['Six Days on the Road', 'spotify:track:0ht3TuGmL8tOkciCPY0rPa'],
#  ['Elämää suurempi', 'spotify:track:3UeVRFcaFpozS8WkSSPz80'],
#  ['Rooster Rock', 'spotify:track:1NNTsIp4DSAehsjRS3vCc3'],
#  ['Paper Bag', 'spotify:track:3edcqSlxftbcrgXWSXQcU3'],
#  ['Shelling Rain', 'spotify:track:7llA8m6S9GXKf7OhEl66GW'],
#  ['Your Stripes', 'spotify:track:4JuEb1usQDZIr6l7BzhylR'],
#  ['Turn It Up', 'spotify:track:1Vrg0vTqazJio7NUdO9ykB'],
#  ['Magic Dice', 'spotify:track:7fkzkupsrsm5s8TJUirEh3'],
#  ['The Secret Life of Arabia', 'spotify:track:4F1V29ygbAKbKCQDgt4z9f'],
#  ['Willie and the Hand Jive', 'spotify:track:2HP0xuxyhxcxj942HqrK84'],
#  ['Do What You Did', 'Not Found'],
# ...

# %%
# Rock humorous dark 40
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 8:
        if alldata[i][26] == 13:
            if alldata[i][27] == 16:
                list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Gypsy (Single Version)', 'Not Found'],
#  ['Salt Lake City Sunday', 'spotify:track:1iJkNi6QLpcMbdusqFkn5G'],
#  ['Her Voice Is Beyond Her Years', 'spotify:track:5yeePebl9r4KsVrNfIbXWI'],
#  ['Rat King', 'spotify:track:7psZ3ZBuZWOcLadCkLYw3M'],
#  ['Ja som ten čo hrával s Dežom', 'spotify:track:26EM1ACW7iTiTyVA7Tx2mm'],
#  ['Mascara Tears', 'spotify:track:0ZkefYfnT4Kz7Gw4BTulpg'],
#  ['I Am a Cliché', 'spotify:track:7gYebRfI8J2ERtskncrbrP'],
#  ['Try a Little Harder', 'spotify:track:18zvuxpGK81DaxSyiuDwF9'],
#  ['Living', 'spotify:track:41vTx1BQQjPNzgzTKEiatk'],
#  ['These 3 Sins', 'spotify:track:4axrZbzeYKZzz6QihAU0ux'],
#  ['Devil Take You', 'spotify:track:5T0TVDFQFUX1hfkqUY8xPK'],
#  ['Gone Baby Gone', 'spotify:track:2nxcHP0xq18YA626I0qLqC'],
#  ['Twist to the Moon (Moon Twist)', 'spotify:track:0Qxxbq47L6Q8OsLhUSAdA6'],
#  ['Some Trees (Merritt Moon)', 'spotify:track:4TVVlhoAI52AphhFZ0zW4L'],
#  ['Nan', 'spotify:track:6NJP0YfHp72nft81vkkGQW'],
# ...

# %%
# Rock aggressive bright instrumental fast danceable 340
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 8:
        if alldata[i][26] == 14:
            if alldata[i][27] == 15:
                if alldata[i][28] == 17:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 0:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Last Night', 'spotify:track:1h9R1je5B6xhFrbjZAwOH8'],
#  ['Eine erhalten', 'spotify:track:7KBz8C43oPuUL5NA07XnbR'],
#  ['Human Touch', 'spotify:track:2oWjU4MiqMeRJ95ZVwkhAe'],
#  ['wake up, painful sister!', 'Not Found'],
#  ['Free Hand (John Peel session)', 'Not Found'],
#  ['Tämä vaikea elämä', 'spotify:track:1JEHcjJ6ng0Vst06QjFCaI'],
#  ['Vantage', 'spotify:track:5i1fXzZbc2UYFsQeTw5kc2'],
#  ['Lonely Too Long', 'Not Found'],
#  ['1234 (Van She Remix)', 'spotify:track:5w40gBpeBVMWwZ4LE99ZCd'],
#  ['Meltdown', 'spotify:track:2JxVTXtiSYvE9dGu6nJnHR'],
#  ['Breakdown', 'spotify:track:2LCjLbXHpDdFXYSsZXNhEX'],
#  ['Its Too Late', 'spotify:track:7pE573alZ5ZaipWfa2khKc'],
#  ['Humppaidiootti', 'spotify:track:5yAyu8kAHfeErLMCycwcba'],
#  ['Psychosomatica', 'spotify:track:5JybxWo7svC8R565L4x0Rx'],
#  ['Medicating Angels', 'spotify:track:1wksW2q0antCJjOJDpfBPi'],
#  ['Clavier-Büchlein Für Anna Magdalena Bach 1725: Partita No. 3 A-Moll, BWV 827: V. Menuet',
#   'Not Found'],
# ...

# %%
# Rock aggressive bright instrumental fast not_danceable 332
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 8:
        if alldata[i][26] == 14:
            if alldata[i][27] == 15:
                if alldata[i][28] == 17:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Tom Busby', 'spotify:track:1ccmyDnfUyLw2bPcOVdees'],
#  ['The Thin Wall (work in progress mix)',
#   'spotify:track:6JZSzvJcr75gBlw9wnpVLd'],
#  ['Bad Habits', 'spotify:track:4p2tIKhOQr30tOAP6YoOk2'],
#  ['Kilby', 'spotify:track:5FF9Yjb6IwSDi520sQaHar'],
#  ['Oracle', 'spotify:track:6qMhSCfd0SfSClvQhu0LpG'],
#  ['Rumble', 'spotify:track:4vytJPqzmyRdrI5l54HzEi'],
#  ['Sing! Harpy', 'spotify:track:4RgL3qFKB7jIL5IsFJbB0T'],
#  ['Down', 'spotify:track:2iMOJWpz8UudWDBqHpOzwC'],
#  ['Fighting in Built Up Areas', 'spotify:track:7MoF9WiutZwZVUTFsRncpu'],
#  ['Baker Street', 'spotify:track:5gOd6zDC8vhlYjqbQdJVWP'],
#  ['The Seer / Bring the Sun / Toussaint l’ouverture', 'Not Found'],
#  ['Dirty Waterfalls', 'spotify:track:5fM7OUvQvHUhh6EgXTS5LU'],
#  ['Creature, Creature', 'spotify:track:0Iz9YhBYDIMvSD49OoL3bE'],
#  ['Home Again', 'spotify:track:3aI4gMV6j2TYZvmo0L4GfS'],
#  ['Fleece On Fire', 'Not Found'],
#  ['Fight for Yesterday', 'spotify:track:0YpH4ayscrQAnfzXrE9mX7'],
# ...

# %%
# Rock aggressive bright instrumental slow 85
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 8:
        if alldata[i][26] == 14:
            if alldata[i][27] == 15:
                if alldata[i][28] == 17:
                    if alldata[i][29] == 20:
                        list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['No Shelter', 'spotify:track:35x7tOpg3XGhCPsqJL3PaA'],
#  ['Long Tall Sally', 'spotify:track:2OCNS7K6uGTKZc1448Btl1'],
#  ['Pagan Baby', 'spotify:track:2G87Gj17vPsYtwCZxJNdK6'],
#  ['Crank', 'spotify:track:23LyZEqtRoQBmbvmoqgkcy'],
#  ['Heart Raper', 'spotify:track:0hI1CHGi1msk57aUs3emlW'],
#  ['Dios de la muerta', 'Not Found'],
#  ['Good Times Bad Times (Live)', 'spotify:track:3YK0T73gI48zFXiBwOJKw3'],
#  ['Believe Me Natalie', 'spotify:track:67kIfRYFai45yakOuXhndQ'],
#  ['Mittendrin', 'spotify:track:3uANuqphs05JQv7Kt5IzaJ'],
#  ['Krampetak', 'Not Found'],
#  ['Two Faced Love', 'spotify:track:6d2A43F4YXI6Wo5jS0bshI'],
#  ['Waste of Time', 'spotify:track:0dwX01KbB3IZD0Ay3Buhs8'],
#  ['Paralyzed', 'spotify:track:4Dh97nKXuExf9MTxIF1j3G'],
#  ['The Franconian Woods in Winters Silence',
#   'spotify:track:0Lg9zc2fADhivnwunCw50m'],
#  ['Stellar Regions (Alternate take)', 'spotify:track:6XCxLIY7kS2ftVBToYrLJx'],
#  ['Call to Arms', 'spotify:track:1BoF5jUgUyTOsh2yWRyyIy'],
# ...

# %%
# Rock aggressive bright voice fast danceable 513
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 8:
        if alldata[i][26] == 14:
            if alldata[i][27] == 15:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 0:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['No Cars Go', 'spotify:track:51xBgzcyzojRpqFW2ICQAB'],
#  ['Best Adventures', 'spotify:track:57UdbUkBf8LAMTWVp0XZ0p'],
#  ['Jadoo', 'spotify:track:1q2tDXo93duT0MUvACflnp'],
#  ['Brooklyn (If You See Something, Say Something)',
#   'spotify:track:5cAGhXP9mizG5jvMyZ4bHw'],
#  ['ONLY BLOOD', 'spotify:track:5acbzqbocT0tTbtqWU5PwB'],
#  ['Live Together', 'Not Found'],
#  ['Put Me On', 'spotify:track:58pbbYd34Qprru9QV3NNES'],
#  ['In Repair', 'spotify:track:4T162Iwzdnk7yWupCwapoq'],
#  ['Food', 'spotify:track:6EevRvzPGVJ8Gfwl0aog5z'],
#  ['Fatamorgana', 'spotify:track:5XBVVqSeJmB2wZ6AINtySL'],
#  ['08 Beacon', 'Not Found'],
#  ['Can Anybody Hear Me', 'spotify:track:2jlYG36aQhRx5BFYZrXb4T'],
#  ['Humble Neighborhoods', 'spotify:track:0opRTPPvTyqqTr4SIDPOxL'],
#  ['Rider', 'spotify:track:6Vwze1ErvmH3q593nr1nuS'],
#  ['On the Beach', 'spotify:track:12oseQ6xiOQbc7jRSyLB2p'],
#  ['This Plan', 'spotify:track:6q2URfPF62NbUWqNfce3ip'],
# ...

# %%
# Rock aggressive bright voice fast not_danceable 683
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 8:
        if alldata[i][26] == 14:
            if alldata[i][27] == 15:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['By Your Side', 'spotify:track:03vDzULzwJwEnDxYL94bT5'],
#  ['Pet Semetary', 'Not Found'],
#  ['Let Me Put It Next to You', 'spotify:track:6slX0cjK8gTfxTcX8Zu9wo'],
#  ['The Rising', 'spotify:track:646WC53QSKIKLIGrwjiW9K'],
#  ['Frantic Romantic', 'Not Found'],
#  ['Deep Ellis', 'spotify:track:5yTWWY4Sw9kavYIFYdq4Ow'],
#  ['True Faith', 'Not Found'],
#  ['Venting (Its a Different World Today)',
#   'spotify:track:16OO9HVwaSIgJyNppuxSrC'],
#  ['Scots Wha Hae', 'spotify:track:5IirhAbul4WlicEnVvstZx'],
#  ['10.Hole In My Heart', 'Not Found'],
#  ['Its Too Late', 'spotify:track:3QC8SkNKVI278HWa53zE2a'],
#  ['Till the End of Time', 'spotify:track:2nqrE06acbgFhg8k9UYDXM'],
#  ['Dont Say Its Over', 'spotify:track:151q4YExN2sUxCY9BDYqvW'],
#  ['Rock ’n’ Roll Toilet', 'spotify:track:3pBVhj89EDX784nbyZc1pm'],
#  ['Unknown Journey VI', 'spotify:track:4K1ws716I10MEseMPX1uAl'],
#  ['My Way', 'spotify:track:3MuSi2VtaslYDCsD06bxbf'],
# ...

# %%
# Rock aggressive bright voice slow danceable 148
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 8:
        if alldata[i][26] == 14:
            if alldata[i][27] == 15:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 20:
                        if alldata[i][30] == 0:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Correct Me If Im Wrong', 'spotify:track:47YVaPzpAi5s4q8D7I87Em'],
#  ['Razamanaz', 'spotify:track:1PSEl6u1vqONe5Tk3xYVNY'],
#  ['Beautiful You', 'spotify:track:0FhTWG6j6NZbc7cLHwq3SM'],
#  ['State of Love and Trust (live)', 'spotify:track:1dDNtWxA3dfEA6iwFfXbnO'],
#  ['We Must Be in Love', 'Not Found'],
#  ['Self Abuse', 'spotify:track:7d5YOGb2ovpK2xXFE8iweL'],
#  ['Gigabyte Wars', 'spotify:track:6tdw0Fs9tc9JyxgLTuRp4C'],
#  ['A Groovy Kind of Love', 'spotify:track:2xOEmK42jfYwj0biDzNlW2'],
#  ['Shes Goin Thru My Head', 'spotify:track:3Fn4C1dAb69sKUTlQyXvoC'],
#  ['Blue', 'spotify:track:4MoqLn9tRZzhSq7cAxEdRG'],
#  ['My Ark', 'spotify:track:173sKLf2AlKOxpPYFmJJlv'],
#  ['Dropping Like Flies', 'spotify:track:4nziUXKov2xsqSTCUJ3k1t'],
#  ['Slide Part 07-27', 'Not Found'],
#  ['Twisted Love', 'spotify:track:5Nc1zAAmAovJPwKrryR4Y9'],
#  ['Overdose Affair', 'spotify:track:50Tt7kgEPFWSOxE6EX5AI1'],
#  ['Run by Night', 'spotify:track:4PmlQBzKUQXYVrPfly7w60'],
# ...

# %%
# Rock aggressive bright voice slow danceable 173
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 8:
        if alldata[i][26] == 14:
            if alldata[i][27] == 15:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 20:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['The Coachmen', 'Not Found'],
#  ['Ca Plane Pour Moi', 'spotify:track:1lc7a3p0mNY08TtMWbv9Fs'],
#  ['Ive Got The Fire (Live)', 'Not Found'],
#  ['Håll om mig', 'spotify:track:4J0WQvqCBytACvgKVrq1S3'],
#  ['£å£á£ò£ô£è', 'spotify:track:7t2bFihaDvhIrd2gn2CWJO'],
#  ['Play Me Something Country', 'spotify:track:0ZyfMWfUeQ9fWeCBHq1B95'],
#  ['Bedroom After Bedroom', 'spotify:track:4OJQEFMfJYdrSwKQVd84XC'],
#  ['Stranger Blues', 'spotify:track:1rJ4QXyMDbqPEIFwoZq5bw'],
#  ['River to Consider', 'spotify:track:0wrTxVqjbSPmSc31dpBs2b'],
#  ['タビダチの歌', 'Not Found'],
#  ['Yaw ha yaw ha yaw', 'spotify:track:1WIFG7wNvLGzwk73B0c4LV'],
#  ['Cant Talk Now', 'Not Found'],
#  ['Stupid Girl', 'spotify:track:40u9RFyKQfXwpPjFzK1bGO'],
#  ['Stone Of Kings', 'spotify:track:1S3vfC7T9GH8hPLImSZKDU'],
#  ['Reign of Terror', 'spotify:track:3lY8UH3S8fYATDgajJCVpe'],
#  ['Far', 'spotify:track:0TKtoLQkBjdvBaFJSxWhVm'],
#  ['Nostalgic Echo', 'spotify:track:0ohFkmTDKUQnmLTBF9keMj'],
# ...

# %%
# Rock aggressive dark instrumental fast danceable 683
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 8:
        if alldata[i][26] == 14:
            if alldata[i][27] == 16:
                if alldata[i][28] == 17:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 0:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Mélo-Trirème', 'Not Found'],
#  ['Fenrisúlfur', 'Not Found'],
#  ['Voto latino', 'spotify:track:5wirJjROTycLT3vjYDZDJN'],
#  ['Supernatural', 'spotify:track:5oEyZA1uIPBDMNMvyOXKAr'],
#  ['Revolution', 'spotify:track:1fC7Ff8HOYuR2GMSgHZVwO'],
#  ['Insurrection', 'Not Found'],
#  ['Stir It Up', 'Not Found'],
#  ['Assimilate (R23)', 'spotify:track:7vmzkjDOXvvu28k7onPMC3'],
#  ['Monkey on Your Back', 'spotify:track:04MelmovbVMQVQscyDufQ1'],
#  ['Blacken The Sky (Demo 2004)', 'spotify:track:1E6qq8X4LNGBOrzyGj5XAG'],
#  ['Just One More', 'spotify:track:683Sb3FcyoHLCnAro47Jn0'],
#  ['Even Gods Do Fall', 'spotify:track:44GaZjQUSiGhhQCDQPzCz9'],
#  ['Somethings Got A Hold on Me', 'spotify:track:24WMIVBe1gDwY08xwfKbvp'],
#  ['Im Flexible', 'spotify:track:42q17ChQ9t715cN7ECC8j5'],
#  ['Mictlan: Entrada al infierno', 'spotify:track:3vZ3I6WYSeJqMwOeslNcNy'],
#  ['Through Stars Into Voids', 'spotify:track:0o3XwXlZfS6xM2Ozayg4U3'],
# ...

# %%
# Rock aggressive dark instrumental fast not_danceable 1761
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 8:
        if alldata[i][26] == 14:
            if alldata[i][27] == 16:
                if alldata[i][28] == 17:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Parasite', 'spotify:track:6jqRl8hLHidNt3S7xrSNck'],
#  ['Must Destroy', 'spotify:track:3hy3TfLSNKV7q769f1jt1E'],
#  ['Splintered in Her Head', 'spotify:track:6A51UTp69oNqzBn8C1YAGS'],
#  ['Toothpicks', 'spotify:track:3oLwYdkXpZEKvTaZawVlzm'],
#  ['Take Me to Your Leader', 'spotify:track:1vjzLvbIo4TXhrwL50dsXY'],
#  ['All You Have to Do', 'spotify:track:5mTjj6Z6qd0R3emQu9Fp3s'],
#  ['Ghost Key (alternate demo version)',
#   'spotify:track:6ncNL7FKOxJB81ye1XiT2T'],
#  ['Living for the Weekend', 'spotify:track:167FV9282AoJ3raMsMXkbY'],
#  ['Pliable Foe', 'spotify:track:3RsXA8ycNwwzWjbX3oIRDr'],
#  ['In Memoriam', 'spotify:track:6IuNdqBU3kULNmxlEQQV6c'],
#  ['Carry the Banner', 'spotify:track:0IEBoUX5XvoP5pZkUJ4qQ0'],
#  ['Dan and Marie Picking Hum', 'spotify:track:1qeHg8qZ1zSCMnWNXwwOgC'],
#  ['In Sleep', 'spotify:track:4MQfntyMKsALV9J4ht9BEq'],
#  ['Daimonos', 'spotify:track:0x2P4d5Q8VRU0nasT1g4Fs'],
#  ['Messengers Of The Verb', 'spotify:track:43z3OortxQF6tnaCmoZKVF'],
# ...

# %%
# Rock aggressive dark instrumental slow danceable 184
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 8:
        if alldata[i][26] == 14:
            if alldata[i][27] == 16:
                if alldata[i][28] == 17:
                    if alldata[i][29] == 20:
                        if alldata[i][30] == 0:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Conscious Self', 'spotify:track:32yVlvJj4vfn3kCtTwXrG1'],
#  ['Im from Hell, Open a Windle', 'spotify:track:0TOFJWSXeC4KqEudyWk9uv'],
#  ['Mountain Dusk', 'Not Found'],
#  ['Work Day', 'spotify:track:6EC9YOtyODY6JdxaCUwwxc'],
#  ['Disgrace', 'spotify:track:6itFFybicSj5KZZaDkq57p'],
#  ['Slow Down', 'spotify:track:1kzM3MIYwBCBi4RfFAU6fp'],
#  ['Seen It All', 'spotify:track:5cnIXwlnlHyBlWkZyxPkvs'],
#  ['Thats The Way Life Goes', 'spotify:track:139aCDCkxsCkr4qWW5hKoT'],
#  ['Too Many Prophets', 'spotify:track:3o0CPYUTuzop4OdiLGrN7I'],
#  ['The Hands', 'spotify:track:4rEueMMzMN5lL31KSdYcvN'],
#  ['A Moment of Violence', 'spotify:track:5qE1VxYm4TLbtuIWaXXSQe'],
#  ['The Narrows (demo)', 'spotify:track:4uxyV8D5IypPO4SDfnhETg'],
#  ['I Cut Like a Buffalo / Dont Sweat the Technique', 'Not Found'],
#  ['Troops of Tomorrow', 'spotify:track:5YNZsMiAxQX2xfArf4MSRu'],
#  ['Voodoo Dust', 'spotify:track:2iQRBac5Sip0h0qSiGPIxp'],
#  ['I Never Dreamed', 'spotify:track:041b7MxWnYhgus5GRSFA7J'],
# ...

# %%
# Rock aggressive dark instrumental slow danceable 547
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 8:
        if alldata[i][26] == 14:
            if alldata[i][27] == 16:
                if alldata[i][28] == 17:
                    if alldata[i][29] == 20:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Until I Find You', 'spotify:track:2Yi9FdjtMftf26uFbZxKsQ'],
#  ['Consign to Oblivion (A New Age Dawns, Part 3)', 'Not Found'],
#  ['05 - Im Losing You', 'Not Found'],
#  ['Black Serenade', 'spotify:track:1TiYU1hgkAChn2DHWB9XlH'],
#  ['Angel on My Shoulder', 'spotify:track:37GSbW1eZpU9PfBBXDniIR'],
#  ['Mercury', 'Not Found'],
#  ['Universal Indians (alternate take)',
#   'spotify:track:0IroMlFLHwJOGqHJanVu9L'],
#  ['Schizoid Man 11', 'Not Found'],
#  ['We Are But Divers In The Ember', 'spotify:track:6P8jfluPaXZ63vM66snArV'],
#  ['Электричество', 'spotify:track:54JPlZkKBUEtUpKpiWw5Zm'],
#  ['Ejército de salvación', 'spotify:track:2n5fseMe1CNvPETJExk037'],
#  ['TV Crimes', 'spotify:track:1ECcwLhP63lbKSNKuswrNL'],
#  ['Turn Up the Night', 'spotify:track:30rVkfX5VqUXycH0V9q66V'],
#  ['Purple Sage', 'spotify:track:4Jxi4CVjIQQURQYel8RH4S'],
#  ['Death League', 'spotify:track:1ICAYcufLDB5TnzQhDzoo7'],
#  ['Trouble in Town', 'spotify:track:1mF6es8VpUeYNTSE4gdcyI'],
# ...

# %%
# Rock aggressive dark voice fast danceable 1206
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 8:
        if alldata[i][26] == 14:
            if alldata[i][27] == 16:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 0:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Into the Land of Dreams', 'Not Found'],
#  ['Conjure the Mass', 'spotify:track:1hxPK2icP8FJfs3c99x9nV'],
#  ['All Or Nothing', 'spotify:track:4mTQvkkJ8K4FP0sYzcouOF'],
#  ['My Life', 'spotify:track:6VCEgIcIShth0fGcRUG1d9'],
#  ['Big Sprawling Corrupt', 'spotify:track:3ChSLGXzvpQyw9H7kR0V1H'],
#  ['I’m Her Slave', 'Not Found'],
#  ['Rausch der Macht', 'Not Found'],
#  ['We Love the Dead', 'spotify:track:0AnXiJO5MBAvZiPbLxNHd1'],
#  ['White Trash', 'spotify:track:3ni7TniDkvdPDHVBAmpYYu'],
#  ['Fuck the Ways of Christ', 'Not Found'],
#  ['Blood, Tears, Dust', 'spotify:track:6gXWMvHAZ8EPYRmcXXoNxk'],
#  ['No Surprise', 'spotify:track:5jGeQRvBScdvFEkbiAlS7J'],
#  ['Black Sabbath', 'Not Found'],
#  ['Long Snake Moan', 'spotify:track:36YJWsgSCEMFsv9Y2jxI4U'],
#  ['When Everyone Is Everybody Else', 'spotify:track:6yOzk74bY6bUB9JDm3JZ8w'],
#  ['Revenge of Princess Olga', 'spotify:track:5y5RUPyLY2zmsWnj8jrpUi'],
#  ['The Truth', 'spotify:track:03vA8pm6iwDKliVcnA3N41'],
# ...

# %%
# Rock aggressive dark voice fast danceable 2103
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 8:
        if alldata[i][26] == 14:
            if alldata[i][27] == 16:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 19:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['From the Ashes', 'Not Found'],
#  ['The Slow Surrender', 'spotify:track:18pix4twyWpotDwCBmdpsC'],
#  ['Din siste dag', 'Not Found'],
#  ['Sins of the Father', 'spotify:track:5C39QgIjWpTpbt1XUCQ5p2'],
#  ['Grave Desecration', 'Not Found'],
#  ['The Rocker', 'spotify:track:2qRF6tYwmXy6oMUSI4bKQA'],
#  ['Im Fine', 'spotify:track:6R1R5m5PSyGXoo8RPepom8'],
#  ['Demi-God', 'spotify:track:6x0TFjc4MGk3cbiuknQBN4'],
#  ['Daylight', 'spotify:track:7pJx8OGZ8fBbchaVLxveE2'],
#  ['Human Waste', 'spotify:track:3LdCpC24RXQoKFCpWiPCBH'],
#  ['Trashed', 'Not Found'],
#  ['Breakdown 2012', 'spotify:track:6u90nxNj5unc9RreFd0h71'],
#  ['A.N.Ts', 'Not Found'],
#  ['Roberta', 'Not Found'],
#  ['Nightmare', 'spotify:track:78KZYvt4u0kASNU1BQ1ZQo'],
#  ['Thy Beauty in Candlelight', 'Not Found'],
#  ['Heaven Ablaze', 'spotify:track:6uQKb1wNc813A2SxEGDsDq'],
#  ['All My Needs', 'spotify:track:6PdvE0e55Z5qvfft0Rgq4r'],
#  ['Slam And Worm', 'spotify:track:6xsGphNbGqKRgCz8iue45k'],
# ...

# %%
# Rock aggressive dark voice slow danceable 475
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 8:
        if alldata[i][26] == 14:
            if alldata[i][27] == 16:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 20:
                        if alldata[i][30] == 0:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [['Off With Her Head', 'spotify:track:4nPI6aIrHaMNZbF2q8NfpX'],
#  ['Welcome to Hell', 'spotify:track:6HRc1GtEsazQZx8WBI0P75'],
#  ['Ora', 'spotify:track:7c7ssX7Yqk9ajFseHFP8ek'],
#  ['Bad Name', 'spotify:track:6TcmbCKUzOOF3qjCS7oKeJ'],
#  ['America Latina', 'spotify:track:3VQNMRQvaX0uFeJBDKScBJ'],
#  ['Touch of Everything', 'spotify:track:4lAKRWNRJvxm2nGISLK7jx'],
#  ['The Beast Fang to Teat Down', 'Not Found'],
#  ['On the Run', 'Not Found'],
#  ['Sunday Papers', 'spotify:track:5MRt5JfLp42Nvj5Gg2ZRwO'],
#  ['Now I Wanna Sniff Some Glue', 'Not Found'],
#  ['Honeybee', 'Not Found'],
#  ['You Gotta Believe', 'spotify:track:0jsaLFI2Ftvp48uTZXNzi8'],
#  ['Bleeder', 'spotify:track:6r77c9NMDUtQ0NbJXG0EcX'],
#  ['Zu Viel', 'spotify:track:7q01TIKeJmE5bcaiHx3Z2r'],
#  ['Fourth Roman Empire', 'Not Found'],
#  ['Final Six', 'Not Found'],
#  ['White Stone', 'spotify:track:6pCAt2tnEjVc5oYxovfIrW'],
#  ['Transitory', 'spotify:track:5MWa30FhpJH2t3SIc88ZZe'],
# ...

# %%
# Rock aggressive dark voice slow danceable 793
list1 = []
for i in range(0, len(alldata)):
    if alldata[i][25] == 8:
        if alldata[i][26] == 14:
            if alldata[i][27] == 16:
                if alldata[i][28] == 18:
                    if alldata[i][29] == 20:
                        if alldata[i][30] == 1:
                            list1.append([alldata[i][0],alldata[i][24]])
list1
# Out:
# [[' Wasted Wishing', 'spotify:track:7xsDGeyJ5d6jubpvOeYzk6'],
#  ['Dead Cell (live)', 'spotify:track:5MjwI0rH5cBiecz5EoKEx4'],
#  ['ENDLESS RAIN (LIVE VERSION, Recorded at NIPPON BUDOKAN 1990.2.4.)',
#   'Not Found'],
#  ['Everlasting Flame', 'spotify:track:5PVSkXQAfNkX23tDq4yvUh'],
#  ['The Nail Will Burn', 'spotify:track:1oqeM3DXKpbDG2JwOxTG6y'],
#  ['Oppression', 'spotify:track:6TFrwrhbgVvEEoVvdrzueX'],
#  ['Asatru', 'spotify:track:3CA3aTHWrvStsQ5y5oYHXv'],
#  ['Forever Scorned', 'spotify:track:2zycIWGshdROvebsUV7KBn'],
#  ['No Remorse', 'spotify:track:6gP7mrmL9EsFS3sMpk3Ig3'],
#  ['Viinaa suon issa, kusta päässä', 'spotify:track:4VUVsJS5ZLGum2P8qB8erc'],
#  ['Dominanz', 'spotify:track:7bKmvzuCRs60KlniTb58IO'],
#  ['Lost Cause', 'spotify:track:0rMdU1QLjxaYi7RYuYaGbE'],
#  ['Abiku', 'spotify:track:78ZJRG3XUTfNqpdMmYsPWp'],
#  ['My Own Maker', 'spotify:track:1x6AKB9xCKg8PD1Mi0ZDtN'],
#  ['Hyper Worm Tamer', 'spotify:track:0iLIZJXsfyhyC2VeIqqNXQ'],
# ...

# %% [markdown]
# # Speech Playlists omitted
